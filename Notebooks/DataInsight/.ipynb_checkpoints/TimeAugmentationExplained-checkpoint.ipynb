# %%
#!/usr/bin/env python
import numpy as np
import pandas as pd
import h5py
import matplotlib.pyplot as plt
import pprint
import json

import numpy as np
import pandas as pd
import obspy
import math

import matplotlib.pyplot as plt
import seaborn as sns

import pylab as pl
import time

from matplotlib.colors import ListedColormap
plt.rcParams["figure.figsize"]= (15,15)
from matplotlib import rcParams, cycler
import matplotlib.colors as colors
from matplotlib import cm


import sys
import os
ISCOLAB = 'google.colab' in sys.modules

import random
import json
import pprint
from obspy import Stream, Trace, UTCDateTime
sns.set(style='white', context='notebook', rc={'figure.figsize':(14,10)})

base_dir = '/media/tord/T7/Thesis_ssd/MasterThesis3/'
os.chdir(base_dir)

from Classes.DataProcessing.LoadData import LoadData
from Classes.DataProcessing.HelperFunctions import HelperFunctions
from Classes.DataProcessing.DataHandler import DataHandler
from Classes.DataProcessing.TimeAugmentor import TimeAugmentor
import json

SMALL_SIZE = 16
MEDIUM_SIZE = 16
BIGGER_SIZE = 18

plt.rc('font', size=MEDIUM_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title


#%matplotlib notebook
helper = HelperFunctions()

# %%
load_args = {
    'earth_explo_only' : True,
    'noise_earth_only' : False,
    'noise_not_noise' : False,
    'downsample' : True,
    'upsample' : True,
    'frac_diff' : 1,
    'seed' : 1,
    'subsample_size' : 0.05,
    'balance_non_train_set' : True,
    'use_true_test_set' : False,
    'even_balance' : True
}
loadData = LoadData(**load_args)
full_ds, train_ds, val_ds, test_ds = loadData.get_datasets()
noise_ds = loadData.noise_ds
handler = DataHandler(loadData)
# Out:
# 2 2
# Mapping redundancy: [--->                                    ] 12 %
# Mapping redundancy: [------>                                 ] 18 %
# Mapping redundancy: [-------->                               ] 24 %
# Mapping redundancy: [----------->                            ] 30 %
# Mapping redundancy: [------------->                          ] 37 %
# Mapping redundancy: [---------------->                       ] 43 %
# Mapping redundancy: [------------------->                    ] 50 %
# Mapping redundancy: [--------------------->                  ] 56 %
# Mapping redundancy: [------------------------>               ] 63 %
# Mapping redundancy: [-------------------------->             ] 69 %
# Mapping redundancy: [----------------------------->          ] 75 %
# Mapping redundancy: [------------------------------->        ] 82 %
# Mapping redundancy: [---------------------------------->     ] 88 %
# Mapping redundancy: [------------------------------------>   ] 94 %
# Mapping redundancy: [--------------------------------------->] 100 %

# %%
earth_ds = full_ds[full_ds[:,1] == "earthquake"]

# %% [markdown]
# ### Observations:

# %% [markdown]
#  - Some events appear to contain multiple earthquakes (f.eks: /media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2007-09-19T04.41.56.167000Z.h5, /media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2010-04-15T19.20.09.574000Z.h5
#  - Generally the onset of the earthquake is very weak, and after often over a minute later, the visually clear event occurs. This is very problematic wrt. the augmentation.
#
#
#
# ### Good candidates:
#
# Events which start at the beginning of the waveform:
#  - /media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2010-04-15T19.20.09.574000Z.h5
#  - /media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2015-10-24T03.04.11.895000Z.h5
#  - /media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2015-01-07T04.18.26.039000Z.h5
#  - /media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2008-02-24T10.49.54.603000Z.h5
#
#
# Events which start at the middle of the waveform:
#
# Events which start at the end of the waveform:
#
#
#  #### Problematic datapoints:
#  - /media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2013-08-18T09.00.06.112000Z.h5 (No clear event)
#  - /media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2009-09-10T13.44.59.544000Z.h5 (Labeled start is before the start of the waveform)
#  - /media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2009-09-14T00.42.14.329000Z.h5 (indistinguishable from noise)
#  - /media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2019-12-12T00.06.11.688000Z.h5 (Event of interest appears to occur waay later than labeled. This leads to that part being cut out.
#
#  - /media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2010-08-11T06.03.18.764000Z.h5 (too similar to noise)

# %%
i = 18
candidates = [1, 2, 6, 7, 8, 10]
use_filter = True

earth_path = earth_ds[i][0]
print(earth_path)
trace, info = handler.path_to_trace(earth_path)
if use_filter:
    trace = np.array([trace])
    trace = handler.detrend_highpass_batch_trace(trace, True, True)
    trace = trace[0]
print(info['est_arrivaltime_arces'])
helper.plot_event(trace, info)
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(info)
# Out:
# /media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2010-08-11T06.03.18.764000Z.h5
# 2010-08-11 06:04:18.764000
# {   'analyst_pick_time': None,
#     'az_to_arces': 171.2505694369304,
#     'baz_to_arces': 355.63920760402095,
#     'dist_to_arces': 1168.1270466886635,
#     'est_arrivaltime_arces': '2010-08-11 06:04:18.764000',
#     'event_type': 'earthquake',
#     'event_type_certainty': 'known',
#     'magnitude_dist_ratio': 0.0019467060594532066,
#     'magnitude_sqrtdist_ratio': 0.06653427371811156,
#     'magnitudes': [   {   'mag': 2.274,
#                           'magnitude_type': 'Mb',
#                           'origin_id': 'smi:local/c8924fdf-1fd4-4175-a3df-53328c5847a1',
#                           'resource_id': 'smi:local/acc0b1ff-23c0-4969-ab5a-2e04e542bfd1'},
#                       {   'mag': 2.17,
#                           'magnitude_type': 'Ml',
#                           'origin_id': 'smi:local/c8924fdf-1fd4-4175-a3df-53328c5847a1',
#                           'resource_id': 'smi:local/97df1e3a-2da3-4a00-9aa9-bda486a9d7b3'}],
#     'origins': [   {   'arrivals': [   {   'azimuth': 24.223327,
#                                            'backazimuth_residual': 7.1166728,
#                                            'comments': [   {   'resource_id': 'smi:local/481ae83c-952f-45a7-9738-ea50d98386d4',
#                                                                'text': 'ARID=4641815'}],
#                                            'horizontal_slowness_residual': 0.84633789,
#                                            'phase': 'Pn',
#                                            'pick_id': 'smi:local/56f70bbf-691d-43bc-995d-8ddc117f60ee',
#                                            'resource_id': 'smi:local/3cadc2e8-b099-46d7-a055-71b5b1f384c4',
#                                            'time_residual': 0.47992185},
#                                        {   'azimuth': 24.223327,
#                                            'backazimuth_residual': 4.9966728,
#                                            'comments': [   {   'resource_id': 'smi:local/4119d582-364d-4d96-9053-758794ce071b',
#                                                                'text': 'ARID=4641816'}],
#                                            'horizontal_slowness_residual': -2.8718356,
#                                            'phase': 'Pg',
#                                            'pick_id': 'smi:local/6675f1b6-c34b-4204-8124-4c4005813887',
#                                            'resource_id': 'smi:local/decd27f4-2a15-4204-90cd-6385d17aed1e',
#                                            'time_residual': 0.059109739},
#                                        {   'azimuth': 24.223327,
#                                            'backazimuth_residual': 25.675765,
#                                            'comments': [   {   'resource_id': 'smi:local/a49d1a04-aa75-4450-be86-46f3ee98da19',
#                                                                'text': 'ARID=4641824'}],
#                                            'horizontal_slowness_residual': -9.5819697,
#                                            'phase': 'Lg',
#                                            'pick_id': 'smi:local/996a93d9-7cec-4cc5-a193-f6b17887dc46',
#                                            'resource_id': 'smi:local/10be1623-b011-40bf-98ed-e5db8f0f0364',
#                                            'time_residual': 0.26403367},
#                                        {   'azimuth': 17.715049,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/c5bb9eb7-c64c-49e8-8db3-cdc5414add0c',
#                                                                'text': 'ARID=25450'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Lg',
#                                            'pick_id': 'smi:local/844691a1-60ff-430b-b316-35c92eb673c4',
#                                            'resource_id': 'smi:local/831bbce1-6730-484e-b396-e02b1b0725d9',
#                                            'time_residual': -1.7325105},
#                                        {   'azimuth': 17.715049,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/1c688c6f-f599-4bb0-a0ea-2b2801ed55fc',
#                                                                'text': 'ARID=25451'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Pg',
#                                            'pick_id': 'smi:local/0f29e2c4-ece2-4646-8ec3-ed2b5efe3e16',
#                                            'resource_id': 'smi:local/852ab99c-030a-4ff7-a8c0-8586175da816',
#                                            'time_residual': -0.64438578},
#                                        {   'azimuth': 17.715049,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/b8bea6b0-6d76-4cc9-bb46-764e0f49d1f6',
#                                                                'text': 'ARID=25452'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Pn',
#                                            'pick_id': 'smi:local/c79db221-a38a-49cd-8eae-4613fd761e8b',
#                                            'resource_id': 'smi:local/559d437e-4350-4735-88bb-49e4fbbf1e07',
#                                            'time_residual': -1.8311956},
#                                        {   'azimuth': 54.270882,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/51fadab2-4433-408a-855a-fd5dac69eaab',
#                                                                'text': 'ARID=25453'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Lg',
#                                            'pick_id': 'smi:local/11a82a04-62aa-4c99-b9f3-b554eaac2243',
#                                            'resource_id': 'smi:local/24836915-b4db-4efd-a1ad-5876d6f9de61',
#                                            'time_residual': -0.84405051},
#                                        {   'azimuth': 54.270882,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/1cbb6cf9-8da1-4e0f-a3a4-59e654b8fddb',
#                                                                'text': 'ARID=25454'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Pg',
#                                            'pick_id': 'smi:local/1e37cac0-4bb0-4e61-878c-6ea679c569d8',
#                                            'resource_id': 'smi:local/548f9909-6c4b-4358-b4fb-e2e960e32f01',
#                                            'time_residual': 0.45708959},
#                                        {   'azimuth': 54.270882,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/917f3eac-8be4-4381-838a-ebb8c0c18d68',
#                                                                'text': 'ARID=25455'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Pn',
#                                            'pick_id': 'smi:local/9b98997e-62f0-4c37-aea8-07e6953b793e',
#                                            'resource_id': 'smi:local/e39a3c8e-16d7-4d2e-8d2f-72de673d48d0',
#                                            'time_residual': -0.78065501}],
#                        'comments': [   {   'resource_id': 'smi:local/0b71da74-5d3b-4e8f-822e-1a8799375157',
#                                            'text': 'orid: 13789'}],
#                        'creation_info': {   'agency_id': 'NORSAR',
#                                             'author': 'ARS:berit',
#                                             'creation_time': '2010-08-16T07:15:00.000000Z'},
#                        'depth': 16.199534,
#                        'depth_errors': {'uncertainty': 18.360769},
#                        'latitude': 79.935406,
#                        'longitude': 20.979704,
#                        'quality': {   'associated_phase_count': 9,
#                                       'used_phase_count': 9},
#                        'resource_id': 'smi:local/c8924fdf-1fd4-4175-a3df-53328c5847a1',
#                        'time': '2010-08-11T06:01:19.052680Z',
#                        'time_errors': {'uncertainty': 3.8905383}}],
#     'resource_id': 'smi:local/31cd3f2b-f730-4ce4-a2c1-6c99e6931181',
#     'trace_stats': {   'channels': [   'P-beam, vertical',
#                                        'S-beam, transverse',
#                                        'S-beam, radial'],
#                        'sampling_rate': 40.0,
#                        'starttime': '2010-08-11T06:03:18.775000Z',
#                        'station': 'ARCES beam'}}

# %%
timeAug = TimeAugmentor(handler, earth_ds, loadData.seed)
timeAug.find_initial_event_index(earth_path)
# Out:
# (2283,
#  {'resource_id': 'smi:local/cb0fc3ac-7fa0-44da-ab98-2e2d98cf83a5',
#   'event_type': 'earthquake',
#   'event_type_certainty': 'known',
#   'origins': [{'resource_id': 'smi:local/0c4097cc-e3c8-4354-b772-fb763a35d653',
#     'time': '2010-05-23T14:54:51.439670Z',
#     'time_errors': {'uncertainty': 2.9341547},
#     'longitude': 8.5156421,
#     'latitude': 78.222379,
#     'depth': 0.0,
#     'depth_errors': {'uncertainty': -1.0},
#     'quality': {'associated_phase_count': 4, 'used_phase_count': 4},
#     'creation_info': {'agency_id': 'NORSAR',
#      'author': 'ARS:berit',
#      'creation_time': '2010-06-01T11:14:43.000000Z'},
#     'comments': [{'text': 'orid: 13516',
#       'resource_id': 'smi:local/9870b1e9-d667-4301-8bc7-2a82bf90dcca'}],
#     'arrivals': [{'resource_id': 'smi:local/5e86e4a6-69cb-4140-91a6-75061c3f8f90',
#       'pick_id': 'smi:local/ced482f1-2953-4c1d-925d-214676e33447',
#       'phase': 'Pn',
#       'azimuth': 275.43378,
#       'time_residual': 0.17095035,
#       'horizontal_slowness_residual': 1.7962292,
#       'backazimuth_residual': -13.233779,
#       'comments': [{'text': 'ARID=4289464',
#         'resource_id': 'smi:local/f0654eb7-1696-43d2-a6a8-4d904d3914ff'}]},
#      {'resource_id': 'smi:local/8d5a0284-d3c1-48e4-ac84-622443d6113c',
#       'pick_id': 'smi:local/3403994f-c8e9-4dbc-a254-e464628aaba9',
#       'phase': 'Lg',
#       'azimuth': 275.43378,
#       'time_residual': -0.00087310803,
#       'horizontal_slowness_residual': -999.0,
#       'backazimuth_residual': -999.0,
#       'comments': [{'text': 'ARID=24550',
#         'resource_id': 'smi:local/543eeb15-9c55-42c8-adc4-c2c2ca3fc975'}]},
#      {'resource_id': 'smi:local/47633755-23ab-4f48-9811-fa59c115a73d',
#       'pick_id': 'smi:local/6c43505f-0765-4d11-a940-86cd8fa2d03b',
#       'phase': 'Lg',
#       'azimuth': 225.67884,
#       'time_residual': 0.012037058,
#       'horizontal_slowness_residual': -999.0,
#       'backazimuth_residual': -999.0,
#       'comments': [{'text': 'ARID=24551',
#         'resource_id': 'smi:local/639fcbbb-e85b-495c-9dfd-5664ee2cde8e'}]},
#      {'resource_id': 'smi:local/384ce6b9-4f9d-4915-abb9-3b60e4abe920',
#       'pick_id': 'smi:local/38c120c8-8030-4aca-9a4e-d248804c779a',
#       'phase': 'Pg',
#       'azimuth': 225.67884,
#       'time_residual': -0.47196021,
#       'horizontal_slowness_residual': -999.0,
#       'backazimuth_residual': -999.0,
#       'comments': [{'text': 'ARID=24552',
#         'resource_id': 'smi:local/cf773bd3-af35-48ad-9b1f-afefe15ce903'}]}]}],
#   'magnitudes': [{'resource_id': 'smi:local/d03c7888-5023-40cc-ac39-c85c1c1573a2',
#     'mag': 2.029,
#     'magnitude_type': 'Mb',
#     'origin_id': 'smi:local/0c4097cc-e3c8-4354-b772-fb763a35d653'},
#    {'resource_id': 'smi:local/77318fe3-cdd9-4a57-9def-bcbcb7dff008',
#     'mag': 2.09,
#     'magnitude_type': 'Ml',
#     'origin_id': 'smi:local/0c4097cc-e3c8-4354-b772-fb763a35d653'}],
#   'az_to_arces': 143.0970707060948,
#   'baz_to_arces': 339.47862538471844,
#   'dist_to_arces': 1094.2611057067936,
#   'est_arrivaltime_arces': '2010-05-23 14:57:39.787000',
#   'magnitude_dist_ratio': 0.0018542192438517219,
#   'magnitude_sqrtdist_ratio': 0.06133686367736081,
#   'analyst_pick_time': None,
#   'trace_stats': {'starttime': '2010-05-23T14:56:39.775000Z',
#    'sampling_rate': 40.0,
#    'station': 'ARCES beam',
#    'channels': ['P-beam, vertical', 'S-beam, transverse', 'S-beam, radial']}})
