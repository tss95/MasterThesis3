# %%
import os
import sys
import pprint
import numpy as np
import pandas as pd
import random
from sklearn.model_selection import ParameterGrid
import pprint
from itertools import chain


base_dir = 'F:\Thesis_ssd\MasterThesis3.0'
os.chdir(base_dir)

from Classes.DataProcessing.LoadData import LoadData
from Classes.DataProcessing.HelperFunctions import HelperFunctions
from Classes.DataProcessing.DataHandler import DataHandler
from Classes.DataProcessing.DataGenerator import DataGenerator
from Classes.DataProcessing.TimeAugmentor import TimeAugmentor
from Classes.DataProcessing.NoiseAugmentor import NoiseAugmentor
from Classes.Modeling.DynamicModels import DynamicModels
from Classes.Modeling.CustomCallback import CustomCallback
from Classes.Modeling.ResultFitter import ResultFitter
from Classes.Modeling.NarrowSearch import NarrowSearch
from Classes.Scaling.ScalerFitter import ScalerFitter
from Classes.Scaling.MinMaxScalerFitter import MinMaxScalerFitter
from Classes.Scaling.StandardScalerFitter import StandardScalerFitter
import json

helper = HelperFunctions()
# %load_ext tensorboard

# %%
### Data conditions: ###
load_args = {
    'earth_explo_only' : False,
    'noise_earth_only' : False,
    'noise_not_noise' : True,
    'downsample' : True,
    'upsample' : True,
    'frac_diff' : 0.05,
    'seed' : 1,
    'subsample_size' : 0.05,
    'balance_non_train_set' : True,
    'use_true_test_set' : False
}

loadData = LoadData(**load_args)

full_ds, train_ds, val_ds, test_ds = loadData.get_datasets()
noise_ds = loadData.noise_ds
handler = DataHandler(loadData)
dataGen = DataGenerator(loadData)

if load_args['earth_explo_only']:
    full_and_noise_ds = np.concatenate((full_ds, noise_ds))
    timeAug = TimeAugmentor(handler, full_and_noise_ds, seed = load_args['seed'])
else:
    timeAug = TimeAugmentor(handler, full_ds, seed = load_args['seed'])
# Out:
# Mapping redundancy: [-------------------------------->       ] 83 %
# Mapping redundancy: [--------------------------------------->] 100 %

# %%
############ Model picker #############
model_nr = 7
num_classes = dataGen.num_classes

########### Hyperparameters ###########
batch_size = 64
epochs = 50
learning_rate = 0.01

#opt = tf.keras.optimizers.RMSprop(learning_rate=learning_rate)
activation = 'tanh'
output_layer_activation = 'sigmoid'
dropout_rate = 0.3
filters = 17
kernel_size = 5
l1_r = 0.0001
l2_r = 0.001
padding = 'same'
start_neurons = 32

########### Preprocessing ###########
use_noise_augmentor = True
use_time_augmentor = True
detrend = False
use_scaler = True
use_highpass = False
highpass_freq = 0.2

use_tensorboard = True
use_livelossplot = True
use_custom = False

# %%
scaler = None
noiseAug = None
if use_time_augmentor:
    timeAug.fit()
if use_scaler:
    scaler = StandardScalerFitter(train_ds, timeAug).fit_scaler(detrend = detrend)
if use_noise_augmentor:
    noiseAug = NoiseAugmentor(train_ds, use_scaler, scaler, loadData, timeAug)

    
    

gen_args = {
    'batch_size' : batch_size,
    'detrend' : False,
    'use_scaler' : use_scaler,
    'scaler' : scaler,
    'use_time_augmentor' : use_time_augmentor,
    'timeAug' : timeAug,
    'use_noise_augmentor' : use_noise_augmentor,
    'noiseAug' : noiseAug,
    'use_highpass' : use_highpass,
    'highpass_freq' : highpass_freq
}


train_gen = dataGen.data_generator(train_ds, **gen_args)
val_gen = dataGen.data_generator(val_ds, **gen_args)
test_gen = dataGen.data_generator(test_ds, **gen_args)
# Out:
# Fit process completed after 2.3616392612457275 seconds. Total datapoints fitted: 2036.
# Average time per datapoint: 0.001159940698057823
# Fitting noise progress: [------------------> ] 99 %%

# %%
X, y = next(train_gen)

# %%
X[:][:,[1,2]].shape
# Out:
# (64, 2, 6000)

# %%
def transform_event(train_ds, timeAug, noiseAug, scaler, index, nr_channels):
    _, info = handler.path_to_trace(train_ds[index][0])
    trace, label = handler.batch_to_aug_trace(np.array([train_ds[index]]), timeAug)
    trace = handler.transform_batch(scaler, trace)
    trace = noiseAug.batch_augment_noise(trace, 0, noiseAug.noise_std/10)
    fill_trace = np.zeros((trace.shape))
    fill_trace[:][:,0:nr_channels] = trace[:][:,0:nr_channels]
    assert fill_trace.shape == trace.shape
    return fill_trace, trace, info

# %%
index = 1
reduced_trace, trace, info = transform_event(train_ds, timeAug, noiseAug, scaler, index, 2)

# %%
helper.plot_event(reduced_trace[0], info)
# Out:
# C:\Users\tss_9\anaconda3\lib\site-packages\obspy\imaging\util.py:275: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# C:\Users\tss_9\anaconda3\lib\site-packages\obspy\imaging\waveform.py:820: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',

# %%
pure_trace, pure_info = handler.path_to_trace(train_ds[index][0])
helper.plot_event(pure_trace, pure_info)

# %%
timeAug.fitted_dict[train_ds[index][0]]
# Out:
# {'initial_index': 2333, 'random_start_index': array([1834, 2771])}

# %%
info
# Out:
# {'resource_id': 'smi:local/2c3d47c4-cfc3-4919-996b-ddc554f9059b',
#  'event_type': 'earthquake',
#  'event_type_certainty': 'known',
#  'picks': [{'resource_id': 'smi:local/cb2d449b-61a3-43df-b511-294e6e4a3053',
#    'time': '2012-05-25T12:54:54.000000Z',
#    'waveform_id': {'station_code': 'ARCES', 'channel_code': 'FD56'},
#    'horizontal_slowness': 10.94,
#    'horizontal_slowness_errors': {'uncertainty': 1.33},
#    'backazimuth': 311.06,
#    'backazimuth_errors': {'uncertainty': 0.12},
#    'phase_hint': 'Pn'},
#   {'resource_id': 'smi:local/246a1f53-3c4a-468b-bfc5-7ad74cbfbf97',
#    'time': '2012-05-25T12:56:13.075000Z',
#    'waveform_id': {'station_code': 'ARCES', 'channel_code': 'FR20'},
#    'horizontal_slowness': 20.98,
#    'horizontal_slowness_errors': {'uncertainty': 1.57},
#    'backazimuth': 298.49,
#    'backazimuth_errors': {'uncertainty': 0.07},
#    'phase_hint': 'Sn'}],
#  'origins': [{'resource_id': 'smi:local/d83e4b2e-d748-4156-8ee2-ecff810503aa',
#    'time': '2012-05-25T12:53:05.748530Z',
#    'time_errors': {'uncertainty': 1.6550705},
#    'longitude': 5.4202687,
#    'latitude': 73.051726,
#    'depth': 0.0,
#    'depth_errors': {'uncertainty': -1.0},
#    'quality': {'associated_phase_count': 10, 'used_phase_count': 10},
#    'creation_info': {'agency_id': 'NORSAR',
#     'author': 'ARS:berit',
#     'creation_time': '2012-05-30T11:59:53.000000Z'},
#    'comments': [{'text': 'orid: 15676',
#      'resource_id': 'smi:local/3cb934e5-376d-42fe-a265-165485d68f20'}],
#    'arrivals': [{'resource_id': 'smi:local/dbe9eb2f-468e-4bd8-a2bb-f91801eb01fe',
#      'pick_id': 'smi:local/997b83ef-6b5f-4a1d-aac9-b01ea61653a9',
#      'phase': 'Pn',
#      'azimuth': 213.35228,
#      'time_residual': 0.7703855,
#      'horizontal_slowness_residual': 0.6317712,
#      'backazimuth_residual': 11.887718,
#      'comments': [{'text': 'ARID=7926915',
#        'resource_id': 'smi:local/d65c9e48-28a4-4e82-ba9c-8db06a0dd207'}]},
#     {'resource_id': 'smi:local/08f92bca-4e05-4413-9cbb-c25fff95d990',
#      'pick_id': 'smi:local/f6d83d45-0fb1-4dcf-b0c7-782d6725cd08',
#      'phase': 'Pn',
#      'azimuth': 57.844186,
#      'time_residual': -0.82664381,
#      'horizontal_slowness_residual': -999.0,
#      'backazimuth_residual': -999.0,
#      'comments': [{'text': 'ARID=33161',
#        'resource_id': 'smi:local/de4f411e-80ac-4e51-85c4-47533e66dc3b'}]},
#     {'resource_id': 'smi:local/f9c6592f-add4-49ae-b615-d2410915c885',
#      'pick_id': 'smi:local/24d2c240-811a-4bb9-b2dd-d8e3a27177a2',
#      'phase': 'Pn',
#      'azimuth': 255.69709,
#      'time_residual': -1.2606302,
#      'horizontal_slowness_residual': -999.0,
#      'backazimuth_residual': -999.0,
#      'comments': [{'text': 'ARID=33162',
#        'resource_id': 'smi:local/abe98e90-d748-487c-b427-a6691c829d71'}]},
#     {'resource_id': 'smi:local/6511a654-b025-45c6-b8b2-c199d60b8e41',
#      'pick_id': 'smi:local/31158046-f976-4662-bdca-da2945b6c51b',
#      'phase': 'Pn',
#      'azimuth': 198.23989,
#      'time_residual': -1.0900498,
#      'horizontal_slowness_residual': -999.0,
#      'backazimuth_residual': -999.0,
#      'comments': [{'text': 'ARID=33163',
#        'resource_id': 'smi:local/849d0b4c-c15f-4da2-830d-4c283d2689bb'}]},
#     {'resource_id': 'smi:local/a8de4d06-dfea-4628-831f-9c4bae159103',
#      'pick_id': 'smi:local/4d7b0640-cb01-410d-ac46-c1562b4453b8',
#      'phase': 'Pn',
#      'azimuth': 351.75126,
#      'time_residual': 1.5295215,
#      'horizontal_slowness_residual': -0.53905072,
#      'backazimuth_residual': -7.6966574,
#      'comments': [{'text': 'ARID=33164',
#        'resource_id': 'smi:local/ee7fc7e8-ae50-4f94-86cd-a3a9f017cd93'}]},
#     {'resource_id': 'smi:local/d81f6a3a-40c3-4844-a691-ba3598aa1ce9',
#      'pick_id': 'smi:local/3ea2b62a-c018-45a4-b263-3692bc880c7a',
#      'phase': 'Pn',
#      'azimuth': 349.47565,
#      'time_residual': -0.47281124,
#      'horizontal_slowness_residual': -0.13517712,
#      'backazimuth_residual': -0.18564968,
#      'comments': [{'text': 'ARID=7926926',
#        'resource_id': 'smi:local/448316ac-f634-46af-869b-45dd2caebdd5'}]},
#     {'resource_id': 'smi:local/0b8ad2dd-e973-413e-aa54-1c6e57f412a8',
#      'pick_id': 'smi:local/cb2d449b-61a3-43df-b511-294e6e4a3053',
#      'phase': 'Pn',
#      'azimuth': 307.88349,
#      'time_residual': 0.58034859,
#      'horizontal_slowness_residual': -2.7868963,
#      'backazimuth_residual': 3.1765122,
#      'comments': [{'text': 'ARID=7926930',
#        'resource_id': 'smi:local/4dc7aa96-9caf-42d3-a679-7f00bd0f6866'}]},
#     {'resource_id': 'smi:local/ddc8d70b-d103-4467-8bce-d7f4e2612fce',
#      'pick_id': 'smi:local/1c77d508-65d6-4e9a-a459-67689b83f5d1',
#      'phase': 'Pn',
#      'azimuth': 334.67887,
#      'time_residual': 0.54418895,
#      'horizontal_slowness_residual': -1.4939474,
#      'backazimuth_residual': 10.091125,
#      'comments': [{'text': 'ARID=7926938',
#        'resource_id': 'smi:local/86394548-37bb-4555-9edd-19f34c1f9018'}]},
#     {'resource_id': 'smi:local/86b17d5a-d4f9-4b59-9e6c-a9e53fecd997',
#      'pick_id': 'smi:local/246a1f53-3c4a-468b-bfc5-7ad74cbfbf97',
#      'phase': 'Sn',
#      'azimuth': 307.88349,
#      'time_residual': -2.5610678,
#      'horizontal_slowness_residual': -3.6694274,
#      'backazimuth_residual': -9.3934878,
#      'comments': [{'text': 'ARID=7926940',
#        'resource_id': 'smi:local/a1e4c32d-22c9-4f51-9142-8c1bff22c14f'}]},
#     {'resource_id': 'smi:local/5ee6556d-0017-4a56-b32e-f11724443f22',
#      'pick_id': 'smi:local/880fb205-aa52-4dba-8fbe-8ddfce1cc9e6',
#      'phase': 'Pn',
#      'azimuth': 351.98777,
#      'time_residual': 0.52817194,
#      'horizontal_slowness_residual': -3.3711454,
#      'backazimuth_residual': -13.587769,
#      'comments': [{'text': 'ARID=10091184',
#        'resource_id': 'smi:local/d53836be-3f34-44be-8737-62fcd646e580'}]}]}],
#  'magnitudes': [{'resource_id': 'smi:local/97e35d69-c877-4ff4-81e6-491e77e4b0ac',
#    'mag': 3.347,
#    'magnitude_type': 'Mb',
#    'origin_id': 'smi:local/d83e4b2e-d748-4156-8ee2-ecff810503aa'},
#   {'resource_id': 'smi:local/1ac8714f-6cdd-40b2-a77f-773da79adcf2',
#    'mag': 2.11,
#    'magnitude_type': 'Ml',
#    'origin_id': 'smi:local/d83e4b2e-d748-4156-8ee2-ecff810503aa'}],
#  'az_to_arces': 108.86004005283273,
#  'baz_to_arces': 307.91703691136996,
#  'dist_to_arces': 814.2267548144331,
#  'est_arrivaltime_arces': '2012-05-25 12:55:11.014000',
#  'magnitude_dist_ratio': 0.004110648514323016,
#  'magnitude_sqrtdist_ratio': 0.11729595294569686,
#  'analyst_pick_time': None,
#  'trace_stats': {'starttime': '2012-05-25T12:54:11.025000Z',
#   'sampling_rate': 40.0,
#   'station': 'ARCES beam',
#   'channels': ['P-beam, vertical', 'S-beam, transverse', 'S-beam, radial']}}
