# %%
import numpy as np
import os
import sys
import pandas as pd

import sklearn as sk
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

import pylab as pl
import h5py

import tensorflow as tf

os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
os.environ['CUDA_VISIBLE_DEVICES']="0" 

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)


from sklearn.metrics import confusion_matrix

base_dir = '/media/tord/T7/Thesis_ssd/MasterThesis3.0'
os.chdir(base_dir)

from Classes.DataProcessing.LoadData import LoadData
from Classes.DataProcessing.HelperFunctions import HelperFunctions
from Classes.DataProcessing.DataHandler import DataHandler
from Classes.DataProcessing.TimeAugmentor import TimeAugmentor
from Classes.DataProcessing.NoiseAugmentor import NoiseAugmentor
from Classes.DataProcessing.RamLoader import RamLoader
from Classes.DataProcessing.RamGenerator import RamGenerator
from Classes.Modeling.InceptionTimeModel import InceptionTimeModel
from Classes.Modeling.NarrowSearchIncepTime import NarrowSearchIncepTime
from Classes.Modeling.CustomCallback import CustomCallback
from Classes.Modeling.ResultFitter import ResultFitter
from Classes.Scaling.ScalerFitter import ScalerFitter
from Classes.Scaling.MinMaxScalerFitter import MinMaxScalerFitter
from Classes.Scaling.StandardScalerFitter import StandardScalerFitter
from Classes.Modeling.GridSearchResultProcessor import GridSearchResultProcessor
import json
#from Classes import Tf_shutup
#Tf_shutup.Tf_shutup()

from livelossplot import PlotLossesKeras



from matplotlib.colors import ListedColormap

plt.rcParams["figure.figsize"]= (15,15)
helper = HelperFunctions()

import sys
ISCOLAB = 'google.colab' in sys.modules

import random
import pprint
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
load_args = {
    'earth_explo_only' : False,
    'noise_earth_only' : False,
    'noise_not_noise' : True,
    'downsample' : True,
    'upsample' : True,
    'frac_diff' : 1,
    'seed' : 1,
    'subsample_size' : 0.4,
    'balance_non_train_set' : True,
    'use_true_test_set' : False,
    'even_balance' : True
}
loadData = LoadData(**load_args)
full_ds, train_ds, val_ds, test_ds = loadData.get_datasets()
noise_ds = loadData.noise_ds
handler = DataHandler(loadData)

if load_args['earth_explo_only']:
    full_and_noise_ds = np.concatenate((full_ds, noise_ds))
    timeAug = TimeAugmentor(handler, full_and_noise_ds, seed = load_args['seed'])
else:
    timeAug = TimeAugmentor(handler, full_ds, seed = load_args['seed'])
# Out:
# 2 3
# {'noise': 105999, 'earthquake': 105999, 'explosion': 102808}

# %%
# Printing data stats:
print(len(train_ds), len(val_ds), len(test_ds))
print("All data:")
classes, counts = handler.get_class_distribution_from_ds(full_ds)
print("Train set:")
classes, counts = handler.get_class_distribution_from_ds(train_ds)
print("Validation set:")
classes, counts = handler.get_class_distribution_from_ds(val_ds)
print("Test set:")
classes, counts = handler.get_class_distribution_from_ds(test_ds)
print("Nr noise samples " + str(len(loadData.noise_ds)))
# Out:
# 63120 12624 8416
# All data:
# Total: 84160, earthquake: 21058, explosion: 20599, noise: 42503
# Train set:
# Total: 63120, earthquake: 15792, explosion: 15479, noise: 31849
# Validation set:
# Total: 12624, earthquake: 3197, explosion: 3082, noise: 6345
# Test set:
# Total: 8416, earthquake: 2069, explosion: 2038, noise: 4309
# Nr noise samples 31849

# %%
main_grid = {
    "batch_size" : [512],
    "epochs" : [100],
    "learning_rate" : [0.01],
    "optimizer" : ["rmsprop"],
    "use_residuals" : [True],
    "use_bottleneck" : [False],
    "nr_modules" : [1],
    "kernel_size" : [40],
    "bottleneck_size" : [26],
    "num_filters" : [32],
    "shortcut_activation" : ["tanh"],
    "module_activation" : ["sigmoid"],
    "module_output_activation" : ["tanh"],
    "output_activation": ["sigmoid"],
    "reg_module" : [False],
    "reg_shortcut" : [True],
    "l1_r" : [0.01],
    "l2_r" : [0.01]
    }

hyper_grid = {
    "batch_size" : [64, 128, 512, 768, 1024],
    "epochs" : [100],
    "learning_rate" : [0.1,0.001, 0.0005],
    "optimizer" : ["rmsprop", "sgd"]
    }
model_grid = {
    "use_residuals" : [False, True],
    "use_bottleneck" : [True, False],
    "nr_modules" : [3, 6, 9, 14],
    "kernel_size" : [10, 30, 50],
    "bottleneck_size" : [22],
    "num_filters" : [28, 30, 34, 36, 40, 44, 48],
    "shortcut_activation" : ["relu", "sigmoid"],
    "module_activation" : ["linear", "relu", "softmax", "tanh"],
    "module_output_activation" : ["relu", "linear", "sigmoid", "softmax"],
    "output_activation": ["sigmoid"],
    "reg_module" : [True, True],
    "reg_shortcut" : [False, False],
    "l1_r" : [0.1, 0.001, 0.0001, 0.0],
    "l2_r" : [0.1, 0.001, 0.0001, 0.0]
}


num_channels = 3

use_time_augmentor = True
use_scaler = True
use_noise_augmentor = True
detrend = False
use_minmax = False
use_highpass = False
highpass_freq = 0.1

use_tensorboard = True
use_liveplots = False
use_custom_callback = False
use_early_stopping = True
start_from_scratch = False
use_reduced_lr = True

narrowSearch = NarrowSearchIncepTime(loadData, train_ds, val_ds, detrend, 
                               use_scaler,  use_time_augmentor, use_noise_augmentor, 
                               use_minmax,use_highpass, main_grid, hyper_grid, model_grid, 
                               use_tensorboard = use_tensorboard, use_liveplots = use_liveplots, 
                               use_custom_callback = use_custom_callback, 
                               use_early_stopping = use_early_stopping, highpass_freq = highpass_freq,
                               start_from_scratch = start_from_scratch, num_channels = num_channels)
# Out:
# Note that highpass and detrend have not been implemented yet in this class.

# %%
def clear_tensorboard_dir():
    import os
    import shutil
    path = f"{base_dir}/Tensorboard_dir/fit"
    files = os.listdir(path)
    print(files)
    for f in files:
        shutil.rmtree(os.path.join(path,f))
if use_tensorboard:
    clear_tensorboard_dir()
    #%tensorboard --logdir tensorboard_dir/fit
# Out:
# []

# %%
results_df, min_loss, max_accuracy, max_precision, max_recall = narrowSearch.fit()
# Out:
# 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 50,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 28,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 30,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 34,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 36,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 40,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 44,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 48,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.1,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.001,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.0001,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.0,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.1,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.001,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.0001,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.0,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': True,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 3,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 6,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 9,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 14,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'relu',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'sigmoid',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 64,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 128,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 768,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 1024,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'sgd',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': False,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': False,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'relu',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'linear',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'sigmoid',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'softmax',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': False},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'simoid',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'linear',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'relu',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'softmax',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True},
#  {'batch_size': 512,
#   'bottleneck_size': 26,
#   'epochs': 100,
#   'kernel_size': 40,
#   'l1_r': 0.01,
#   'l2_r': 0.01,
#   'learning_rate': 0.01,
#   'module_activation': 'tanh',
#   'module_output_activation': 'tanh',
#   'nr_modules': 1,
#   'num_filters': 32,
#   'optimizer': 'rmsprop',
#   'output_activation': 'sigmoid',
#   'reg_module': False,
#   'reg_shortcut': True,
#   'shortcut_activation': 'tanh',
#   'use_bottleneck': False,
#   'use_residuals': True}]
# Starting loading to RAM
# Completed loading to RAM
# Starting loading to RAM
# Completed loading to RAM
# Model nr 1 of 50
# [{'model_nr_type': 'InceptionTime', 'index': 0}, {'batch_size': 512, 'epochs': 100, 'learning_rate': 0.1, 'optimizer': 'rmsprop'}, {'bottleneck_size': 26, 'kernel_size': 40, 'l1_r': 0.01, 'l2_r': 0.01, 'module_activation': 'simoid', 'module_output_activation': 'tanh', 'nr_modules': 1, 'num_filters': 32, 'output_activation': 'sigmoid', 'reg_module': False, 'reg_shortcut': True, 'shortcut_activation': 'tanh', 'use_bottleneck': False, 'use_residuals': True}]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-8-479d9934dff2> in <module>
# ----> 1 results_df, min_loss, max_accuracy, max_precision, max_recall = narrowSearch.fit()
#
# /media/tord/T7/Thesis_ssd/MasterThesis3.0/Classes/Modeling/NarrowSearchIncepTime.py in fit(self)
#     144             # Build model using args generated above
#     145             inceptionTime = InceptionTimeModel(**model_args)
# --> 146             model = inceptionTime.build_model(input_shape, self.num_classes)
#     147
#     148             # Initializing generators:
#
# /media/tord/T7/Thesis_ssd/MasterThesis3.0/Classes/Modeling/InceptionTimeModel.py in build_model(self, input_shape, num_classes, num_modules)
#      59         for d in range(self.nr_modules):
#      60
# ---> 61             x = self._inception_module(x, self.reg_module, activation = self.module_activation)
#      62
#      63             if self.use_residuals and d % 3 == 2:
#
# /media/tord/T7/Thesis_ssd/MasterThesis3.0/Classes/Modeling/InceptionTimeModel.py in _inception_module(self, input_tensor, reg_module, stride, activation)
#      88         for i in range(len(kernel_size_s)):
#      89             if not reg_module:
# ---> 90                 conv_list.append(tf.keras.layers.Conv1D(filters=self.num_filters, kernel_size=kernel_size_s[i],
#      91                                                     strides=stride, padding='same', activation=activation, use_bias=False)(
#      92                     input_inception))
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/layers/convolutional.py in __init__(self, filters, kernel_size, strides, padding, data_format, dilation_rate, groups, activation, use_bias, kernel_initializer, bias_initializer, kernel_regularizer, bias_regularizer, activity_regularizer, kernel_constraint, bias_constraint, **kwargs)
#     501         dilation_rate=dilation_rate,
#     502         groups=groups,
# --> 503         activation=activations.get(activation),
#     504         use_bias=use_bias,
#     505         kernel_initializer=initializers.get(kernel_initializer),
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/activations.py in get(identifier)
#     580   if isinstance(identifier, six.string_types):
#     581     identifier = str(identifier)
# --> 582     return deserialize(identifier)
#     583   elif isinstance(identifier, dict):
#     584     return deserialize(identifier)
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     204     """Call target, and fall back on dispatchers if there is a TypeError."""
#     205     try:
# --> 206       return target(*args, **kwargs)
#     207     except (TypeError, ValueError):
#     208       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/activations.py in deserialize(name, custom_objects)
#     539       globs[key] = val
#     540
# --> 541   return deserialize_keras_object(
#     542       name,
#     543       module_objects=globs,
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/utils/generic_utils.py in deserialize_keras_object(identifier, module_objects, custom_objects, printable_module_name)
#     380       obj = module_objects.get(object_name)
#     381       if obj is None:
# --> 382         raise ValueError(
#     383             'Unknown {}: {}. Please ensure this object is '
#     384             'passed to the `custom_objects` argument. See '
#
# ValueError: Unknown activation function: simoid. Please ensure this object is passed to the `custom_objects` argument. See https://www.tensorflow.org/guide/keras/save_and_serialize#registering_the_custom_object for details.
