# %%
import numpy as np
import os
import sys
import pandas as pd
import seaborn as sns

import pylab as pl
import h5py

import tensorflow as tf
from tensorflow.keras import mixed_precision

os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
os.environ['CUDA_VISIBLE_DEVICES']="0" 

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)


from sklearn.metrics import confusion_matrix

base_dir = '/media/tord/T7/Thesis_ssd/MasterThesis3'
os.chdir(base_dir)
from Classes.DataProcessing.LoadData import LoadData
from Classes.DataProcessing.HelperFunctions import HelperFunctions
from Classes.DataProcessing.DataHandler import DataHandler
from Classes.Modeling.DynamicModels import DynamicModels
from Classes.Modeling.TrainSingleModelRam import TrainSingleModelRam
from Classes.DataProcessing.RamLoader import RamLoader
import json

import gc

import datetime
import re
from livelossplot import PlotLossesKeras
from GlobalUtils import GlobalUtils
from Classes.Modeling.CustomCallback import CustomCallback
from tensorflow.keras.callbacks import EarlyStopping
utils = GlobalUtils()

from tensorflow.keras.utils import GeneratorEnqueuer






import sys


helper = HelperFunctions()

tf.config.optimizer.set_jit(True)
mixed_precision.set_global_policy('mixed_float16')
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# WARNING:tensorflow:From /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/tensorflow/python/util/module_wrapper.py:49: The name tf.keras.layers.CuDNNLSTM is deprecated. Please use tf.compat.v1.keras.layers.CuDNNLSTM instead.
#
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: GeForce RTX 3090, compute capability 8.6

# %%
load_args = {
    'earth_explo_only' : False,
    'noise_earth_only' : False,
    'noise_not_noise' : True,
    'downsample' : True,
    'upsample' : True,
    'frac_diff' : 1,
    'seed' : 1,
    'subsample_size' : 0.25,
    'balance_non_train_set' : False,
    'use_true_test_set' : False,
    'even_balance' : True
}
loadData = LoadData(**load_args)
train_ds, val_ds, test_ds = loadData.get_datasets()
noise_ds = loadData.noise_ds
handler = DataHandler(loadData)
# Out:
# 2 3
# Balancing due to disguised labels.
# This functions barely works, and is a piece of shit that should not be trusted. Only works because noise has id: 0
# {'noise': 84799, 'earthquake': 84799, 'explosion': 82246}
# Mapping train redundancy: : [--------------------------------------->] 100 %
#
# Mapping validation redundancy: : [--------------------------------------->] 100 %
#
# Mapping test redundancy: : [--------------------------------------->] 100 %
#
#
#
# Loaded noise non-noise dataset.
# Evenly balanced among classes in the train set.
# Distribution (Label: (counts, proportion)) of
# Train ds:
# earthquake: (10631, 0.2526)  |  explosion: (10106, 0.2402)  |  noise: (21343, 0.5072)
# Val ds:
# earthquake: (242, 0.0371)  |  explosion: (3125, 0.4788)  |  noise: (3160, 0.4841)
# Test ds:
# earthquake: (184, 0.0423)  |  explosion: (2062, 0.4739)  |  noise: (2105, 0.4838)

# %%
model_type = "LSTM"
is_lstm = True
num_channels = 3    

use_time_augmentor = True
scaler_name = "standard"
use_noise_augmentor = True
filter_name = None
band_min = 2.0
band_max = 4.0
highpass_freq = 0.075

shutdown = False

num_classes = len(list(set(loadData.label_dict.values())))



ramLoader = RamLoader(loadData, 
                      handler, 
                      use_time_augmentor = use_time_augmentor, 
                      use_noise_augmentor = use_noise_augmentor, 
                      scaler_name = scaler_name,
                      filter_name = filter_name, 
                      band_min = band_min,
                      band_max = band_max,
                      highpass_freq = highpass_freq, 
                      load_test_set = False, 
                      meier_load = False)

x_train, y_train, x_val, y_val, noiseAug = ramLoader.load_to_ram()
# Out:
# Fitting train time augmentor: [--------------------------------------->] 100 %
#
# Fit process completed after 186.25785756111145 seconds. Total datapoints fitted: 42080.
# Average time per datapoint: 0.0044262798850074015
#
#
# Fitting validation time augmentor: [--------------------------------------->] 100 %
#
# Fit process completed after 59.438077449798584 seconds. Total datapoints fitted: 6527.
# Average time per datapoint: 0.009106492638240935
#
#
# Stage one loading training set, timeAug: [--------------------------------------->] 100 %
#
# Stage one loading validation set, timeAug: [--------------------------------------->] 100 %
#
# Fit process of normalizer skipped as unecessary
#
#
# Stage two loading training set, labels and normalize scaler: [--------------------------------------->] 100 %
#
# Stage two loading validation set, labels and normalize scaler: [--------------------------------------->] 100 %
#
# (array([    4,     5,     6, ..., 42071, 42073, 42075]), array([0, 0, 0, ..., 0, 0, 0]))
# Fitting noise augmentor: [--------------------------------------->] 100 %
#
#
#
# Time elapsed to completion of load_to_ram_noise_not_noise: 0:05:30.792901

# %%
use_tensorboard = True
use_liveplots = False
use_custom_callback = True
use_early_stopping = True
start_from_scratch = False
use_reduced_lr = True
log_data = True
model_type = "MLSTM_FCN"

beta = 2

def clear_tensorboard_dir():
        import os
        import shutil
        path = f"{base_dir}/Tensorboard_dir/fit"
        files = os.listdir(path)
        print(files)
        for f in files:
            shutil.rmtree(os.path.join(path,f))
if use_tensorboard:
    clear_tensorboard_dir()


modelTrain = TrainSingleModelRam(noiseAug, helper,
                              loadData, model_type, num_channels, use_tensorboard, use_liveplots,
                              use_custom_callback, use_early_stopping, use_reduced_lr, ramLoader,
                              log_data = log_data, 
                              start_from_scratch = start_from_scratch, beta = beta)

params = {
        "batch_size" : 128,
        "epochs" : 50,
        "learning_rate" : 0.01,
        "optimizer" : "sgd",
        "units" : 1,
        "output_layer_activation" : "sigmoid"
    }
model = modelTrain.run(x_train, y_train, x_val, y_val, None, None, 16, 15, evaluate_train = True, evaluate_val = True, evaluate_test = False, meier_mode = False, **params)
# Out:
# []
# Trying to create result file
# Made result file:  results_MLSTM_FCN_noiseNotNoise_timeAug_normalize_noiseAug_earlyS_unbalanced_valtest_subsample-0.25_numChannels-3.csv
# [   {'model_type': 'MLSTM_FCN'},
#     {   'batch_size': 128,
#         'epochs': 50,
#         'learning_rate': 0.001,
#         'meier_load': False,
#         'optimizer': 'adam',
#         'output_layer_activation': 'sigmoid',
#         'units': 8}]
# Saving file. 45 rows.
# results_MLSTM_FCN_noiseNotNoise_timeAug_normalize_noiseAug_earlyS_unbalanced_valtest_subsample-0.25_numChannels-3.csv saved to path:   /media/tord/T7/Thesis_ssd/MasterThesis3/GridSearchResults/2_classes
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 6000, 3)]    0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 6000, 128)    3200        input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 6000, 128)    512         conv1d[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 6000, 128)    0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 128)          0           activation[0][0]
# __________________________________________________________________________________________________
# reshape (Reshape)               (None, 1, 128)       0           global_average_pooling1d[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1, 8)         1024        reshape[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1, 128)       1024        dense[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 6000, 128)    0           activation[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 6000, 256)    164096      multiply[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 6000, 256)    1024        conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 6000, 256)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 256)          0           activation_1[0][0]
# __________________________________________________________________________________________________
# reshape_1 (Reshape)             (None, 1, 256)       0           global_average_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1, 16)        4096        reshape_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1, 256)       4096        dense_2[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 6000, 256)    0           activation_1[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# permute (Permute)               (None, 3, 6000)      0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 6000, 128)    98432       multiply_1[0][0]
# __________________________________________________________________________________________________
# masking (Masking)               (None, 3, 6000)      0           permute[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 6000, 128)    512         conv1d_2[0][0]
# __________________________________________________________________________________________________
# lstm_block_out (LSTM)           (None, 8)            192288      masking[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 6000, 128)    0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 8)            0           lstm_block_out[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_2 (Glo (None, 128)          0           activation_2[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 136)          0           dropout[0][0]
#                                                                  global_average_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            137         concatenate[0][0]
# ==================================================================================================
# Total params: 470,441
# Trainable params: 469,417
# Non-trainable params: 1,024
# __________________________________________________________________________________________________
# ----------EarlyStop monitoring val_binary_accuracy------------
# ----------Reduce LR monitoring val_binary_accuracy------------
# Utilizes 6400/6527 validation points
# Utilizes 41984/42080 training points
# -------------------------------------------------------------------
# Epoch 1/50
# 328/328 [==============================] - 52s 120ms/step - loss: 0.2978 - binary_accuracy: 0.8733 - precision: 0.9100 - recall: 0.8321 - val_loss: 1.0937 - val_binary_accuracy: 0.5156 - val_precision: 0.5156 - val_recall: 1.0000
# - val_f2: 0.8418
# Epoch 2/50
# 328/328 [==============================] - 39s 118ms/step - loss: 0.2271 - binary_accuracy: 0.9134 - precision: 0.9212 - recall: 0.9039 - val_loss: 0.6911 - val_binary_accuracy: 0.5569 - val_precision: 0.5378 - val_recall: 1.0000
# - val_f2: 0.8533
# Epoch 3/50
# 328/328 [==============================] - 39s 118ms/step - loss: 0.2034 - binary_accuracy: 0.9233 - precision: 0.9301 - recall: 0.9122 - val_loss: 0.4135 - val_binary_accuracy: 0.8719 - val_precision: 0.9628 - val_recall: 0.7807
# - val_f2: 0.8119
# Epoch 4/50
# 328/328 [==============================] - 39s 118ms/step - loss: 0.1856 - binary_accuracy: 0.9280 - precision: 0.9355 - recall: 0.9181 - val_loss: 0.3838 - val_binary_accuracy: 0.8836 - val_precision: 0.9691 - val_recall: 0.7986
# - val_f2: 0.8302
# Epoch 5/50
# 328/328 [==============================] - 37s 114ms/step - loss: 0.1757 - binary_accuracy: 0.9322 - precision: 0.9380 - recall: 0.9247 - val_loss: 2.3485 - val_binary_accuracy: 0.6708 - val_precision: 0.9847 - val_recall: 0.3664
# - val_f2: 0.4203
# Epoch 6/50
# 328/328 [==============================] - 37s 113ms/step - loss: 0.1719 - binary_accuracy: 0.9349 - precision: 0.9418 - recall: 0.9249 - val_loss: 1.2903 - val_binary_accuracy: 0.7525 - val_precision: 0.9879 - val_recall: 0.5253
# - val_f2: 0.5803
# Epoch 7/50
# 328/328 [==============================] - 37s 111ms/step - loss: 0.1608 - binary_accuracy: 0.9403 - precision: 0.9481 - recall: 0.9301 - val_loss: 1.6667 - val_binary_accuracy: 0.5294 - val_precision: 0.5228 - val_recall: 0.9993
# - val_f2: 0.8452
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.000500000023749.
# Epoch 8/50
# 328/328 [==============================] - 37s 114ms/step - loss: 0.1523 - binary_accuracy: 0.9440 - precision: 0.9488 - recall: 0.9361 - val_loss: 1.8917 - val_binary_accuracy: 0.7039 - val_precision: 0.9902 - val_recall: 0.4293
# - val_f2: 0.4855
# Epoch 9/50
# 328/328 [==============================] - 37s 112ms/step - loss: 0.1443 - binary_accuracy: 0.9463 - precision: 0.9517 - recall: 0.9385 - val_loss: 0.2102 - val_binary_accuracy: 0.9309 - val_precision: 0.9053 - val_recall: 0.9665
# - val_f2: 0.9536
# Epoch 10/50
# 328/328 [==============================] - 37s 114ms/step - loss: 0.1428 - binary_accuracy: 0.9455 - precision: 0.9521 - recall: 0.9380 - val_loss: 0.2103 - val_binary_accuracy: 0.9222 - val_precision: 0.9587 - val_recall: 0.8866
# - val_f2: 0.8997
# Epoch 11/50
# 328/328 [==============================] - 38s 115ms/step - loss: 0.1388 - binary_accuracy: 0.9501 - precision: 0.9562 - recall: 0.9426 - val_loss: 0.8283 - val_binary_accuracy: 0.6561 - val_precision: 0.6013 - val_recall: 0.9927
# - val_f2: 0.8785
# Epoch 12/50
# 328/328 [==============================] - 37s 113ms/step - loss: 0.1370 - binary_accuracy: 0.9498 - precision: 0.9569 - recall: 0.9409 - val_loss: 1.1120 - val_binary_accuracy: 0.7492 - val_precision: 0.9830 - val_recall: 0.5219
# - val_f2: 0.5756
#
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 0.000250000011874.
# Epoch 13/50
# 328/328 [==============================] - 39s 118ms/step - loss: 0.1287 - binary_accuracy: 0.9535 - precision: 0.9602 - recall: 0.9443 - val_loss: 0.2212 - val_binary_accuracy: 0.9161 - val_precision: 0.8711 - val_recall: 0.9830
# - val_f2: 0.9586
# Epoch 14/50
# 328/328 [==============================] - 39s 118ms/step - loss: 0.1257 - binary_accuracy: 0.9534 - precision: 0.9602 - recall: 0.9453 - val_loss: 0.1521 - val_binary_accuracy: 0.9484 - val_precision: 0.9356 - val_recall: 0.9667
# - val_f2: 0.961
# Epoch 15/50
# 328/328 [==============================] - 39s 118ms/step - loss: 0.1231 - binary_accuracy: 0.9541 - precision: 0.9595 - recall: 0.9468 - val_loss: 0.1628 - val_binary_accuracy: 0.9453 - val_precision: 0.9536 - val_recall: 0.9393
# - val_f2: 0.9421
# Epoch 16/50
# 328/328 [==============================] - 39s 118ms/step - loss: 0.1254 - binary_accuracy: 0.9544 - precision: 0.9604 - recall: 0.9468 - val_loss: 0.2708 - val_binary_accuracy: 0.9172 - val_precision: 0.9736 - val_recall: 0.8620
# - val_f2: 0.8828
# Epoch 17/50
# 328/328 [==============================] - 39s 118ms/step - loss: 0.1205 - binary_accuracy: 0.9559 - precision: 0.9618 - recall: 0.9490 - val_loss: 0.2647 - val_binary_accuracy: 0.9031 - val_precision: 0.9772 - val_recall: 0.8306
# - val_f2: 0.8584
#
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 0.000125000005937.
# Epoch 18/50
# 328/328 [==============================] - 39s 118ms/step - loss: 0.1138 - binary_accuracy: 0.9598 - precision: 0.9664 - recall: 0.9514 - val_loss: 0.1304 - val_binary_accuracy: 0.9561 - val_precision: 0.9498 - val_recall: 0.9659
# - val_f2: 0.9617
# Epoch 19/50
# 328/328 [==============================] - 39s 118ms/step - loss: 0.1152 - binary_accuracy: 0.9581 - precision: 0.9625 - recall: 0.9524 - val_loss: 0.1693 - val_binary_accuracy: 0.9411 - val_precision: 0.9102 - val_recall: 0.9833
# - val_f2: 0.9674
# Epoch 20/50
# 328/328 [==============================] - 39s 118ms/step - loss: 0.1146 - binary_accuracy: 0.9590 - precision: 0.9643 - recall: 0.9518 - val_loss: 0.1400 - val_binary_accuracy: 0.9523 - val_precision: 0.9372 - val_recall: 0.9727
# - val_f2: 0.9662
# Epoch 21/50
# 328/328 [==============================] - 37s 112ms/step - loss: 0.1109 - binary_accuracy: 0.9602 - precision: 0.9643 - recall: 0.9547 - val_loss: 0.4953 - val_binary_accuracy: 0.7997 - val_precision: 0.7225 - val_recall: 0.9935
# - val_f2: 0.9239
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 6.25000029686e-05.
# Epoch 22/50
# 328/328 [==============================] - 36s 110ms/step - loss: 0.1130 - binary_accuracy: 0.9594 - precision: 0.9617 - recall: 0.9553 - val_loss: 0.2179 - val_binary_accuracy: 0.9258 - val_precision: 0.9784 - val_recall: 0.8748
# - val_f2: 0.8933
# Epoch 23/50
# 328/328 [==============================] - 36s 109ms/step - loss: 0.1090 - binary_accuracy: 0.9607 - precision: 0.9647 - recall: 0.9551 - val_loss: 0.1493 - val_binary_accuracy: 0.9484 - val_precision: 0.9684 - val_recall: 0.9300
# - val_f2: 0.9379
# Epoch 24/50
# 328/328 [==============================] - 36s 109ms/step - loss: 0.1081 - binary_accuracy: 0.9631 - precision: 0.9674 - recall: 0.9573 - val_loss: 0.1533 - val_binary_accuracy: 0.9464 - val_precision: 0.9696 - val_recall: 0.9247
# - val_f2: 0.9344
#
# Epoch 00024: ReduceLROnPlateau reducing learning rate to 5e-05.
# Epoch 25/50
# 328/328 [==============================] - 36s 109ms/step - loss: 0.1071 - binary_accuracy: 0.9623 - precision: 0.9677 - recall: 0.9554 - val_loss: 0.1492 - val_binary_accuracy: 0.9509 - val_precision: 0.9324 - val_recall: 0.9757
# - val_f2: 0.9666
# Restoring model weights from the end of the best epoch.
# Epoch 00025: early stopping
# 50/50 [==============================] - 3s 51ms/step - loss: 0.1304 - binary_accuracy: 0.9561 - precision: 0.9497 - recall: 0.9659
# 2931 169 116 3184
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[2931,  169],
#        [ 116, 3184]], dtype=int32)>
#               precision    recall  f1-score   support
#
#        noise       0.96      0.95      0.95      3100
#    not_noise       0.95      0.96      0.96      3300
#
#     accuracy                           0.96      6400
#    macro avg       0.96      0.96      0.96      6400
# weighted avg       0.96      0.96      0.96      6400
#
# Evaluating train:
# 328/328 [==============================] - 17s 51ms/step - loss: 0.1006 - binary_accuracy: 0.9633 - precision: 0.9756 - recall: 0.9492
# 20802 483 1045 19654
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[20802,   483],
#        [ 1045, 19654]], dtype=int32)>
#               precision    recall  f1-score   support
#
#        noise       0.95      0.98      0.96     21285
#    not_noise       0.98      0.95      0.96     20699
#
#     accuracy                           0.96     41984
#    macro avg       0.96      0.96      0.96     41984
# weighted avg       0.96      0.96      0.96     41984
#
# Saving file. 45 rows.
# results_MLSTM_FCN_noiseNotNoise_timeAug_normalize_noiseAug_earlyS_unbalanced_valtest_subsample-0.25_numChannels-3.csv saved to path:   /media/tord/T7/Thesis_ssd/MasterThesis3/GridSearchResults/2_classes
# meier_load                                       False
# units                                                8
# output_layer_activation                        sigmoid
# optimizer                                         adam
# learning_rate                                    0.001
# epochs                                              50
# batch_size                                         128
# train_loss                                     0.10064
# train_accuracy                                0.963605
# train_precision                               0.976014
# train_recall                                  0.949514
# train_f2                                      0.954699
# val_loss                                      0.130367
# val_accuracy                                  0.955469
# val_precision                                 0.949597
# val_recall                                    0.964848
# val_f2                                        0.961759
# confusion_matrix           [[2931  169]\n [ 116 3184]]
# Name: 44, dtype: object
# Unsaved train eval:
# 20793 492 1042 19657
# ['noise', 'not_noise']
# 3N
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[20793,   492],
#        [ 1042, 19657]], dtype=int32)>
#               precision    recall  f1-score   support
#
#        noise       0.95      0.98      0.96     21285
#    not_noise       0.98      0.95      0.96     20699
#
#     accuracy                           0.96     41984
#    macro avg       0.96      0.96      0.96     41984
# weighted avg       0.96      0.96      0.96     41984
#
# Unsaved val eval:
# 2930 170 114 3186
# ['noise', 'not_noise']
# 3N
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[2930,  170],
#        [ 114, 3186]], dtype=int32)>
#               precision    recall  f1-score   support
#
#        noise       0.96      0.95      0.95      3100
#    not_noise       0.95      0.97      0.96      3300
#
#     accuracy                           0.96      6400
#    macro avg       0.96      0.96      0.96      6400
# weighted avg       0.96      0.96      0.96      6400

# %%
conf, report, accuracy, precision, recall, fscore = helper.evaluate_generator(model, x_val, y_val, params["batch_size"],
                                                                             loadData.label_dict, num_channels, noiseAug,
                                                                             scaler_name, 2, plot_conf_matrix = True, plot_p_r_curve = True, beta = beta)
# Out:
# 2930 170 111 3189
# ['noise', 'not_noise']
# 3N
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[2930,  170],
#        [ 111, 3189]], dtype=int32)>
#               precision    recall  f1-score   support
#
#        noise       0.96      0.95      0.95      3100
#    not_noise       0.95      0.97      0.96      3300
#
#     accuracy                           0.96      6400
#    macro avg       0.96      0.96      0.96      6400
# weighted avg       0.96      0.96      0.96      6400

# %%
accuracy, precision, recall, fscore
# Out:
# (0.95609374999999996, 0.94938999999999996, 0.966364, 0.96292)

# %%
model.summary()

# %%
save_dir = '/media/tord/T7/Thesis_ssd/SavedModels/LSTM'
model_name = 'LSTM_baseline_3N_final'
model_path = f'{save_dir}/{model_name}'

model.save(model_path)
#model = helper.load_model(model_path)
# Out:
# WARNING:absl:Found untraced functions such as lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_fn, lstm_cell_layer_call_and_return_conditional_losses, lstm_cell_layer_call_and_return_conditional_losses while saving (showing 5 of 5). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /media/tord/T7/Thesis_ssd/SavedModels/InceptionTime/MLSTM-FCN_3N_final/assets
# INFO:tensorflow:Assets written to: /media/tord/T7/Thesis_ssd/SavedModels/InceptionTime/MLSTM-FCN_3N_final/assets

# %%
def get_false_negative_indexes(rounded_predictions, y_test):
    false_negative_indexes = []
    for i in range(len(rounded_predictions)):
        if y_test[i] == 1 and rounded_predictions[i] == 0:
            false_negative_indexes.append(i)
    return false_negative_indexes

def get_false_positive_indexes(rounded_predictions, y_test):
    false_positive_indexes = []
    for i in range(len(rounded_predictions)):
        if y_test[i] == 0 and rounded_predictions[i] == 1:
            false_positive_indexes.append(i)
    return false_positive_indexes

def get_true_positive_indexes(rouneded_predictions, y_test):
    true_positive_indexes = []
    for i in range(len(rounded_predictions)):
        if y_test[i] == 1 and rounded_predictions[i] == 1:
            true_positive_indexes.append(i)
    return true_positive_indexes

def get_true_negative_indexes(rouneded_predictions, y_test):
    true_negative_indexes = []
    for i in range(len(rounded_predictions)):
        if y_test[i] == 0 and rounded_predictions[i] == 0:
            true_negative_indexes.append(i)
    return true_negative_indexes

predictions = helper.predict_RamGenerator(model, x_val, y_val, params["batch_size"], True, noiseAug, loadData.label_dict, 3)
rounded_predictions = np.rint(predictions)
y = y_val


false_negatives_indexes = get_false_negative_indexes(rounded_predictions, y)
false_positives_indexes = get_false_positive_indexes(rounded_predictions, y)
true_negative_indexes = get_true_negative_indexes(rounded_predictions, y)
true_positive_indexes = get_true_positive_indexes(rounded_predictions, y)

# %% [markdown]
# # True Positive

# %%
import pprint
i = 0
pp = pprint.PrettyPrinter(indent = 4)

# %%
index = true_positive_indexes[i]
original_trace, sample_info = handler.path_to_trace(val_ds[index][0])
transformed_trace = x_val[index]
print(f"Predicted label: {predictions[index]}, Correct: {y_val[index]}")
print("Transformed")
helper.plot_event(transformed_trace, sample_info)
helper.plot_event(original_trace, sample_info)
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(sample_info)
i += 1
# Out:
# Predicted label: [ 0.99876755], Correct: [1]
# Transformed
# /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/obspy/imaging/util.py:275: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/obspy/imaging/waveform.py:820: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# {   'analyst_pick_time': None,
#     'az_to_arces': 303.7234699338369,
#     'baz_to_arces': 116.33584235472742,
#     'comments': [   {   'creation_info': {'author': 'general'},
#                         'resource_id': 'smi:local/c87cc170-0643-46a5-b2d5-af7eb02d5ae6',
#                         'text': 'FULLY AUTOMATIC, EVENT TYPE & LOCATION & '
#                                 'MAGNITUDE CHECKED (KAA)'},
#                     {   'creation_info': {'author': 'general'},
#                         'resource_id': 'smi:local/f4bd9ca5-5451-404c-99ed-63807c631809',
#                         'text': 'BALTIC STATES - BELARUS - NORTHWESTERN RUSSIA '
#                                 'REGION'}],
#     'dist_to_arces': 371.1530400124094,
#     'est_arrivaltime_arces': '2016-07-05 15:36:29.200000',
#     'event_type': 'explosion',
#     'event_type_certainty': 'known',
#     'magnitude_dist_ratio': 0.005119182103254426,
#     'magnitude_sqrtdist_ratio': 0.09862274583575234,
#     'magnitudes': [   {   'creation_info': {'agency_id': 'HEL'},
#                           'mag': 1.9,
#                           'mag_errors': {'uncertainty': 0.1},
#                           'magnitude_type': 'ML',
#                           'origin_id': 'smi:local/919db4b9-5777-4a12-9180-d94525f25b87',
#                           'resource_id': 'smi:local/5be95741-08a4-4906-9267-eb583c73583d',
#                           'station_count': 10}],
#     'origins': [   {   'creation_info': {'agency_id': 'HEL'},
#                        'depth': 0.0,
#                        'evaluation_mode': 'manual',
#                        'latitude': 67.861,
#                        'latitude_errors': {'uncertainty': 2.1},
#                        'longitude': 33.437,
#                        'longitude_errors': {'uncertainty': 2.5},
#                        'resource_id': 'smi:local/919db4b9-5777-4a12-9180-d94525f25b87',
#                        'time': '2016-07-05T15:35:32.100000Z',
#                        'time_errors': {'uncertainty': 0.2}}],
#     'preferred_magnitude_id': 'smi:local/5be95741-08a4-4906-9267-eb583c73583d',
#     'preferred_origin_id': 'smi:local/919db4b9-5777-4a12-9180-d94525f25b87',
#     'resource_id': 'smi:local/8eb0d302-9314-4e09-8172-4372eb821d70',
#     'trace_stats': {   'channels': [   'P-beam, vertical',
#                                        'S-beam, transverse',
#                                        'S-beam, radial'],
#                        'sampling_rate': 40.0,
#                        'starttime': '2016-07-05T15:35:29.200000Z',
#                        'station': 'ARCES beam'}}

# %% [markdown]
# # False Positive

# %%
j = 0

# %%
# Plotting false negative
index = false_positives_indexes[j]
original_trace, sample_info = handler.path_to_trace(val_ds[index][0])
transformed_trace = x_val[index]
print(f"Predicted label: {predictions[index]}, Correct: {y_val[index]}")
print("Transformed")
print(j)
helper.plot_event(transformed_trace, sample_info)
helper.plot_event(original_trace, sample_info)
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(sample_info)
j += 1
# Out:
# Predicted label: [ 0.62594426], Correct: [0]
# Transformed
# -1
# /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/obspy/imaging/util.py:275: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/obspy/imaging/waveform.py:820: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# {   'analyst_pick_time': None,
#     'baz_to_arces': 1.1082204134593368,
#     'est_arrivaltime_arces': '2020-07-13 15:46:47',
#     'trace_stats': {   'channels': [   'P-beam, vertical',
#                                        'S-beam, transverse',
#                                        'S-beam, radial'],
#                        'sampling_rate': 40.0,
#                        'starttime': '2020-07-13T15:45:47.000000Z',
#                        'station': 'ARCES beam'}}

# %% [markdown]
# # True Negative

# %%
k = 0

# %%
# Plotting true negative
index = true_negative_indexes[k]
original_trace, sample_info = handler.path_to_trace(val_ds[index][0])
transformed_trace = x_val[index]
print(f"Predicted label: {predictions[index]}, Correct: {y_val[index]}")
print("Transformed")
helper.plot_event(transformed_trace, sample_info)
helper.plot_event(original_trace, sample_info)
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(sample_info)
k += 1
# Out:
# Predicted label: [ 0.0269309], Correct: [0]
# Transformed
# /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/obspy/imaging/util.py:275: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/obspy/imaging/waveform.py:820: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# {   'analyst_pick_time': None,
#     'baz_to_arces': 1.8030060610431773,
#     'est_arrivaltime_arces': '1998-11-02 08:38:51',
#     'trace_stats': {   'channels': [   'P-beam, vertical',
#                                        'S-beam, transverse',
#                                        'S-beam, radial'],
#                        'sampling_rate': 40.0,
#                        'starttime': '1998-11-02T08:37:51.007110Z',
#                        'station': 'ARCES beam'}}

# %% [markdown]
# # False Negative

# %%
m = 0

# %%
# Plotting false negative
index = false_negatives_indexes[m]
original_trace, sample_info = handler.path_to_trace(val_ds[index][0])
transformed_trace = x_val[index]
print(f"Predicted label: {predictions[index]}, Correct: {y_val[index]}")
print("Transformed")
print(m)
helper.plot_event(transformed_trace, sample_info)
helper.plot_event(original_trace, sample_info)
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(sample_info)
m += 1
# Out:
# Predicted label: [ 0.42957294], Correct: [1]
# Transformed
# 16
# /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/obspy/imaging/util.py:275: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/obspy/imaging/waveform.py:820: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# {   'analyst_pick_time': None,
#     'az_to_arces': 46.61140145221144,
#     'baz_to_arces': 231.55942541200716,
#     'comments': [   {   'creation_info': {'author': 'mining area'},
#                         'resource_id': 'smi:local/007a9e44-9f0e-45e6-ac42-c36ccdab8875',
#                         'text': 'MINING AREA: KIRUNA  2KM'},
#                     {   'creation_info': {'author': 'general'},
#                         'resource_id': 'smi:local/6ec1c731-26dd-48a8-9879-1b2eee872cd5',
#                         'text': 'SWEDEN'}],
#     'dist_to_arces': 284.9849223536319,
#     'est_arrivaltime_arces': '2012-10-05 17:59:38.843000',
#     'event_type': 'explosion',
#     'event_type_certainty': 'known',
#     'magnitude_dist_ratio': 0.00421074908135296,
#     'magnitude_sqrtdist_ratio': 0.07108374566399517,
#     'magnitudes': [   {   'creation_info': {'agency_id': 'HEL'},
#                           'mag': 1.2,
#                           'mag_errors': {'uncertainty': 0.1},
#                           'magnitude_type': 'ML',
#                           'origin_id': 'smi:local/2bf21bc0-5ea0-4b23-ac73-6e3509bc29c0',
#                           'resource_id': 'smi:local/1d812bde-f831-4973-b9fe-25b1d73d3ece',
#                           'station_count': 11},
#                       {   'creation_info': {'agency_id': 'HEL'},
#                           'mag': 1.2,
#                           'magnitude_type': 'ML',
#                           'origin_id': 'smi:local/3748db97-67bc-4f67-8e62-7bd76a2f41d7',
#                           'resource_id': 'smi:local/4c7c398d-f467-4d9e-8bba-a291c41a44a7',
#                           'station_count': 6},
#                       {   'creation_info': {'agency_id': 'UPP'},
#                           'mag': 1.8,
#                           'magnitude_type': 'ML',
#                           'origin_id': 'smi:local/405cc533-7eba-4e0e-9dad-f70cb0a9c05f',
#                           'resource_id': 'smi:local/86d1f077-fcce-489a-83b7-1780e5ed7586',
#                           'station_count': 6}],
#     'origins': [   {   'creation_info': {'agency_id': 'HEL'},
#                        'depth': 0.0,
#                        'latitude': 67.855,
#                        'latitude_errors': {'uncertainty': 0.373},
#                        'longitude': 20.2,
#                        'longitude_errors': {'uncertainty': 0.293},
#                        'region': 'KIRUNA',
#                        'resource_id': 'smi:local/2bf21bc0-5ea0-4b23-ac73-6e3509bc29c0',
#                        'time': '2012-10-05T17:58:55.000000Z',
#                        'time_errors': {'uncertainty': 0.0}},
#                    {   'creation_info': {'agency_id': 'HEL'},
#                        'depth': 0.0,
#                        'latitude': 67.838,
#                        'longitude': 20.23,
#                        'resource_id': 'smi:local/3748db97-67bc-4f67-8e62-7bd76a2f41d7',
#                        'time': '2012-10-05T17:58:55.400000Z'},
#                    {   'creation_info': {'agency_id': 'UPP'},
#                        'depth': 0.1,
#                        'latitude': 67.851,
#                        'longitude': 20.2,
#                        'resource_id': 'smi:local/405cc533-7eba-4e0e-9dad-f70cb0a9c05f',
#                        'time': '2012-10-05T17:58:54.400000Z'}],
#     'preferred_magnitude_id': 'smi:local/1d812bde-f831-4973-b9fe-25b1d73d3ece',
#     'preferred_origin_id': 'smi:local/2bf21bc0-5ea0-4b23-ac73-6e3509bc29c0',
#     'resource_id': 'smi:local/67d1bcb9-a887-443a-908b-da8a3227c5eb',
#     'trace_stats': {   'channels': [   'P-beam, vertical',
#                                        'S-beam, transverse',
#                                        'S-beam, radial'],
#                        'sampling_rate': 40.0,
#                        'starttime': '2012-10-05T17:58:38.850000Z',
#                        'station': 'ARCES beam'}}
