# %%
import numpy as np
import os
import sys
import pandas as pd
import seaborn as sns

import pylab as pl
import h5py

import tensorflow as tf
from tensorflow.keras import mixed_precision

os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
os.environ['CUDA_VISIBLE_DEVICES']="0" 

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)


from sklearn.metrics import confusion_matrix

base_dir = '/media/tord/T7/Thesis_ssd/MasterThesis3'
os.chdir(base_dir)
from Classes.DataProcessing.LoadData import LoadData
from Classes.DataProcessing.HelperFunctions import HelperFunctions
from Classes.DataProcessing.DataHandler import DataHandler
from Classes.Modeling.DynamicModels import DynamicModels
from Classes.Modeling.TrainSingleModelRam import TrainSingleModelRam
from Classes.DataProcessing.RamLoader import RamLoader
import json

import gc

import datetime
import re
from livelossplot import PlotLossesKeras
from GlobalUtils import GlobalUtils
from Classes.Modeling.CustomCallback import CustomCallback
from tensorflow.keras.callbacks import EarlyStopping
utils = GlobalUtils()

from tensorflow.keras.utils import GeneratorEnqueuer






import sys


helper = HelperFunctions()

tf.config.optimizer.set_jit(True)
mixed_precision.set_global_policy('mixed_float16')
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# WARNING:tensorflow:From /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/tensorflow/python/util/module_wrapper.py:49: The name tf.keras.layers.CuDNNLSTM is deprecated. Please use tf.compat.v1.keras.layers.CuDNNLSTM instead.
#
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: GeForce RTX 3090, compute capability 8.6

# %%
load_args = {
    'earth_explo_only' : True,
    'noise_earth_only' : False,
    'noise_not_noise' : False,
    'downsample' : True,
    'upsample' : True,
    'frac_diff' : 1,
    'seed' : 1,
    'subsample_size' : 0.25,
    'balance_non_train_set' : False,
    'use_true_test_set' : False,
    'even_balance' : True
}
loadData = LoadData(**load_args)
train_ds, val_ds, test_ds = loadData.get_datasets()
noise_ds = loadData.noise_ds
handler = DataHandler(loadData)
# Out:
# 2 2
# Mapping train redundancy: : [--------------------------------------->] 100 %
#
# Mapping validation redundancy: : [--------------------------------------->] 100 %
#
# Mapping test redundancy: : [--------------------------------------->] 100 %
#
#
#
# Loaded explosion and earthquake dataset:
# Evenly balanced among classes in the train set.
# Distribution (Label: (counts, proportion)) of
# Train ds:
# earthquake: (20507, 0.4987)  |  explosion: (20616, 0.5013)
# Val ds:
# earthquake: (255, 0.0762)  |  explosion: (3092, 0.9238)
# Test ds:
# earthquake: (176, 0.0789)  |  explosion: (2055, 0.9211)

# %%
model_type = "CNN_grow_double"
is_lstm = True
num_channels = 3    

use_time_augmentor = True
scaler_name = "normalize"
use_noise_augmentor = True
filter_name = None
band_min = 2.0
band_max = 4.0
highpass_freq = 0.075


shutdown = False

num_classes = len(list(set(loadData.label_dict.values())))



ramLoader = RamLoader(loadData, 
                      handler, 
                      use_time_augmentor = use_time_augmentor, 
                      use_noise_augmentor = use_noise_augmentor, 
                      scaler_name = scaler_name,
                      filter_name = filter_name, 
                      band_min = band_min,
                      band_max = band_max,
                      highpass_freq = highpass_freq, 
                      load_test_set = True, 
                      meier_load = False)

x_train, y_train, x_val, y_val, x_test, y_test, noiseAug = ramLoader.load_to_ram()
# Out:
# Fitting noise set time augmentor: [--------------------------------------->] 100 %
#
# Fit process completed after 147.9863007068634 seconds. Total datapoints fitted: 21199.
# Average time per datapoint: 0.0069808151661334686
#
#
# Fitting train time augmentor: [--------------------------------------->] 100 %
#
# Fit process completed after 180.46871423721313 seconds. Total datapoints fitted: 41123.
# Average time per datapoint: 0.0043885104257280145
#
#
# Fitting validation time augmentor: [--------------------------------------->] 100 %
#
# Fit process completed after 27.627767086029053 seconds. Total datapoints fitted: 3347.
# Average time per datapoint: 0.008254486730214835
#
#
# Fitting test time augmentor: [--------------------------------------->] 100 %
#
# Fit process completed after 18.693748712539673 seconds. Total datapoints fitted: 2231.
# Average time per datapoint: 0.008379089517050504
#
#
# Stage one loading training set, timeAug: [--------------------------------------->] 100 %
#
# Stage one loading validation set, timeAug: [--------------------------------------->] 100 %
#
# Stage one loading test set, timeAug: [--------------------------------------->] 100 %
#
# Fit process of normalizer skipped as unecessary
#
#
# Stage one loading noise set, timeAug: [--------------------------------------->] 100 %
#
# Stage two loading noise set, labels and normalize scaler: [--------------------------------------->] 100 %
#
# Fitting noise augmentor: [--------------------------------------->] 100 %
#
#
#
# Stage two loading training set, labels and normalize scaler: [--------------------------------------->] 100 %
#
# Stage two loading validation set, labels and normalize scaler: [--------------------------------------->] 100 %
#
# Stage two loading test set, labels and normalize scaler: [--------------------------------------->] 100 %
#
#
#
# Completed loading to RAM
# Time elapsed to completion of load_to_ram_earth_explo_only: 0:08:03.814633

# %%
use_tensorboard = True
use_liveplots = False
use_custom_callback = True
use_early_stopping = True
start_from_scratch = False
use_reduced_lr = True
log_data = True

beta = 2

def clear_tensorboard_dir():
        import os
        import shutil
        path = f"{base_dir}/Tensorboard_dir/fit"
        files = os.listdir(path)
        print(files)
        for f in files:
            shutil.rmtree(os.path.join(path,f))
if use_tensorboard:
    clear_tensorboard_dir()

"""
modelTrain = TrainSingleModelRam(noiseAug, helper,
                              loadData, model_type, num_channels, use_tensorboard, use_liveplots,
                              use_custom_callback, use_early_stopping, use_reduced_lr, ramLoader,
                              log_data = log_data, 
                              start_from_scratch = start_from_scratch, beta = beta)
"""
### CNN grow double params
params = {    
    'batch_size': 256,
    'cnn_activation': 'relu',
    'dense_activation': 'relu',
    'dropout_T_bn_F': True,
    'dropout_rate': 0.001,
    'epochs': 100,
    'filter_size': 72,
    'first_dense_units': 254,
    'growth_sequence': [1, 4, 8],
    'l1_r': 0.0,
    'l2_r': 0.001,
    'learning_rate': 0.0001,
    'num_filters': 78,
    'num_layers': 3,
    'optimizer': 'adam',
    'output_layer_activation': 'sigmoid',
    'padding': 'same',
    'second_dense_units': 234,
    'use_layerwise_dropout_batchnorm': True
}
#model = modelTrain.run(x_train, y_train, x_val, y_val, x_test, y_test, 16, 15, evaluate_train = True, evaluate_val = True, evaluate_test = True, meier_mode = False, **params)
# Out:
# ['20210503-021928']

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 6000, 3)]         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 6000, 78)          16926
# _________________________________________________________________
# activation (Activation)      (None, 6000, 78)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 6000, 78)          0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 3000, 78)          0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 3000, 312)         1752504
# _________________________________________________________________
# activation_1 (Activation)    (None, 3000, 312)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3000, 312)         0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 1500, 312)         0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 1500, 624)         14018160
# _________________________________________________________________
# activation_2 (Activation)    (None, 1500, 624)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1500, 624)         0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 750, 624)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 468000)            0
# _________________________________________________________________
# dense (Dense)                (None, 254)               118872254
# _________________________________________________________________
# dense_1 (Dense)              (None, 234)               59670
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 235
# =================================================================
# Total params: 134,719,749
# Trainable params: 134,719,749
# Non-trainable params: 0
# _________________________________________________________________

# %%
conf, report, accuracy, precision, recall, fscore = helper.evaluate_generator(model, x_val, y_val, params["batch_size"],
                                                                             loadData.label_dict, num_channels, noiseAug,
                                                                             scaler_name, 2, plot_conf_matrix = True, plot_p_r_curve = True, beta = beta)
# Out:
# 2782 292 33 221
# ['explosion', 'earthquake']
# EE
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[2782,  292],
#        [  33,  221]], dtype=int32)>
#               precision    recall  f1-score   support
#
#    explosion       0.99      0.91      0.94      3074
#   earthquake       0.43      0.87      0.58       254
#
#     accuracy                           0.90      3328
#    macro avg       0.71      0.89      0.76      3328
# weighted avg       0.95      0.90      0.92      3328

# %%
accuracy, precision, recall, fscore
# Out:
# (0.90234375, 0.43079899999999999, 0.87007900000000005, 0.72269499999999998)

# %%
def load_model_ramGen(path):
    acc = tf.keras.metrics.BinaryAccuracy(name="binary_accuacy", dtype = None, threshold = 0.5)
    precision = helper.precision
    recall = helper.recall
    return tf.keras.models.load_model(model_path, custom_objects = {"accuracy" : acc,
                                                                    "precision": precision,
                                                                    "recall" : recall})

# %%
save_dir = '/media/tord/T7/Thesis_ssd/SavedModels/CNN'
model_name = 'CNN_EE_final'
model_path = f'{save_dir}/{model_name}'

#model.save(model_path)
model = load_model_ramGen(model_path, x_val, y_val, val_ds, noiseAug, scaler_name, params["batch_size"], beta)

# %%
predictions = helper.predict_RamGenerator(model, x_val, y_val, params["batch_size"], True, noiseAug, loadData.label_dict, 3)
rounded_predictions = np.rint(predictions)

# %%
def get_false_negative_indexes(rounded_predictions, y_test):
    false_negative_indexes = []
    for i in range(len(rounded_predictions)):
        if y_test[i] == 1 and rounded_predictions[i] == 0:
            false_negative_indexes.append(i)
    return false_negative_indexes

def get_false_positive_indexes(rounded_predictions, y_test):
    false_positive_indexes = []
    for i in range(len(rounded_predictions)):
        if y_test[i] == 0 and rounded_predictions[i] == 1:
            false_positive_indexes.append(i)
    return false_positive_indexes

def get_true_positive_indexes(rouneded_predictions, y_test):
    true_positive_indexes = []
    for i in range(len(rounded_predictions)):
        if y_test[i] == 1 and rounded_predictions[i] == 1:
            true_positive_indexes.append(i)
    return true_positive_indexes

def get_true_negative_indexes(rouneded_predictions, y_test):
    true_negative_indexes = []
    for i in range(len(rounded_predictions)):
        if y_test[i] == 0 and rounded_predictions[i] == 0:
            true_negative_indexes.append(i)
    return true_negative_indexes

# %%
false_negatives_indexes = get_false_negative_indexes(rounded_predictions, y_val)
false_positives_indexes = get_false_positive_indexes(rounded_predictions, y_val)
true_negative_indexes = get_true_negative_indexes(rounded_predictions, y_val)
true_positive_indexes = get_true_positive_indexes(rounded_predictions, y_val)

# %% [markdown]
# # True Positives

# %%
import pprint
i = 0
pp = pprint.PrettyPrinter(indent = 4)

# %%
index = true_positive_indexes[i]
original_trace, sample_info = handler.path_to_trace(val_ds[index][0])
transformed_trace = x_val[index]
print(f"Predicted label: {predictions[index]}, Correct: {y_val[index]}")
print("Transformed")
helper.plot_event(transformed_trace, sample_info)
helper.plot_event(original_trace, sample_info)
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(sample_info)
i += 1
# Out:
# Predicted label: [ 0.6069228], Correct: [1]
# Transformed
# /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/obspy/imaging/util.py:275: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/obspy/imaging/waveform.py:820: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# {   'analyst_pick_time': None,
#     'az_to_arces': 310.95053205806516,
#     'baz_to_arces': 124.06395740936195,
#     'dist_to_arces': 381.7028505378676,
#     'est_arrivaltime_arces': '2008-04-19 03:51:52.617000',
#     'event_type': 'earthquake',
#     'event_type_certainty': 'known',
#     'magnitude_dist_ratio': 0.005920836055626448,
#     'magnitude_sqrtdist_ratio': 0.1156766592088299,
#     'magnitudes': [   {   'mag': 2.26,
#                           'magnitude_type': 'Mb',
#                           'origin_id': 'smi:local/f6b24ef1-b90a-40f9-bf65-5231bf5e42ae',
#                           'resource_id': 'smi:local/f85975b1-20c0-48d2-aa71-fc05a945bfe6'},
#                       {   'mag': 2.04,
#                           'magnitude_type': 'Ml',
#                           'origin_id': 'smi:local/f6b24ef1-b90a-40f9-bf65-5231bf5e42ae',
#                           'resource_id': 'smi:local/760e2cd7-5ddb-40bf-a82d-f0008af538bb'}],
#     'origins': [   {   'arrivals': [   {   'azimuth': 191.06422,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/2953deab-81e9-4674-be1e-635ffa7bfc54',
#                                                                'text': 'ARID=18366'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Lg',
#                                            'pick_id': 'smi:local/3c953b59-c1e0-4e6a-9aab-1a025d4ee7ac',
#                                            'resource_id': 'smi:local/9a4345ae-bb72-4301-af5f-508bc4682a38',
#                                            'time_residual': 1.3049062},
#                                        {   'azimuth': 191.06422,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/feac8949-9701-4817-8184-ae6abc6c5b5a',
#                                                                'text': 'ARID=18367'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Pg',
#                                            'pick_id': 'smi:local/5e2bc1e9-d1b7-40ce-b20e-00fd35fd3650',
#                                            'resource_id': 'smi:local/5fcaccc5-9487-4d6c-bbd9-edda14c78d1b',
#                                            'time_residual': -1.4282457},
#                                        {   'azimuth': 23.150943,
#                                            'backazimuth_residual': -8.2195264,
#                                            'comments': [   {   'resource_id': 'smi:local/a7e51e13-a54a-492a-88d8-ff443f026d1c',
#                                                                'text': 'ARID=18368'}],
#                                            'horizontal_slowness_residual': -3.0880371,
#                                            'phase': 'Sn',
#                                            'pick_id': 'smi:local/f5ad7990-747b-4409-9239-2c833d250878',
#                                            'resource_id': 'smi:local/2cdda0eb-6b59-4e5c-95a7-e6904397ceeb',
#                                            'time_residual': 1.6640835},
#                                        {   'azimuth': 23.150943,
#                                            'backazimuth_residual': -14.620177,
#                                            'comments': [   {   'resource_id': 'smi:local/ee1b5cc4-cae3-4cbb-bbff-0fd9e4f3793b',
#                                                                'text': 'ARID=18369'}],
#                                            'horizontal_slowness_residual': -3.660261,
#                                            'phase': 'Lg',
#                                            'pick_id': 'smi:local/cff9c439-f525-4202-bf2f-b59ed7fd0583',
#                                            'resource_id': 'smi:local/2492e02d-d9ec-40f1-9e09-44f292551451',
#                                            'time_residual': -0.04585916},
#                                        {   'azimuth': 124.11714,
#                                            'backazimuth_residual': -1.9771368,
#                                            'comments': [   {   'resource_id': 'smi:local/4d576cdc-5793-46dc-b8e2-e05bcfb4c5e8',
#                                                                'text': 'ARID=9017577'}],
#                                            'horizontal_slowness_residual': 0.89038624,
#                                            'phase': 'Pn',
#                                            'pick_id': 'smi:local/3cc057ee-9d47-4ce3-823b-2221e9ee5d8a',
#                                            'resource_id': 'smi:local/fef27848-aa22-4e42-80e4-74f2ea4c6a3d',
#                                            'time_residual': -1.5156064},
#                                        {   'azimuth': 124.11714,
#                                            'backazimuth_residual': -1.4051358,
#                                            'comments': [   {   'resource_id': 'smi:local/ea5e1de2-a1db-4171-a09e-f5fdc99abfe5',
#                                                                'text': 'ARID=9017579'}],
#                                            'horizontal_slowness_residual': -6.0084711,
#                                            'phase': 'Pg',
#                                            'pick_id': 'smi:local/9bf83145-e438-4db7-a36e-1de23629c84c',
#                                            'resource_id': 'smi:local/4d86a4de-0e15-494f-8324-e8eb48a4384f',
#                                            'time_residual': 0.43341416},
#                                        {   'azimuth': 124.11714,
#                                            'backazimuth_residual': -0.41713683,
#                                            'comments': [   {   'resource_id': 'smi:local/52b3c2b9-6891-450c-bf5f-2e6abaf3eee4',
#                                                                'text': 'ARID=9017582'}],
#                                            'horizontal_slowness_residual': 0.20540398,
#                                            'phase': 'Sn',
#                                            'pick_id': 'smi:local/f0c62f2d-db9c-493d-aa65-ee3346ed268f',
#                                            'resource_id': 'smi:local/644ebaa8-5b9e-4e7a-99a9-8467ea41db0f',
#                                            'time_residual': 0.27150048},
#                                        {   'azimuth': 124.11714,
#                                            'backazimuth_residual': -3.4371368,
#                                            'comments': [   {   'resource_id': 'smi:local/6aa27ce1-7d0b-4172-b3f7-1f3b5ef41d70',
#                                                                'text': 'ARID=9017584'}],
#                                            'horizontal_slowness_residual': -8.3800081,
#                                            'phase': 'Lg',
#                                            'pick_id': 'smi:local/2ce22e4e-4410-4037-a423-004789fdfb01',
#                                            'resource_id': 'smi:local/04fb5653-6cc2-488e-adde-7fc2c5fd55a3',
#                                            'time_residual': 0.34960365},
#                                        {   'azimuth': 23.150943,
#                                            'backazimuth_residual': 2.3931236,
#                                            'comments': [   {   'resource_id': 'smi:local/d8d5d11a-3322-41f9-b37f-2ff75d2c3ce3',
#                                                                'text': 'ARID=9017591'}],
#                                            'horizontal_slowness_residual': -6.2692548,
#                                            'phase': 'Pn',
#                                            'pick_id': 'smi:local/36af2d31-bc5c-4d7e-86ae-a9b83bcc6a00',
#                                            'resource_id': 'smi:local/20decf2e-a061-4d16-9c73-3226f9daa1b7',
#                                            'time_residual': 1.4300443}],
#                        'comments': [   {   'resource_id': 'smi:local/be831c24-49c2-4405-bba5-c2cf67ac6ae9',
#                                            'text': 'orid: 11019'}],
#                        'creation_info': {   'agency_id': 'NORSAR',
#                                             'author': 'ARS:berit',
#                                             'creation_time': '2008-04-23T11:09:03.000000Z'},
#                        'depth': 0.0,
#                        'depth_errors': {'uncertainty': -1.0},
#                        'latitude': 67.442288,
#                        'longitude': 32.909691,
#                        'quality': {   'associated_phase_count': 9,
#                                       'used_phase_count': 9},
#                        'resource_id': 'smi:local/f6b24ef1-b90a-40f9-bf65-5231bf5e42ae',
#                        'time': '2008-04-19T03:50:53.893600Z',
#                        'time_errors': {'uncertainty': 1.1175125}}],
#     'picks': [   {   'backazimuth': 122.14,
#                      'backazimuth_errors': {'uncertainty': 0.06},
#                      'horizontal_slowness': 14.64,
#                      'horizontal_slowness_errors': {'uncertainty': 0.92},
#                      'phase_hint': 'Pn',
#                      'resource_id': 'smi:local/3cc057ee-9d47-4ce3-823b-2221e9ee5d8a',
#                      'time': '2008-04-19T03:51:46.600000Z',
#                      'waveform_id': {   'channel_code': 'FE54',
#                                         'station_code': 'ARCES'}},
#                  {   'backazimuth': 122.712,
#                      'backazimuth_errors': {'uncertainty': 3.542665},
#                      'horizontal_slowness': 12.220426,
#                      'horizontal_slowness_errors': {'uncertainty': 0.755483},
#                      'phase_hint': 'Pg',
#                      'resource_id': 'smi:local/9bf83145-e438-4db7-a36e-1de23629c84c',
#                      'time': '2008-04-19T03:51:54.875000Z',
#                      'waveform_id': {   'channel_code': 'FG67',
#                                         'station_code': 'ARCES'}},
#                  {   'backazimuth': 123.7,
#                      'backazimuth_errors': {'uncertainty': 0.05},
#                      'horizontal_slowness': 24.93,
#                      'horizontal_slowness_errors': {'uncertainty': 1.15},
#                      'phase_hint': 'Sn',
#                      'resource_id': 'smi:local/f0c62f2d-db9c-493d-aa65-ee3346ed268f',
#                      'time': '2008-04-19T03:52:29.150000Z',
#                      'waveform_id': {   'channel_code': 'FB17',
#                                         'station_code': 'ARCES'}},
#                  {   'backazimuth': 120.68,
#                      'backazimuth_errors': {'uncertainty': 0.06},
#                      'horizontal_slowness': 23.39,
#                      'horizontal_slowness_errors': {'uncertainty': 1.32},
#                      'phase_hint': 'Lg',
#                      'resource_id': 'smi:local/2ce22e4e-4410-4037-a423-004789fdfb01',
#                      'time': '2008-04-19T03:52:42.375000Z',
#                      'waveform_id': {   'channel_code': 'FC30',
#                                         'station_code': 'ARCES'}}],
#     'resource_id': 'smi:local/a92dbc92-eaba-4836-b104-645cf3e6e166',
#     'trace_stats': {   'channels': [   'P-beam, vertical',
#                                        'S-beam, transverse',
#                                        'S-beam, radial'],
#                        'sampling_rate': 40.0,
#                        'starttime': '2008-04-19T03:50:52.625000Z',
#                        'station': 'ARCES beam'}}

# %% [markdown]
# # False Positives

# %%
j = 0

# %%
# Plotting false negative
index = false_positives_indexes[j]
original_trace, sample_info = handler.path_to_trace(val_ds[index][0])
transformed_trace = x_val[index]
print(f"Predicted label: {predictions[index]}, Correct: {y_val[index]}")
print("Transformed")
print(j)
helper.plot_event(transformed_trace, sample_info)
helper.plot_event(original_trace, sample_info)
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(sample_info)
j += 1
# Out:
# Predicted label: [ 0.9981719], Correct: [0]
# Transformed
# 28
# /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/obspy/imaging/util.py:275: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/obspy/imaging/waveform.py:820: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# {   'analyst_pick_time': None,
#     'az_to_arces': 13.106334086673531,
#     'baz_to_arces': 199.62030341158015,
#     'dist_to_arces': 1245.0353427663154,
#     'est_arrivaltime_arces': '1995-05-02 08:26:21.643000',
#     'event_type': 'explosion',
#     'event_type_certainty': 'known',
#     'magnitude_dist_ratio': 0.0023292511468441988,
#     'magnitude_sqrtdist_ratio': 0.08218776262831454,
#     'magnitudes': [   {   'creation_info': {'agency_id': 'HEL'},
#                           'mag': 2.9,
#                           'mag_errors': {'uncertainty': 0.0},
#                           'magnitude_type': 'MA',
#                           'origin_id': 'smi:local/dfc90efb-2196-465b-896f-e74495d8eed4',
#                           'resource_id': 'smi:local/9bf8e7f7-4607-482c-bfcd-601939304ef2',
#                           'station_count': 10}],
#     'origins': [   {   'creation_info': {'agency_id': 'HEL'},
#                        'depth': 0.0,
#                        'latitude': 58.794,
#                        'latitude_errors': {'uncertainty': 6.6},
#                        'longitude': 18.306,
#                        'longitude_errors': {'uncertainty': 5.1},
#                        'resource_id': 'smi:local/dfc90efb-2196-465b-896f-e74495d8eed4',
#                        'time': '1995-05-02T08:23:10.100000Z',
#                        'time_errors': {'uncertainty': 0.8}}],
#     'preferred_magnitude_id': 'smi:local/9bf8e7f7-4607-482c-bfcd-601939304ef2',
#     'preferred_origin_id': 'smi:local/dfc90efb-2196-465b-896f-e74495d8eed4',
#     'resource_id': 'smi:local/ab1d4c09-f5af-4b6f-88fa-d06ede412f97',
#     'trace_stats': {   'channels': [   'P-beam, vertical',
#                                        'S-beam, transverse',
#                                        'S-beam, radial'],
#                        'sampling_rate': 40.0,
#                        'starttime': '1995-05-02T08:25:21.637013Z',
#                        'station': 'ARCES beam'}}

# %% [markdown]
# # True Negatives

# %%
k = 0

# %%
# Plotting false negative
index = true_negative_indexes[k]
original_trace, sample_info = handler.path_to_trace(val_ds[index][0])
transformed_trace = x_val[index]
print(f"Predicted label: {predictions[index]}, Correct: {y_val[index]}")
print("Transformed")
helper.plot_event(transformed_trace, sample_info)
helper.plot_event(original_trace, sample_info)
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(sample_info)
k += 1
# Out:
# Predicted label: [ 0.0001394], Correct: [0]
# Transformed
# /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/obspy/imaging/util.py:275: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/obspy/imaging/waveform.py:820: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# {   'analyst_pick_time': None,
#     'az_to_arces': 45.69263987668042,
#     'baz_to_arces': 230.5136751291478,
#     'comments': [   {   'creation_info': {'author': 'general'},
#                         'resource_id': 'smi:local/550dd27b-2038-4030-bdb3-f5d50affc880',
#                         'text': 'FULLY AUTOMATIC LOCATION'},
#                     {   'creation_info': {'author': 'mining area'},
#                         'resource_id': 'smi:local/57fae300-3a52-48f9-bef0-55042668b6ad',
#                         'text': 'MINING AREA: KIRUNA  6KM'}],
#     'dist_to_arces': 282.0149084599872,
#     'est_arrivaltime_arces': '2012-04-05 12:05:23.486000',
#     'event_type': 'explosion',
#     'event_type_certainty': 'known',
#     'magnitude_dist_ratio': 0.004964276561281988,
#     'magnitude_sqrtdist_ratio': 0.08336658314813426,
#     'magnitudes': [   {   'creation_info': {'agency_id': 'HEL'},
#                           'mag': 1.4,
#                           'mag_errors': {'uncertainty': 0.2},
#                           'magnitude_type': 'ML',
#                           'origin_id': 'smi:local/8b8e10c9-8a43-4605-9ac3-4eb93763d75c',
#                           'resource_id': 'smi:local/0512041a-2215-43c0-85ee-fa34e58bf9a7',
#                           'station_count': 8}],
#     'origins': [   {   'creation_info': {'agency_id': 'HEL'},
#                        'depth': 0.0,
#                        'evaluation_mode': 'automatic',
#                        'latitude': 67.84,
#                        'latitude_errors': {'uncertainty': 1.5},
#                        'longitude': 20.336,
#                        'longitude_errors': {'uncertainty': 7.3},
#                        'region': 'KIRUNA',
#                        'resource_id': 'smi:local/8b8e10c9-8a43-4605-9ac3-4eb93763d75c',
#                        'time': '2012-04-05T12:04:40.100000Z',
#                        'time_errors': {'uncertainty': 0.3}}],
#     'preferred_magnitude_id': 'smi:local/0512041a-2215-43c0-85ee-fa34e58bf9a7',
#     'preferred_origin_id': 'smi:local/8b8e10c9-8a43-4605-9ac3-4eb93763d75c',
#     'resource_id': 'smi:local/b565cd1a-63e0-4b7b-a193-aebbed662bd5',
#     'trace_stats': {   'channels': [   'P-beam, vertical',
#                                        'S-beam, transverse',
#                                        'S-beam, radial'],
#                        'sampling_rate': 40.0,
#                        'starttime': '2012-04-05T12:04:23.475000Z',
#                        'station': 'ARCES beam'}}

# %% [markdown]
# # False Negatives

# %%
m = 0

# %%
# Plotting false negative
index = false_negatives_indexes[m]
original_trace, sample_info = handler.path_to_trace(val_ds[index][0])
transformed_trace = x_val[index]
print(f"Predicted label: {predictions[index]}, Correct: {y_val[index]}")
print("Transformed")
print(m)
helper.plot_event(transformed_trace, sample_info)
helper.plot_event(original_trace, sample_info)
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(sample_info)
m += 1
# Out:
# Predicted label: [ 0.30186617], Correct: [1]
# Transformed
# 7
# /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/obspy/imaging/util.py:275: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/obspy/imaging/waveform.py:820: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# {   'analyst_pick_time': None,
#     'az_to_arces': 51.03934889818538,
#     'baz_to_arces': 241.90286878134253,
#     'comments': [   {   'creation_info': {'author': 'general'},
#                         'resource_id': 'smi:local/6b5fa113-dd2a-40a8-b74a-e6a0a6406159',
#                         'text': 'PROBABLY EARTHQUAKE, NORTHERN NORWAY'}],
#     'dist_to_arces': 584.2890775768652,
#     'est_arrivaltime_arces': '2015-05-12 20:51:02.090000',
#     'event_type': 'earthquake',
#     'event_type_certainty': 'known',
#     'magnitude_dist_ratio': 0.003251815022590506,
#     'magnitude_sqrtdist_ratio': 0.07860310771796471,
#     'magnitudes': [   {   'creation_info': {'agency_id': 'HEL'},
#                           'mag': 1.9,
#                           'mag_errors': {'uncertainty': 0.1},
#                           'magnitude_type': 'ML',
#                           'origin_id': 'smi:local/795923a6-9ba5-45dc-853f-d8724383d17d',
#                           'resource_id': 'smi:local/b6b26944-142c-441c-98b0-3b97fd033ae0',
#                           'station_count': 12}],
#     'origins': [   {   'creation_info': {'agency_id': 'HEL'},
#                        'depth': 10.0,
#                        'latitude': 66.622,
#                        'latitude_errors': {'uncertainty': 1.783},
#                        'longitude': 13.809,
#                        'longitude_errors': {'uncertainty': 2.223},
#                        'resource_id': 'smi:local/795923a6-9ba5-45dc-853f-d8724383d17d',
#                        'time': '2015-05-12T20:49:32.200000Z',
#                        'time_errors': {'uncertainty': 0.3}}],
#     'preferred_magnitude_id': 'smi:local/b6b26944-142c-441c-98b0-3b97fd033ae0',
#     'preferred_origin_id': 'smi:local/795923a6-9ba5-45dc-853f-d8724383d17d',
#     'resource_id': 'smi:local/4b3840b1-87e9-4296-a54c-e2df37c941f9',
#     'trace_stats': {   'channels': [   'P-beam, vertical',
#                                        'S-beam, transverse',
#                                        'S-beam, radial'],
#                        'sampling_rate': 40.0,
#                        'starttime': '2015-05-12T20:50:02.100000Z',
#                        'station': 'ARCES beam'}}
