# %%
import numpy as np
import os
import sys
import pandas as pd
import seaborn as sns

import pylab as pl
import h5py

import tensorflow as tf
from tensorflow.keras import mixed_precision

os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
os.environ['CUDA_VISIBLE_DEVICES']="0" 

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)


from sklearn.metrics import confusion_matrix

base_dir = '/media/tord/T7/Thesis_ssd/MasterThesis3'
os.chdir(base_dir)
from Classes.DataProcessing.LoadData import LoadData
from Classes.DataProcessing.HelperFunctions import HelperFunctions
from Classes.DataProcessing.DataHandler import DataHandler
from Classes.Modeling.DynamicModels import DynamicModels
from Classes.Modeling.TrainSingleModelRam import TrainSingleModelRam
from Classes.DataProcessing.RamLoader import RamLoader
import json

import gc

import datetime
import re
from livelossplot import PlotLossesKeras
from GlobalUtils import GlobalUtils
from Classes.Modeling.CustomCallback import CustomCallback
from tensorflow.keras.callbacks import EarlyStopping
utils = GlobalUtils()

from tensorflow.keras.utils import GeneratorEnqueuer






import sys


helper = HelperFunctions()

tf.config.optimizer.set_jit(True)
mixed_precision.set_global_policy('mixed_float16')
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# WARNING:tensorflow:From /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/tensorflow/python/util/module_wrapper.py:49: The name tf.keras.layers.CuDNNLSTM is deprecated. Please use tf.compat.v1.keras.layers.CuDNNLSTM instead.
#
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: GeForce RTX 3090, compute capability 8.6

# %%
load_args = {
    'earth_explo_only' : True,
    'noise_earth_only' : False,
    'noise_not_noise' : False,
    'downsample' : True,
    'upsample' : True,
    'frac_diff' : 1,
    'seed' : 1,
    'subsample_size' : 0.25,
    'balance_non_train_set' : False,
    'use_true_test_set' : False,
    'even_balance' : True
}
loadData = LoadData(**load_args)
train_ds, val_ds, test_ds = loadData.get_datasets()
noise_ds = loadData.noise_ds
handler = DataHandler(loadData)
# Out:
# 2 2
# Mapping train redundancy: : [--------------------------------------->] 100 %
#
# Mapping validation redundancy: : [--------------------------------------->] 100 %
#
# Mapping test redundancy: : [--------------------------------------->] 100 %
#
#
#
# Loaded explosion and earthquake dataset:
# Evenly balanced among classes in the train set.
# Distribution (Label: (counts, proportion)) of
# Train ds:
# earthquake: (20507, 0.4987)  |  explosion: (20616, 0.5013)
# Val ds:
# earthquake: (255, 0.0762)  |  explosion: (3092, 0.9238)
# Test ds:
# earthquake: (176, 0.0789)  |  explosion: (2055, 0.9211)

# %%
model_type = "CNN_grow_double"
is_lstm = True
num_channels = 3    

use_time_augmentor = True
scaler_name = "normalize"
use_noise_augmentor = True
filter_name = None
band_min = 2.0
band_max = 4.0
highpass_freq = 0.075


shutdown = False

num_classes = len(list(set(loadData.label_dict.values())))



ramLoader = RamLoader(loadData, 
                      handler, 
                      use_time_augmentor = use_time_augmentor, 
                      use_noise_augmentor = use_noise_augmentor, 
                      scaler_name = scaler_name,
                      filter_name = filter_name, 
                      band_min = band_min,
                      band_max = band_max,
                      highpass_freq = highpass_freq, 
                      load_test_set = True, 
                      meier_load = False)

x_train, y_train, x_val, y_val, x_test, y_test, noiseAug = ramLoader.load_to_ram()
# Out:
# Fitting noise set time augmentor: [--------------------------------------->] 100 %
#
# Fit process completed after 9.943254232406616 seconds. Total datapoints fitted: 21199.
# Average time per datapoint: 0.00046904355075270607
#
#
# Fitting train time augmentor: [--------------------------------------->] 100 %
#
# Fit process completed after 98.96584701538086 seconds. Total datapoints fitted: 41123.
# Average time per datapoint: 0.002406581402509079
#
#
# Fitting validation time augmentor: [--------------------------------------->] 100 %
#
# Fit process completed after 17.206379413604736 seconds. Total datapoints fitted: 3347.
# Average time per datapoint: 0.005140836394862485
#
#
# Fitting test time augmentor: [--------------------------------------->] 100 %
#
# Fit process completed after 11.698127508163452 seconds. Total datapoints fitted: 2231.
# Average time per datapoint: 0.005243445767890386
#
#
# Stage one loading training set, timeAug: [--------------------------------------->] 100 %
#
# Stage one loading validation set, timeAug: [--------------------------------------->] 100 %
#
# Stage one loading test set, timeAug: [--------------------------------------->] 100 %
#
# Fit process of normalizer skipped as unecessary
#
#
# Stage one loading noise set, timeAug: [--------------------------------------->] 100 %
#
# Stage two loading noise set, labels and normalize scaler: [--------------------------------------->] 100 %
#
# Fitting noise augmentor: [--------------------------------------->] 100 %
#
#
#
# Stage two loading training set, labels and normalize scaler: [--------------------------------------->] 100 %
#
# Stage two loading validation set, labels and normalize scaler: [--------------------------------------->] 100 %
#
# Stage two loading test set, labels and normalize scaler: [--------------------------------------->] 100 %
#
#
#
# Completed loading to RAM
# Time elapsed to completion of load_to_ram_earth_explo_only: 0:03:49.773016

# %%
use_tensorboard = True
use_liveplots = False
use_custom_callback = True
use_early_stopping = True
start_from_scratch = False
use_reduced_lr = True
log_data = True

beta = 2

def clear_tensorboard_dir():
        import os
        import shutil
        path = f"{base_dir}/Tensorboard_dir/fit"
        files = os.listdir(path)
        print(files)
        for f in files:
            shutil.rmtree(os.path.join(path,f))
if use_tensorboard:
    clear_tensorboard_dir()

"""
modelTrain = TrainSingleModelRam(noiseAug, helper,
                              loadData, model_type, num_channels, use_tensorboard, use_liveplots,
                              use_custom_callback, use_early_stopping, use_reduced_lr, ramLoader,
                              log_data = log_data, 
                              start_from_scratch = start_from_scratch, beta = beta)
"""
### CNN grow double params
params = {    
    'batch_size': 256,
    'cnn_activation': 'relu',
    'dense_activation': 'relu',
    'dropout_T_bn_F': True,
    'dropout_rate': 0.001,
    'epochs': 100,
    'filter_size': 72,
    'first_dense_units': 254,
    'growth_sequence': [1, 4, 8],
    'l1_r': 0.0,
    'l2_r': 0.001,
    'learning_rate': 0.0001,
    'num_filters': 78,
    'num_layers': 3,
    'optimizer': 'adam',
    'output_layer_activation': 'sigmoid',
    'padding': 'same',
    'second_dense_units': 234,
    'use_layerwise_dropout_batchnorm': True
}
#model = modelTrain.run(x_train, y_train, x_val, y_val, x_test, y_test, 16, 15, evaluate_train = True, evaluate_val = True, evaluate_test = True, meier_mode = False, **params)
# Out:
# ['20210506-161807', '20210506-161923']

# %%
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 6000, 3)]         0
# _________________________________________________________________
# conv1d (Conv1D)              (None, 6000, 78)          16926
# _________________________________________________________________
# activation (Activation)      (None, 6000, 78)          0
# _________________________________________________________________
# dropout (Dropout)            (None, 6000, 78)          0
# _________________________________________________________________
# max_pooling1d (MaxPooling1D) (None, 3000, 78)          0
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 3000, 312)         1752504
# _________________________________________________________________
# activation_1 (Activation)    (None, 3000, 312)         0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 3000, 312)         0
# _________________________________________________________________
# max_pooling1d_1 (MaxPooling1 (None, 1500, 312)         0
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 1500, 624)         14018160
# _________________________________________________________________
# activation_2 (Activation)    (None, 1500, 624)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1500, 624)         0
# _________________________________________________________________
# max_pooling1d_2 (MaxPooling1 (None, 750, 624)          0
# _________________________________________________________________
# flatten (Flatten)            (None, 468000)            0
# _________________________________________________________________
# dense (Dense)                (None, 254)               118872254
# _________________________________________________________________
# dense_1 (Dense)              (None, 234)               59670
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 235
# =================================================================
# Total params: 134,719,749
# Trainable params: 134,719,749
# Non-trainable params: 0
# _________________________________________________________________

# %%
conf, report, accuracy, precision, recall, fscore = helper.evaluate_generator(model, x_val, y_val, params["batch_size"],
                                                                             loadData.label_dict, num_channels, noiseAug,
                                                                             scaler_name, 2, plot_conf_matrix = True, plot_p_r_curve = True, beta = beta)
# Out:
# 2782 292 33 221
# ['explosion', 'earthquake']
# EE
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[2782,  292],
#        [  33,  221]], dtype=int32)>
#               precision    recall  f1-score   support
#
#    explosion       0.99      0.91      0.94      3074
#   earthquake       0.43      0.87      0.58       254
#
#     accuracy                           0.90      3328
#    macro avg       0.71      0.89      0.76      3328
# weighted avg       0.95      0.90      0.92      3328

# %%
accuracy, precision, recall, fscore
# Out:
# (0.90234375, 0.43079899999999999, 0.87007900000000005, 0.72269499999999998)

# %%
def load_model_ramGen(path):
    acc = tf.keras.metrics.BinaryAccuracy(name="binary_accuacy", dtype = None, threshold = 0.5)
    precision = helper.precision
    recall = helper.recall
    return tf.keras.models.load_model(model_path, custom_objects = {"accuracy" : acc,
                                                                    "precision": precision,
                                                                    "recall" : recall})

# %%
save_dir = '/media/tord/T7/Thesis_ssd/SavedModels/CNN'
model_name = 'CNN_EE_final'
model_path = f'{save_dir}/{model_name}'

#model.save(model_path)
model = helper.load_model(model_path)

# %%
predictions = helper.predict_RamGenerator(model, x_val, y_val, params["batch_size"], True, noiseAug, loadData.label_dict, 3)
rounded_predictions = np.rint(predictions)

# %%
def get_false_negative_indexes(rounded_predictions, y_test):
    false_negative_indexes = []
    for i in range(len(rounded_predictions)):
        if y_test[i] == 1 and rounded_predictions[i] == 0:
            false_negative_indexes.append(i)
    return false_negative_indexes

def get_false_positive_indexes(rounded_predictions, y_test):
    false_positive_indexes = []
    for i in range(len(rounded_predictions)):
        if y_test[i] == 0 and rounded_predictions[i] == 1:
            false_positive_indexes.append(i)
    return false_positive_indexes

def get_true_positive_indexes(rouneded_predictions, y_test):
    true_positive_indexes = []
    for i in range(len(rounded_predictions)):
        if y_test[i] == 1 and rounded_predictions[i] == 1:
            true_positive_indexes.append(i)
    return true_positive_indexes

def get_true_negative_indexes(rouneded_predictions, y_test):
    true_negative_indexes = []
    for i in range(len(rounded_predictions)):
        if y_test[i] == 0 and rounded_predictions[i] == 0:
            true_negative_indexes.append(i)
    return true_negative_indexes

# %%
false_negatives_indexes = get_false_negative_indexes(rounded_predictions, y_val)
false_positives_indexes = get_false_positive_indexes(rounded_predictions, y_val)
true_negative_indexes = get_true_negative_indexes(rounded_predictions, y_val)
true_positive_indexes = get_true_positive_indexes(rounded_predictions, y_val)

# %% [markdown]
# # True Positives

# %%
import pprint
i = 0
pp = pprint.PrettyPrinter(indent = 4)

# %%
index = true_positive_indexes[i]
original_trace, sample_info = handler.path_to_trace(val_ds[index][0])
transformed_trace = x_val[index]
print(f"Predicted label: {predictions[index]}, Correct: {y_val[index]}")
print("Transformed")
helper.plot_event(transformed_trace, sample_info)
helper.plot_event(original_trace, sample_info)
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(sample_info)
i += 1
# Out:
# Predicted label: [ 0.99999964], Correct: [1]
# Transformed
# /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/obspy/imaging/util.py:275: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/obspy/imaging/waveform.py:820: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# {   'analyst_pick_time': None,
#     'az_to_arces': 162.11028823239158,
#     'baz_to_arces': 348.5501326700314,
#     'dist_to_arces': 853.5922704788013,
#     'est_arrivaltime_arces': '2010-10-02 01:36:58.340000',
#     'event_type': 'earthquake',
#     'event_type_certainty': 'known',
#     'magnitude_dist_ratio': 0.0037043446963576122,
#     'magnitude_sqrtdist_ratio': 0.10822725132739336,
#     'magnitudes': [   {   'mag': 3.162,
#                           'magnitude_type': 'Mb',
#                           'origin_id': 'smi:local/0c393f40-54e0-47fe-8f78-b31635a00271',
#                           'resource_id': 'smi:local/4c1f4342-fe33-455d-be3f-9cc09673ce18'},
#                       {   'mag': 3.2,
#                           'magnitude_type': 'Ml',
#                           'origin_id': 'smi:local/0c393f40-54e0-47fe-8f78-b31635a00271',
#                           'resource_id': 'smi:local/9e7afb3c-ba7e-4926-857f-0ee862501626'}],
#     'origins': [   {   'arrivals': [   {   'azimuth': 289.90144,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/efe93c92-f863-417a-aa23-a10cfb630d59',
#                                                                'text': 'ARID=26275'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Sn',
#                                            'pick_id': 'smi:local/8bf532f4-8432-4a7a-b283-9a8689f3fe0d',
#                                            'resource_id': 'smi:local/fa20ac59-9578-47de-aeb5-93bb046dfa8b',
#                                            'time_residual': -1.0030668},
#                                        {   'azimuth': 289.90144,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/1786a8de-c4c0-458a-a419-8ecc228e37e4',
#                                                                'text': 'ARID=26276'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Lg',
#                                            'pick_id': 'smi:local/2461e8fa-576d-42d1-8226-1a711c2aa25a',
#                                            'resource_id': 'smi:local/8aac6265-6080-4d23-83a9-547f3a9daebf',
#                                            'time_residual': -0.13668318},
#                                        {   'azimuth': 289.90144,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/41fac8bd-1165-4c33-b937-369c334af432',
#                                                                'text': 'ARID=26277'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Pn',
#                                            'pick_id': 'smi:local/1a4ef432-ff3d-4e3e-a203-01c548ba3ecb',
#                                            'resource_id': 'smi:local/16b5deaf-42f9-43f0-9c40-ab18ff71e6b0',
#                                            'time_residual': 0.28506476},
#                                        {   'azimuth': 93.072779,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/4325b93c-de67-45f4-bc81-38fea6d6bef8',
#                                                                'text': 'ARID=26278'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Lg',
#                                            'pick_id': 'smi:local/9c335581-c582-4531-9b6c-3779e5a65a8e',
#                                            'resource_id': 'smi:local/0bc571b2-c468-498e-bf4f-a14f636cff84',
#                                            'time_residual': -0.36535102},
#                                        {   'azimuth': 93.072779,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/0ad718c2-5bbe-4042-8c6a-1ffc6ca1fb85',
#                                                                'text': 'ARID=26279'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Pg',
#                                            'pick_id': 'smi:local/183f20f6-3b60-4b5d-81af-2c88d11fcf4b',
#                                            'resource_id': 'smi:local/f8451938-a16f-4cc7-bbd6-f917cf313fb4',
#                                            'time_residual': 0.085692162},
#                                        {   'azimuth': 140.7542,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/397d9b84-0c4e-4534-a888-393be7ce39f9',
#                                                                'text': 'ARID=26280'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Lg',
#                                            'pick_id': 'smi:local/04f493f1-0416-45a6-b5dd-f935fca8450e',
#                                            'resource_id': 'smi:local/5adc8070-b9ff-454e-ad96-4e7b24945c87',
#                                            'time_residual': -1.4640546},
#                                        {   'azimuth': 140.7542,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/2fb16250-ea18-4810-87a9-520f913c18e2',
#                                                                'text': 'ARID=26281'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Pg',
#                                            'pick_id': 'smi:local/77f39634-9e7b-4b17-a651-ce790a1be4c1',
#                                            'resource_id': 'smi:local/fd0bf9b9-803d-4837-a15d-9d2e5235d737',
#                                            'time_residual': 0.33639005},
#                                        {   'azimuth': 341.79229,
#                                            'backazimuth_residual': -8.3573361,
#                                            'comments': [   {   'resource_id': 'smi:local/e0ae056d-bbc4-4d4e-abee-ec7918959ed6',
#                                                                'text': 'ARID=4930986'}],
#                                            'horizontal_slowness_residual': 1.222424,
#                                            'phase': 'Pn',
#                                            'pick_id': 'smi:local/6f8b57e9-0e84-4157-b50f-a1dbc0f0866c',
#                                            'resource_id': 'smi:local/e5eb60e6-1e63-4b40-95ac-7fd0b842c818',
#                                            'time_residual': -1.9366549},
#                                        {   'azimuth': 140.7542,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/d4f0b127-2724-4931-a93b-594a2503acd8',
#                                                                'text': 'ARID=26282'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Pn',
#                                            'pick_id': 'smi:local/1fff79a4-e2e9-4859-86e5-f5aeb2516291',
#                                            'resource_id': 'smi:local/896b6e7d-e29a-48b5-b60b-a6c7ca3c537a',
#                                            'time_residual': -0.57207873},
#                                        {   'azimuth': 348.54795,
#                                            'backazimuth_residual': 3.3620464,
#                                            'comments': [   {   'resource_id': 'smi:local/8fce6ace-824d-4f49-adac-d8d09d97adba',
#                                                                'text': 'ARID=4931798'}],
#                                            'horizontal_slowness_residual': -1.2628718,
#                                            'phase': 'Pn',
#                                            'pick_id': 'smi:local/9fb49ac9-f7ea-4dff-b6fd-7524409981f6',
#                                            'resource_id': 'smi:local/4d332710-b1e1-44a5-bd78-932b82dfc6d2',
#                                            'time_residual': 0.80204138},
#                                        {   'azimuth': 358.9381,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/2f49a165-2f90-4091-92f3-23d4f54a1b96',
#                                                                'text': 'ARID=26274'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Lg',
#                                            'pick_id': 'smi:local/fd736e06-9d18-4cd3-ac86-ffaa9df360e9',
#                                            'resource_id': 'smi:local/45136fa9-93df-46e8-8f82-fa7d9905c362',
#                                            'time_residual': 1.098659},
#                                        {   'azimuth': 155.85762,
#                                            'backazimuth_residual': -5.5976161,
#                                            'comments': [   {   'resource_id': 'smi:local/ba3e5091-912a-45fe-a5e3-e432b2c27bfd',
#                                                                'text': 'ARID=4932055'}],
#                                            'horizontal_slowness_residual': 3.2260499,
#                                            'phase': 'Pn',
#                                            'pick_id': 'smi:local/1869a25f-6e7a-4f0b-93cb-e515d7175e6a',
#                                            'resource_id': 'smi:local/97c97023-d982-49fe-b3d7-e6525856620a',
#                                            'time_residual': 0.76342423},
#                                        {   'azimuth': 155.85762,
#                                            'backazimuth_residual': 9.3988209,
#                                            'comments': [   {   'resource_id': 'smi:local/2238a946-ff68-4891-a312-defe5f7b573f',
#                                                                'text': 'ARID=4932058'}],
#                                            'horizontal_slowness_residual': -11.251567,
#                                            'phase': 'Lg',
#                                            'pick_id': 'smi:local/6b3194c7-56f1-4aa2-a253-96ee55a0a5a1',
#                                            'resource_id': 'smi:local/b60ef3a6-b956-4e04-b77a-2c767d2586c6',
#                                            'time_residual': -0.61666907},
#                                        {   'azimuth': 348.54795,
#                                            'backazimuth_residual': 0.66774839,
#                                            'comments': [   {   'resource_id': 'smi:local/e66b00b6-d362-4a30-a8e0-f85cacc74947',
#                                                                'text': 'ARID=4931814'}],
#                                            'horizontal_slowness_residual': -5.3617984,
#                                            'phase': 'Sn',
#                                            'pick_id': 'smi:local/eb8c4a16-2770-4c5b-9da0-2bfa0206e153',
#                                            'resource_id': 'smi:local/8e0f4bb3-a19f-4dd4-b2d0-d8026c0ceff2',
#                                            'time_residual': -3.5237044}],
#                        'comments': [   {   'resource_id': 'smi:local/e6262f90-b174-4a68-9690-7809e15545f7',
#                                            'text': 'orid: 13987'}],
#                        'creation_info': {   'agency_id': 'NORSAR',
#                                             'author': 'ARS:berit',
#                                             'creation_time': '2010-10-05T12:09:02.000000Z'},
#                        'depth': 13.148503,
#                        'depth_errors': {'uncertainty': 11.679775},
#                        'latitude': 76.941792,
#                        'longitude': 18.798994,
#                        'quality': {   'associated_phase_count': 14,
#                                       'used_phase_count': 14},
#                        'resource_id': 'smi:local/0c393f40-54e0-47fe-8f78-b31635a00271',
#                        'time': '2010-10-02T01:34:47.018570Z',
#                        'time_errors': {'uncertainty': 1.2013186}}],
#     'picks': [   {   'backazimuth': 351.91,
#                      'backazimuth_errors': {'uncertainty': 0.08},
#                      'horizontal_slowness': 12.46,
#                      'horizontal_slowness_errors': {'uncertainty': 0.98},
#                      'phase_hint': 'Pn',
#                      'resource_id': 'smi:local/9fb49ac9-f7ea-4dff-b6fd-7524409981f6',
#                      'time': '2010-10-02T01:36:37.800000Z',
#                      'waveform_id': {   'channel_code': 'FD25',
#                                         'station_code': 'ARCES'}},
#                  {   'backazimuth': 349.2157,
#                      'backazimuth_errors': {'uncertainty': 4.196096},
#                      'horizontal_slowness': 19.273589,
#                      'horizontal_slowness_errors': {'uncertainty': 1.411199},
#                      'phase_hint': 'Sn',
#                      'resource_id': 'smi:local/eb8c4a16-2770-4c5b-9da0-2bfa0206e153',
#                      'time': '2010-10-02T01:37:57.500000Z',
#                      'waveform_id': {   'channel_code': 'FT25',
#                                         'station_code': 'ARCES'}}],
#     'resource_id': 'smi:local/f87017d4-eca6-4da2-9e1e-8c90d92f742c',
#     'trace_stats': {   'channels': [   'P-beam, vertical',
#                                        'S-beam, transverse',
#                                        'S-beam, radial'],
#                        'sampling_rate': 40.0,
#                        'starttime': '2010-10-02T01:35:58.350000Z',
#                        'station': 'ARCES beam'}}

# %% [markdown]
# # False Positives

# %%
j = 0

# %%
# Plotting false negative
index = false_positives_indexes[j]
original_trace, sample_info = handler.path_to_trace(val_ds[index][0])
transformed_trace = x_val[index]
print(f"Predicted label: {predictions[index]}, Correct: {y_val[index]}")
print("Transformed")
print(j)
helper.plot_event(transformed_trace, sample_info)
helper.plot_event(original_trace, sample_info)
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(sample_info)
j += 1
# Out:
# Predicted label: [ 0.9296626], Correct: [0]
# Transformed
# 25
# /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/obspy/imaging/util.py:275: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/obspy/imaging/waveform.py:820: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# {   'analyst_pick_time': None,
#     'az_to_arces': 307.3410084843237,
#     'baz_to_arces': 119.8773322809963,
#     'dist_to_arces': 392.6372974438652,
#     'est_arrivaltime_arces': '1995-02-26 06:39:45.105000',
#     'event_type': 'explosion',
#     'event_type_certainty': 'known',
#     'magnitude_dist_ratio': 0.007640639387879105,
#     'magnitude_sqrtdist_ratio': 0.15139986183493467,
#     'magnitudes': [   {   'creation_info': {'agency_id': 'HEL'},
#                           'mag': 3.0,
#                           'mag_errors': {'uncertainty': 0.0},
#                           'magnitude_type': 'MA',
#                           'origin_id': 'smi:local/e4babe69-d89f-4c50-ba34-44ea7101e9a9',
#                           'resource_id': 'smi:local/724b13a4-d9bf-4388-86c5-34fdb418c020',
#                           'station_count': 4}],
#     'origins': [   {   'creation_info': {'agency_id': 'HEL'},
#                        'depth': 0.0,
#                        'latitude': 67.577,
#                        'latitude_errors': {'uncertainty': 2.3},
#                        'longitude': 33.526,
#                        'longitude_errors': {'uncertainty': 2.9},
#                        'resource_id': 'smi:local/e4babe69-d89f-4c50-ba34-44ea7101e9a9',
#                        'time': '1995-02-26T06:38:44.700000Z',
#                        'time_errors': {'uncertainty': 0.5}}],
#     'preferred_magnitude_id': 'smi:local/724b13a4-d9bf-4388-86c5-34fdb418c020',
#     'preferred_origin_id': 'smi:local/e4babe69-d89f-4c50-ba34-44ea7101e9a9',
#     'resource_id': 'smi:local/f7be0731-e09a-43f5-ab13-86fa943fbe6d',
#     'trace_stats': {   'channels': [   'P-beam, vertical',
#                                        'S-beam, transverse',
#                                        'S-beam, radial'],
#                        'sampling_rate': 40.0,
#                        'starttime': '1995-02-26T06:38:45.093587Z',
#                        'station': 'ARCES beam'}}

# %% [markdown]
# # True Negatives

# %%
k = 0

# %%
# Plotting false negative
index = true_negative_indexes[k]
original_trace, sample_info = handler.path_to_trace(val_ds[index][0])
transformed_trace = x_val[index]
print(f"Predicted label: {predictions[index]}, Correct: {y_val[index]}")
print("Transformed")
helper.plot_event(transformed_trace, sample_info)
helper.plot_event(original_trace, sample_info)
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(sample_info)
k += 1
# Out:
# Predicted label: [ 0.0001394], Correct: [0]
# Transformed
# /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/obspy/imaging/util.py:275: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/obspy/imaging/waveform.py:820: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# {   'analyst_pick_time': None,
#     'az_to_arces': 45.69263987668042,
#     'baz_to_arces': 230.5136751291478,
#     'comments': [   {   'creation_info': {'author': 'general'},
#                         'resource_id': 'smi:local/550dd27b-2038-4030-bdb3-f5d50affc880',
#                         'text': 'FULLY AUTOMATIC LOCATION'},
#                     {   'creation_info': {'author': 'mining area'},
#                         'resource_id': 'smi:local/57fae300-3a52-48f9-bef0-55042668b6ad',
#                         'text': 'MINING AREA: KIRUNA  6KM'}],
#     'dist_to_arces': 282.0149084599872,
#     'est_arrivaltime_arces': '2012-04-05 12:05:23.486000',
#     'event_type': 'explosion',
#     'event_type_certainty': 'known',
#     'magnitude_dist_ratio': 0.004964276561281988,
#     'magnitude_sqrtdist_ratio': 0.08336658314813426,
#     'magnitudes': [   {   'creation_info': {'agency_id': 'HEL'},
#                           'mag': 1.4,
#                           'mag_errors': {'uncertainty': 0.2},
#                           'magnitude_type': 'ML',
#                           'origin_id': 'smi:local/8b8e10c9-8a43-4605-9ac3-4eb93763d75c',
#                           'resource_id': 'smi:local/0512041a-2215-43c0-85ee-fa34e58bf9a7',
#                           'station_count': 8}],
#     'origins': [   {   'creation_info': {'agency_id': 'HEL'},
#                        'depth': 0.0,
#                        'evaluation_mode': 'automatic',
#                        'latitude': 67.84,
#                        'latitude_errors': {'uncertainty': 1.5},
#                        'longitude': 20.336,
#                        'longitude_errors': {'uncertainty': 7.3},
#                        'region': 'KIRUNA',
#                        'resource_id': 'smi:local/8b8e10c9-8a43-4605-9ac3-4eb93763d75c',
#                        'time': '2012-04-05T12:04:40.100000Z',
#                        'time_errors': {'uncertainty': 0.3}}],
#     'preferred_magnitude_id': 'smi:local/0512041a-2215-43c0-85ee-fa34e58bf9a7',
#     'preferred_origin_id': 'smi:local/8b8e10c9-8a43-4605-9ac3-4eb93763d75c',
#     'resource_id': 'smi:local/b565cd1a-63e0-4b7b-a193-aebbed662bd5',
#     'trace_stats': {   'channels': [   'P-beam, vertical',
#                                        'S-beam, transverse',
#                                        'S-beam, radial'],
#                        'sampling_rate': 40.0,
#                        'starttime': '2012-04-05T12:04:23.475000Z',
#                        'station': 'ARCES beam'}}

# %% [markdown]
# # False Negatives

# %%
m = 0

# %%
# Plotting false negative
index = false_negatives_indexes[m]
original_trace, sample_info = handler.path_to_trace(val_ds[index][0])
transformed_trace = x_val[index]
print(f"Predicted label: {predictions[index]}, Correct: {y_val[index]}")
print("Transformed")
print(m)
helper.plot_event(transformed_trace, sample_info)
helper.plot_event(original_trace, sample_info)
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(sample_info)
m += 1
# Out:
# Predicted label: [ 0.32859182], Correct: [1]
# Transformed
# 20
# /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/obspy/imaging/util.py:275: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small')
# /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/obspy/imaging/waveform.py:820: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 30.
#   plt.setp(ax.get_xticklabels(), fontsize='small',
# {   'analyst_pick_time': None,
#     'az_to_arces': 305.5518032260843,
#     'baz_to_arces': 117.90761179157127,
#     'dist_to_arces': 392.7746037412052,
#     'est_arrivaltime_arces': '2014-11-02 08:53:26.086000',
#     'event_type': 'earthquake',
#     'event_type_certainty': 'known',
#     'magnitude_dist_ratio': 0.005636820657220445,
#     'magnitude_sqrtdist_ratio': 0.11171356647733552,
#     'magnitudes': [   {   'mag': 2.214,
#                           'magnitude_type': 'Mb',
#                           'origin_id': 'smi:local/ebbec781-081c-46bb-ab78-1e5ef2bf45cb',
#                           'resource_id': 'smi:local/dba264f6-cfec-40db-aaba-07415dc6a781'},
#                       {   'mag': 2.16,
#                           'magnitude_type': 'Ml',
#                           'origin_id': 'smi:local/ebbec781-081c-46bb-ab78-1e5ef2bf45cb',
#                           'resource_id': 'smi:local/a156432c-974a-4a0f-9aa0-bdd97010f50b'}],
#     'origins': [   {   'arrivals': [   {   'azimuth': 75.915184,
#                                            'backazimuth_residual': 0.0048160583,
#                                            'comments': [   {   'resource_id': 'smi:local/9b61fc2d-967b-4e39-a557-e567fc7b6afc',
#                                                                'text': 'ARID=3577915'}],
#                                            'horizontal_slowness_residual': -3.7815942,
#                                            'phase': 'Pg',
#                                            'pick_id': 'smi:local/8c8b33de-ebac-406b-b68e-6753824df0d7',
#                                            'resource_id': 'smi:local/454f8819-c52d-4678-bbbb-9846d25f7764',
#                                            'time_residual': -0.17865324},
#                                        {   'azimuth': 75.915184,
#                                            'backazimuth_residual': 0.84429606,
#                                            'comments': [   {   'resource_id': 'smi:local/8607e2a6-c614-4ada-bdbe-93f4d534285d',
#                                                                'text': 'ARID=3577917'}],
#                                            'horizontal_slowness_residual': 5.7569194,
#                                            'phase': 'Lg',
#                                            'pick_id': 'smi:local/4aefefbe-cb75-4468-b01c-b7977f31b593',
#                                            'resource_id': 'smi:local/fba9799d-1cda-48b8-969f-cf1afb18146b',
#                                            'time_residual': -0.13892592},
#                                        {   'azimuth': 75.915184,
#                                            'backazimuth_residual': -5.3552189,
#                                            'comments': [   {   'resource_id': 'smi:local/5fbaca7c-1d6d-4b14-95dc-28c0b70e5d8b',
#                                                                'text': 'ARID=3577918'}],
#                                            'horizontal_slowness_residual': 3.0279209,
#                                            'phase': 'Rg',
#                                            'pick_id': 'smi:local/192dce7d-e25f-49b6-b0de-44ac3e38302b',
#                                            'resource_id': 'smi:local/e92f60e4-2fa6-443f-a7bc-c64cbadce8d1',
#                                            'time_residual': 0.34404997},
#                                        {   'azimuth': 117.96618,
#                                            'backazimuth_residual': 4.9538182,
#                                            'comments': [   {   'resource_id': 'smi:local/774a0d5e-e5b7-4d3f-86fc-3bb7dd466285',
#                                                                'text': 'ARID=3577798'}],
#                                            'horizontal_slowness_residual': 0.88072002,
#                                            'phase': 'Pn',
#                                            'pick_id': 'smi:local/cc40606e-86a7-4683-8197-2d3a3b3919c0',
#                                            'resource_id': 'smi:local/36d1dc23-09de-4461-9eae-e4d3faa8ecf0',
#                                            'time_residual': 0.29271832},
#                                        {   'azimuth': 117.96618,
#                                            'backazimuth_residual': 6.0590002,
#                                            'comments': [   {   'resource_id': 'smi:local/f1d34ce4-43c8-4846-86c3-f4aec77c11f0',
#                                                                'text': 'ARID=3577800'}],
#                                            'horizontal_slowness_residual': -3.5155137,
#                                            'phase': 'Pg',
#                                            'pick_id': 'smi:local/386adade-3e74-4ba6-84c0-d5769be2c9e3',
#                                            'resource_id': 'smi:local/47a2857a-52d0-42ca-880f-fa85edb5f438',
#                                            'time_residual': 2.1787646},
#                                        {   'azimuth': 117.96618,
#                                            'backazimuth_residual': 7.5714962,
#                                            'comments': [   {   'resource_id': 'smi:local/d8a26873-8e9a-4eab-8428-a1a72e40f148',
#                                                                'text': 'ARID=3577803'}],
#                                            'horizontal_slowness_residual': -1.456214,
#                                            'phase': 'Sn',
#                                            'pick_id': 'smi:local/c940ad8a-d808-45c5-b6cf-8f7d5dd5318f',
#                                            'resource_id': 'smi:local/012628c4-c613-4150-a13e-8cc5211c6e30',
#                                            'time_residual': -0.85173837},
#                                        {   'azimuth': 117.96618,
#                                            'backazimuth_residual': -8.1109678,
#                                            'comments': [   {   'resource_id': 'smi:local/3ceff15e-cc77-4cfd-8e74-d3da3dce07db',
#                                                                'text': 'ARID=3577805'}],
#                                            'horizontal_slowness_residual': 2.73827,
#                                            'phase': 'Lg',
#                                            'pick_id': 'smi:local/eb23fe66-5603-4d61-801d-25ef3e95a793',
#                                            'resource_id': 'smi:local/0daf4b9f-f428-4715-b9ae-f7d2ef87820a',
#                                            'time_residual': -4.0963006},
#                                        {   'azimuth': 24.405609,
#                                            'backazimuth_residual': 4.304391,
#                                            'comments': [   {   'resource_id': 'smi:local/9aefa436-b774-45cc-85cf-84c50f5bfc84',
#                                                                'text': 'ARID=3577827'}],
#                                            'horizontal_slowness_residual': -3.9999814,
#                                            'phase': 'Lg',
#                                            'pick_id': 'smi:local/e9aafd82-0811-4426-89fc-67b7ce250769',
#                                            'resource_id': 'smi:local/6da6d9fe-a2d4-48a6-a4c4-bb0c3bc727fa',
#                                            'time_residual': -5.0903966},
#                                        {   'azimuth': 99.965709,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/31932d2f-e91e-4cda-9e0f-795ea7cdaca7',
#                                                                'text': 'ARID=46565'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Lg',
#                                            'pick_id': 'smi:local/8c996a05-ad85-4478-822a-59a91cd3bc48',
#                                            'resource_id': 'smi:local/a5923d9c-26b7-4966-bad1-8173ca721371',
#                                            'time_residual': -7.1512647},
#                                        {   'azimuth': 99.965709,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/77063c9b-53f0-4fac-bcef-fcebe69ece61',
#                                                                'text': 'ARID=46566'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Sn',
#                                            'pick_id': 'smi:local/5095eec2-7682-4525-99ab-d77992739ce6',
#                                            'resource_id': 'smi:local/d491f102-8b18-4787-8633-be5518247e53',
#                                            'time_residual': -3.6208896},
#                                        {   'azimuth': 99.965709,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/ab7c557a-63f0-4011-ac25-8d075d3df1e2',
#                                                                'text': 'ARID=46567'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Pn',
#                                            'pick_id': 'smi:local/8e2353d5-4d36-4dc6-bd4c-95ec65fc2b84',
#                                            'resource_id': 'smi:local/9038d1ed-cc5b-480c-bb81-651725a2ef0d',
#                                            'time_residual': -0.12361471},
#                                        {   'azimuth': 48.434049,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/b6a70658-f2d0-4df6-ba0b-cf1534e218a0',
#                                                                'text': 'ARID=46568'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Rg',
#                                            'pick_id': 'smi:local/08697de6-c6bc-42de-9ab4-c9282a81299e',
#                                            'resource_id': 'smi:local/85c2ffe5-bdc8-4eba-a6e0-2aae09800fbb',
#                                            'time_residual': 0.50664787},
#                                        {   'azimuth': 48.434049,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/4200059d-333d-45c5-a7cd-c58f3126f6ac',
#                                                                'text': 'ARID=46569'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Lg',
#                                            'pick_id': 'smi:local/30c5516e-4aa7-4175-8041-baa8ba6d6f75',
#                                            'resource_id': 'smi:local/c61165ff-b54d-47ce-b69b-183f719be2aa',
#                                            'time_residual': 0.10330751},
#                                        {   'azimuth': 48.434049,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/87b98cf3-a84b-45e5-8bb5-0071bc141ad7',
#                                                                'text': 'ARID=46570'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Pg',
#                                            'pick_id': 'smi:local/d128c9a3-1f4b-483d-86b8-7d188aa27899',
#                                            'resource_id': 'smi:local/1fbecd73-f088-4311-a165-999dc2c29463',
#                                            'time_residual': 0.0072076731}],
#                        'comments': [   {   'resource_id': 'smi:local/2d10fbc2-1455-4f6f-9ae5-cb503475b5bb',
#                                            'text': 'orid: 18007'}],
#                        'creation_info': {   'agency_id': 'NORSAR',
#                                             'author': 'ARS:berit',
#                                             'creation_time': '2014-11-11T08:38:46.000000Z'},
#                        'depth': 0.0,
#                        'depth_errors': {'uncertainty': -1.0},
#                        'latitude': 67.673575,
#                        'longitude': 33.717196,
#                        'quality': {   'associated_phase_count': 14,
#                                       'used_phase_count': 14},
#                        'resource_id': 'smi:local/ebbec781-081c-46bb-ab78-1e5ef2bf45cb',
#                        'time': '2014-11-02T08:52:25.659540Z',
#                        'time_errors': {'uncertainty': 1.3018107}}],
#     'picks': [   {   'backazimuth': 122.92,
#                      'backazimuth_errors': {'uncertainty': 0.06},
#                      'horizontal_slowness': 14.63,
#                      'horizontal_slowness_errors': {'uncertainty': 0.86},
#                      'phase_hint': 'Pn',
#                      'resource_id': 'smi:local/cc40606e-86a7-4683-8197-2d3a3b3919c0',
#                      'time': '2014-11-02T08:53:21.637500Z',
#                      'waveform_id': {   'channel_code': 'FF17',
#                                         'station_code': 'ARCES'}},
#                  {   'backazimuth': 124.02518,
#                      'backazimuth_errors': {'uncertainty': 2.032511},
#                      'horizontal_slowness': 14.713288,
#                      'horizontal_slowness_errors': {'uncertainty': 0.521912},
#                      'phase_hint': 'Pg',
#                      'resource_id': 'smi:local/386adade-3e74-4ba6-84c0-d5769be2c9e3',
#                      'time': '2014-11-02T08:53:30.375000Z',
#                      'waveform_id': {   'channel_code': 'FG16',
#                                         'station_code': 'ARCES'}},
#                  {   'backazimuth': 125.53768,
#                      'backazimuth_errors': {'uncertainty': 2.047285},
#                      'horizontal_slowness': 23.267066,
#                      'horizontal_slowness_errors': {'uncertainty': 0.831331},
#                      'phase_hint': 'Sn',
#                      'resource_id': 'smi:local/c940ad8a-d808-45c5-b6cf-8f7d5dd5318f',
#                      'time': '2014-11-02T08:54:02.437500Z',
#                      'waveform_id': {   'channel_code': 'FT36',
#                                         'station_code': 'ARCES'}},
#                  {   'backazimuth': 109.85521,
#                      'backazimuth_errors': {'uncertainty': 2.879303},
#                      'horizontal_slowness': 34.50828,
#                      'horizontal_slowness_errors': {'uncertainty': 1.733973},
#                      'phase_hint': 'Lg',
#                      'resource_id': 'smi:local/eb23fe66-5603-4d61-801d-25ef3e95a793',
#                      'time': '2014-11-02T08:54:12.825000Z',
#                      'waveform_id': {   'channel_code': 'FT28',
#                                         'station_code': 'ARCES'}}],
#     'resource_id': 'smi:local/442f0bd6-e953-46a6-939c-e5ff8be07c68',
#     'trace_stats': {   'channels': [   'P-beam, vertical',
#                                        'S-beam, transverse',
#                                        'S-beam, radial'],
#                        'sampling_rate': 40.0,
#                        'starttime': '2014-11-02T08:52:26.075000Z',
#                        'station': 'ARCES beam'}}
