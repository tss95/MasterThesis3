# %%
import numpy as np
import os
import sys
import pandas as pd
import seaborn as sns

import pylab as pl
import h5py

import tensorflow as tf
from tensorflow.keras import mixed_precision

os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
os.environ['CUDA_VISIBLE_DEVICES']="0" 

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)


from sklearn.metrics import confusion_matrix

base_dir = '/media/tord/T7/Thesis_ssd/MasterThesis3'
os.chdir(base_dir)
from Classes.DataProcessing.LoadData import LoadData
from Classes.DataProcessing.HelperFunctions import HelperFunctions
from Classes.DataProcessing.DataHandler import DataHandler
from Classes.Modeling.DynamicModels import DynamicModels
from Classes.Modeling.TrainSingleModelRam import TrainSingleModelRam
from Classes.DataProcessing.RamLoader import RamLoader
import json

import gc

import datetime
import re
from livelossplot import PlotLossesKeras
from GlobalUtils import GlobalUtils
from Classes.Modeling.CustomCallback import CustomCallback
from tensorflow.keras.callbacks import EarlyStopping
utils = GlobalUtils()

from tensorflow.keras.utils import GeneratorEnqueuer






import sys


helper = HelperFunctions()

tf.config.optimizer.set_jit(True)
mixed_precision.set_global_policy('mixed_float16')

load_args = {
    'earth_explo_only' : True,
    'noise_earth_only' : False,
    'noise_not_noise' : False,
    'downsample' : True,
    'upsample' : True,
    'frac_diff' : 1,
    'seed' : 1,
    'subsample_size' : 0.25,
    'balance_non_train_set' : False,
    'use_true_test_set' : False,
    'even_balance' : True
}
loadData = LoadData(**load_args)
train_ds, val_ds, test_ds = loadData.get_datasets()
noise_ds = loadData.noise_ds
handler = DataHandler(loadData)



model_type = "DENSE_baseline"
is_lstm = True
num_channels = 3    

use_time_augmentor = True
scaler_name = "standard"
use_noise_augmentor = False
filter_name = None
band_min = 2.0
band_max = 4.0
highpass_freq = 0.075


shutdown = False

num_classes = len(list(set(loadData.label_dict.values())))



ramLoader = RamLoader(loadData, 
                      handler, 
                      use_time_augmentor = use_time_augmentor, 
                      use_noise_augmentor = use_noise_augmentor, 
                      scaler_name = scaler_name,
                      filter_name = filter_name, 
                      band_min = band_min,
                      band_max = band_max,
                      highpass_freq = highpass_freq, 
                      load_test_set = True, 
                      meier_load = False)

x_train, y_train, x_val, y_val, x_test, y_test, noiseAug = ramLoader.load_to_ram()
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# WARNING:tensorflow:From /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/tensorflow/python/util/module_wrapper.py:49: The name tf.keras.layers.CuDNNLSTM is deprecated. Please use tf.compat.v1.keras.layers.CuDNNLSTM instead.
#
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: GeForce RTX 3090, compute capability 8.6
# 2 2
# Mapping train redundancy: : [--------------------------------------->] 100 %
#
# Mapping validation redundancy: : [--------------------------------------->] 100 %
#
# Mapping test redundancy: : [--------------------------------------->] 100 %
#
#
#
# Loaded explosion and earthquake dataset:
# Evenly balanced among classes in the train set.
# Distribution (Label: (counts, proportion)) of
# Train ds:
# earthquake: (20507, 0.4987)  |  explosion: (20616, 0.5013)
# Val ds:
# earthquake: (255, 0.0762)  |  explosion: (3092, 0.9238)
# Test ds:
# earthquake: (176, 0.0789)  |  explosion: (2055, 0.9211)
# Fitting noise set time augmentor: [--------------------------------------->] 100 %
#
# Fit process completed after 119.66247868537903 seconds. Total datapoints fitted: 21199.
# Average time per datapoint: 0.005644722802272703
#
#
# Fitting train time augmentor: [--------------------------------------->] 100 %
#
# Fit process completed after 150.60014963150024 seconds. Total datapoints fitted: 41123.
# Average time per datapoint: 0.0036621878178026953
#
#
# Fitting validation time augmentor: [--------------------------------------->] 100 %
#
# Fit process completed after 20.981311082839966 seconds. Total datapoints fitted: 3347.
# Average time per datapoint: 0.006268691688927387
#
#
# Fitting test time augmentor: [--------------------------------------->] 100 %
#
# Fit process completed after 14.5889151096344 seconds. Total datapoints fitted: 2231.
# Average time per datapoint: 0.006539182030315733
#
#
# Stage one loading training set, timeAug: [--------------------------------------->] 100 %
#
# Stage one loading validation set, timeAug: [--------------------------------------->] 100 %
#
# Stage one loading test set, timeAug: [--------------------------------------->] 100 %
#
# Fitting scaler progress: [------------------->] 100 %
#
# Stage two loading training set, labels and standard scaler: [--------------------------------------->] 100 %
#
# Stage two loading validation set, labels and standard scaler: [--------------------------------------->] 100 %
#
# Stage two loading test set, labels and standard scaler: [--------------------------------------->] 100 %
#
#
#
# Completed loading to RAM
# Time elapsed to completion of load_to_ram_earth_explo_only: 0:06:09.877744

# %%
loadData.label_dict
# Out:
# {'explosion': 0, 'earthquake': 1}

# %%
y_train
# Out:
# array([[0],
#        [0],
#        [0],
#        ...,
#        [0],
#        [0],
#        [0]], dtype=int8)

# %%
use_tensorboard = True
use_liveplots = False
use_custom_callback = True
use_early_stopping = False
start_from_scratch = False
use_reduced_lr = False
log_data = False

beta = 2

def clear_tensorboard_dir():
        import os
        import shutil
        path = f"{base_dir}/Tensorboard_dir/fit"
        files = os.listdir(path)
        print(files)
        for f in files:
            shutil.rmtree(os.path.join(path,f))
if use_tensorboard:
    clear_tensorboard_dir()


params = {
        "batch_size" : 128,
        "epochs" : 50,
        "learning_rate" : 0.01,
        "optimizer" : "sgd",
        "units" : 50,
        "dense_activation" : "relu",
        "output_layer_activation" : "sigmoid"
    }

modelTrain = TrainSingleModelRam(noiseAug, helper,
                              loadData, model_type, num_channels, use_tensorboard, use_liveplots,
                              use_custom_callback, use_early_stopping, use_reduced_lr, ramLoader,
                              log_data = log_data, 
                              start_from_scratch = start_from_scratch, beta = beta)

model = modelTrain.run(x_train, y_train, x_val, y_val, x_test, y_test, 16, 15, evaluate_train = True, evaluate_val = True, evaluate_test = True, meier_mode = False, **params)
# Out:
# ['20210522-155555']
# [   {'model_type': 'DENSE_baseline'},
#     {   'batch_size': 128,
#         'dense_activation': 'relu',
#         'epochs': 50,
#         'learning_rate': 0.01,
#         'optimizer': 'sgd',
#         'output_layer_activation': 'sigmoid',
#         'units': 50}]
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 6000, 3)]         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18000)             0
# _________________________________________________________________
# dense (Dense)                (None, 50)                900050
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 900,101
# Trainable params: 900,101
# Non-trainable params: 0
# _________________________________________________________________
# Utilizes 3328/3347 validation points
# Utilizes 41088/41123 training points
# -------------------------------------------------------------------
# Epoch 1/50
# 321/321 [==============================] - 4s 8ms/step - loss: 0.6944 - precision: 0.4862 - recall: 0.6163 - binary_accuracy: 0.4739 - val_loss: 0.6903 - val_precision: 0.1171 - val_recall: 0.0918 - val_binary_accuracy: 0.8822
# - val_f2: 0.0998
# Epoch 2/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6931 - precision: 0.6073 - recall: 0.0884 - binary_accuracy: 0.5141 - val_loss: 0.6895 - val_precision: 0.1445 - val_recall: 0.1000 - val_binary_accuracy: 0.8879
# - val_f2: 0.1095
# Epoch 3/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6925 - precision: 0.6474 - recall: 0.0955 - binary_accuracy: 0.5217 - val_loss: 0.6884 - val_precision: 0.1616 - val_recall: 0.0962 - val_binary_accuracy: 0.8948
# - val_f2: 0.1076
# Epoch 4/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6921 - precision: 0.6237 - recall: 0.2104 - binary_accuracy: 0.5243 - val_loss: 0.6843 - val_precision: 0.2747 - val_recall: 0.0674 - val_binary_accuracy: 0.9117
# - val_f2: 0.078
# Epoch 5/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6916 - precision: 0.7636 - recall: 0.0627 - binary_accuracy: 0.5261 - val_loss: 0.6895 - val_precision: 0.1492 - val_recall: 0.1781 - val_binary_accuracy: 0.8579
# - val_f2: 0.1768
# Epoch 6/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6913 - precision: 0.7128 - recall: 0.1341 - binary_accuracy: 0.5432 - val_loss: 0.6884 - val_precision: 0.1756 - val_recall: 0.1590 - val_binary_accuracy: 0.8753
# - val_f2: 0.1702
# Epoch 7/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6908 - precision: 0.7428 - recall: 0.1485 - binary_accuracy: 0.5510 - val_loss: 0.6893 - val_precision: 0.1611 - val_recall: 0.1991 - val_binary_accuracy: 0.8567
# - val_f2: 0.197
# Epoch 8/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6904 - precision: 0.7008 - recall: 0.2031 - binary_accuracy: 0.5562 - val_loss: 0.6896 - val_precision: 0.1506 - val_recall: 0.2158 - val_binary_accuracy: 0.8453
# - val_f2: 0.2016
# Epoch 9/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6901 - precision: 0.7123 - recall: 0.2109 - binary_accuracy: 0.5629 - val_loss: 0.6882 - val_precision: 0.1861 - val_recall: 0.1918 - val_binary_accuracy: 0.8708
# - val_f2: 0.1935
# Epoch 10/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6898 - precision: 0.7620 - recall: 0.1780 - binary_accuracy: 0.5630 - val_loss: 0.6896 - val_precision: 0.1522 - val_recall: 0.2185 - val_binary_accuracy: 0.8462
# - val_f2: 0.2053
# Epoch 11/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6898 - precision: 0.6716 - recall: 0.2829 - binary_accuracy: 0.5648 - val_loss: 0.6855 - val_precision: 0.2063 - val_recall: 0.1368 - val_binary_accuracy: 0.8897
# - val_f2: 0.1499
# Epoch 12/50
# 321/321 [==============================] - 2s 5ms/step - loss: 0.6893 - precision: 0.7842 - recall: 0.1595 - binary_accuracy: 0.5604 - val_loss: 0.6885 - val_precision: 0.1725 - val_recall: 0.1984 - val_binary_accuracy: 0.8645
# - val_f2: 0.1974
# Epoch 13/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6893 - precision: 0.7305 - recall: 0.2105 - binary_accuracy: 0.5672 - val_loss: 0.6880 - val_precision: 0.1837 - val_recall: 0.1963 - val_binary_accuracy: 0.8699
# - val_f2: 0.1966
# Epoch 14/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6890 - precision: 0.7681 - recall: 0.1897 - binary_accuracy: 0.5695 - val_loss: 0.6883 - val_precision: 0.1715 - val_recall: 0.1946 - val_binary_accuracy: 0.8642
# - val_f2: 0.1938
# Epoch 15/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6888 - precision: 0.7043 - recall: 0.2638 - binary_accuracy: 0.5700 - val_loss: 0.6868 - val_precision: 0.1915 - val_recall: 0.1767 - val_binary_accuracy: 0.8798
# - val_f2: 0.1834
# Epoch 16/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6887 - precision: 0.7715 - recall: 0.1783 - binary_accuracy: 0.5656 - val_loss: 0.6892 - val_precision: 0.1629 - val_recall: 0.2366 - val_binary_accuracy: 0.8504
# - val_f2: 0.2207
# Epoch 17/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6885 - precision: 0.7136 - recall: 0.2526 - binary_accuracy: 0.5730 - val_loss: 0.6861 - val_precision: 0.1936 - val_recall: 0.1697 - val_binary_accuracy: 0.8828
# - val_f2: 0.1774
# Epoch 18/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6882 - precision: 0.7290 - recall: 0.2338 - binary_accuracy: 0.5687 - val_loss: 0.6854 - val_precision: 0.1994 - val_recall: 0.1592 - val_binary_accuracy: 0.8882
# - val_f2: 0.1686
# Epoch 19/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6881 - precision: 0.7744 - recall: 0.1883 - binary_accuracy: 0.5669 - val_loss: 0.6880 - val_precision: 0.1736 - val_recall: 0.1967 - val_binary_accuracy: 0.8663
# - val_f2: 0.1948
# Epoch 20/50
# 321/321 [==============================] - 2s 5ms/step - loss: 0.6882 - precision: 0.7572 - recall: 0.2066 - binary_accuracy: 0.5709 - val_loss: 0.6877 - val_precision: 0.1766 - val_recall: 0.1958 - val_binary_accuracy: 0.8687
# - val_f2: 0.196
# Epoch 21/50
# 321/321 [==============================] - 2s 5ms/step - loss: 0.6877 - precision: 0.7802 - recall: 0.1933 - binary_accuracy: 0.5728 - val_loss: 0.6890 - val_precision: 0.1581 - val_recall: 0.2183 - val_binary_accuracy: 0.8513
# - val_f2: 0.2112
# Epoch 22/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6880 - precision: 0.7103 - recall: 0.2615 - binary_accuracy: 0.5730 - val_loss: 0.6863 - val_precision: 0.1822 - val_recall: 0.1735 - val_binary_accuracy: 0.8792
# - val_f2: 0.1794
# Epoch 23/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6872 - precision: 0.7625 - recall: 0.2192 - binary_accuracy: 0.5747 - val_loss: 0.6873 - val_precision: 0.1843 - val_recall: 0.1958 - val_binary_accuracy: 0.8720
# - val_f2: 0.1977
# Epoch 24/50
# 321/321 [==============================] - 2s 5ms/step - loss: 0.6874 - precision: 0.7673 - recall: 0.2114 - binary_accuracy: 0.5747 - val_loss: 0.6892 - val_precision: 0.1545 - val_recall: 0.2231 - val_binary_accuracy: 0.8465
# - val_f2: 0.2088
# Epoch 25/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6873 - precision: 0.7509 - recall: 0.2270 - binary_accuracy: 0.5760 - val_loss: 0.6886 - val_precision: 0.1582 - val_recall: 0.2128 - val_binary_accuracy: 0.8531
# - val_f2: 0.2054
# Epoch 26/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6873 - precision: 0.7524 - recall: 0.2268 - binary_accuracy: 0.5776 - val_loss: 0.6881 - val_precision: 0.1675 - val_recall: 0.2128 - val_binary_accuracy: 0.8597
# - val_f2: 0.2088
# Epoch 27/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6867 - precision: 0.7292 - recall: 0.2474 - binary_accuracy: 0.5752 - val_loss: 0.6853 - val_precision: 0.2034 - val_recall: 0.1776 - val_binary_accuracy: 0.8849
# - val_f2: 0.1859
# Epoch 28/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6871 - precision: 0.8015 - recall: 0.1854 - binary_accuracy: 0.5723 - val_loss: 0.6910 - val_precision: 0.1374 - val_recall: 0.2703 - val_binary_accuracy: 0.8128
# - val_f2: 0.2295
# Epoch 29/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6871 - precision: 0.7168 - recall: 0.2574 - binary_accuracy: 0.5726 - val_loss: 0.6902 - val_precision: 0.1504 - val_recall: 0.2642 - val_binary_accuracy: 0.8293
# - val_f2: 0.2319
# Epoch 30/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6869 - precision: 0.7059 - recall: 0.2777 - binary_accuracy: 0.5791 - val_loss: 0.6862 - val_precision: 0.2006 - val_recall: 0.1993 - val_binary_accuracy: 0.8789
# - val_f2: 0.2049
# Epoch 31/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6866 - precision: 0.7606 - recall: 0.2231 - binary_accuracy: 0.5765 - val_loss: 0.6873 - val_precision: 0.1718 - val_recall: 0.2066 - val_binary_accuracy: 0.8645
# - val_f2: 0.2044
# Epoch 32/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6865 - precision: 0.7693 - recall: 0.2222 - binary_accuracy: 0.5776 - val_loss: 0.6905 - val_precision: 0.1571 - val_recall: 0.2105 - val_binary_accuracy: 0.8522
# - val_f2: 0.1949
# Epoch 33/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6869 - precision: 0.6985 - recall: 0.2066 - binary_accuracy: 0.5606 - val_loss: 0.6926 - val_precision: 0.1377 - val_recall: 0.2269 - val_binary_accuracy: 0.8323
# - val_f2: 0.1987
# Epoch 34/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6870 - precision: 0.6482 - recall: 0.2639 - binary_accuracy: 0.5547 - val_loss: 0.6910 - val_precision: 0.1574 - val_recall: 0.2153 - val_binary_accuracy: 0.8504
# - val_f2: 0.1974
# Epoch 35/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6864 - precision: 0.6975 - recall: 0.2128 - binary_accuracy: 0.5632 - val_loss: 0.6926 - val_precision: 0.1401 - val_recall: 0.2269 - val_binary_accuracy: 0.8344
# - val_f2: 0.1997
# Epoch 36/50
# 321/321 [==============================] - 2s 5ms/step - loss: 0.6862 - precision: 0.6667 - recall: 0.2356 - binary_accuracy: 0.5577 - val_loss: 0.6925 - val_precision: 0.1384 - val_recall: 0.2214 - val_binary_accuracy: 0.8359
# - val_f2: 0.1972
# Epoch 37/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6863 - precision: 0.6986 - recall: 0.2224 - binary_accuracy: 0.5648 - val_loss: 0.6922 - val_precision: 0.1445 - val_recall: 0.2214 - val_binary_accuracy: 0.8404
# - val_f2: 0.1993
# Epoch 38/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6860 - precision: 0.6838 - recall: 0.2248 - binary_accuracy: 0.5612 - val_loss: 0.6917 - val_precision: 0.1522 - val_recall: 0.2214 - val_binary_accuracy: 0.8456
# - val_f2: 0.2017
# Epoch 39/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6856 - precision: 0.7064 - recall: 0.2155 - binary_accuracy: 0.5655 - val_loss: 0.6924 - val_precision: 0.1438 - val_recall: 0.2252 - val_binary_accuracy: 0.8386
# - val_f2: 0.2017
# Epoch 40/50
# 321/321 [==============================] - 2s 5ms/step - loss: 0.6858 - precision: 0.7036 - recall: 0.2193 - binary_accuracy: 0.5663 - val_loss: 0.6943 - val_precision: 0.1253 - val_recall: 0.2388 - val_binary_accuracy: 0.8149
# - val_f2: 0.2003
# Epoch 41/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6850 - precision: 0.6945 - recall: 0.2248 - binary_accuracy: 0.5679 - val_loss: 0.6962 - val_precision: 0.1114 - val_recall: 0.2730 - val_binary_accuracy: 0.7806
# - val_f2: 0.2117
# Epoch 42/50
# 321/321 [==============================] - 2s 5ms/step - loss: 0.6854 - precision: 0.6239 - recall: 0.2922 - binary_accuracy: 0.5537 - val_loss: 0.6905 - val_precision: 0.1567 - val_recall: 0.2070 - val_binary_accuracy: 0.8534
# - val_f2: 0.192
# Epoch 43/50
# 321/321 [==============================] - 2s 5ms/step - loss: 0.6847 - precision: 0.7140 - recall: 0.2179 - binary_accuracy: 0.5669 - val_loss: 0.6932 - val_precision: 0.1409 - val_recall: 0.2334 - val_binary_accuracy: 0.8326
# - val_f2: 0.2053
# Epoch 44/50
# 321/321 [==============================] - 2s 5ms/step - loss: 0.6850 - precision: 0.7065 - recall: 0.2241 - binary_accuracy: 0.5693 - val_loss: 0.6951 - val_precision: 0.1194 - val_recall: 0.2398 - val_binary_accuracy: 0.8071
# - val_f2: 0.1999
# Epoch 45/50
# 321/321 [==============================] - 2s 5ms/step - loss: 0.6851 - precision: 0.6465 - recall: 0.2726 - binary_accuracy: 0.5601 - val_loss: 0.6924 - val_precision: 0.1506 - val_recall: 0.2279 - val_binary_accuracy: 0.8422
# - val_f2: 0.2067
# Epoch 46/50
# 321/321 [==============================] - 2s 5ms/step - loss: 0.6850 - precision: 0.6888 - recall: 0.2454 - binary_accuracy: 0.5666 - val_loss: 0.6920 - val_precision: 0.1522 - val_recall: 0.2218 - val_binary_accuracy: 0.8447
# - val_f2: 0.2013
# Epoch 47/50
# 321/321 [==============================] - 2s 5ms/step - loss: 0.6846 - precision: 0.7037 - recall: 0.2423 - binary_accuracy: 0.5699 - val_loss: 0.6923 - val_precision: 0.1507 - val_recall: 0.2244 - val_binary_accuracy: 0.8431
# - val_f2: 0.2039
# Epoch 48/50
# 321/321 [==============================] - 2s 5ms/step - loss: 0.6846 - precision: 0.6745 - recall: 0.2425 - binary_accuracy: 0.5617 - val_loss: 0.6911 - val_precision: 0.1525 - val_recall: 0.2113 - val_binary_accuracy: 0.8504
# - val_f2: 0.194
# Epoch 49/50
# 321/321 [==============================] - 2s 6ms/step - loss: 0.6842 - precision: 0.6814 - recall: 0.2461 - binary_accuracy: 0.5617 - val_loss: 0.6928 - val_precision: 0.1401 - val_recall: 0.2205 - val_binary_accuracy: 0.8377
# - val_f2: 0.198
# Epoch 50/50
# 321/321 [==============================] - 2s 5ms/step - loss: 0.6838 - precision: 0.6941 - recall: 0.2358 - binary_accuracy: 0.5658 - val_loss: 0.6950 - val_precision: 0.1218 - val_recall: 0.2343 - val_binary_accuracy: 0.8110
# - val_f2: 0.1985
# Unsaved train eval:
# 17843 2755 15109 5381
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[17843,  2755],
#        [15109,  5381]], dtype=int32)>
#               precision    recall  f1-score   support
#
#    explosion       0.54      0.87      0.67     20598
#   earthquake       0.66      0.26      0.38     20490
#
#     accuracy                           0.57     41088
#    macro avg       0.60      0.56      0.52     41088
# weighted avg       0.60      0.57      0.52     41088
#
# Unsaved val eval:
# 2639 435 194 60
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[2639,  435],
#        [ 194,   60]], dtype=int32)>
#               precision    recall  f1-score   support
#
#    explosion       0.93      0.86      0.89      3074
#   earthquake       0.12      0.24      0.16       254
#
#     accuracy                           0.81      3328
#    macro avg       0.53      0.55      0.53      3328
# weighted avg       0.87      0.81      0.84      3328
#
# Unsaved test eval:
# 1679 330 126 41
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[1679,  330],
#        [ 126,   41]], dtype=int32)>
#               precision    recall  f1-score   support
#
#    explosion       0.93      0.84      0.88      2009
#   earthquake       0.11      0.25      0.15       167
#
#     accuracy                           0.79      2176
#    macro avg       0.52      0.54      0.52      2176
# weighted avg       0.87      0.79      0.82      2176

# %%
conf, report, accuracy, precision, recall, fscore = helper.evaluate_generator(model, x_val, y_val, params["batch_size"],
                                                                             loadData.label_dict, num_channels, noiseAug,
                                                                             scaler_name, 2, plot_conf_matrix = True, plot_p_r_curve = True, beta = beta)
# Out:
# 2639 435 194 60
# ['explosion', 'earthquake']
# EE
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[2639,  435],
#        [ 194,   60]], dtype=int32)>
#               precision    recall  f1-score   support
#
#    explosion       0.93      0.86      0.89      3074
#   earthquake       0.12      0.24      0.16       254
#
#     accuracy                           0.81      3328
#    macro avg       0.53      0.55      0.53      3328
# weighted avg       0.87      0.81      0.84      3328

# %%
accuracy, precision, recall, fscore
# Out:
# (0.81099759615384615, 0.121212, 0.23622000000000001, 0.198544)

# %%
import matplotlib as plt
plt.plotconfusion(y_val, 2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-7-c303d7c9f29b> in <module>
#       1 import matplotlib as plt
# ----> 2 plt.plotconfusion(y_val, 2)
#
# AttributeError: module 'matplotlib' has no attribute 'plotconfusion'
