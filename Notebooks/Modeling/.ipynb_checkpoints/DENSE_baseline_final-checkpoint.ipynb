# %%
import numpy as np
import os
import sys
import pandas as pd
import seaborn as sns

import pylab as pl
import h5py

import tensorflow as tf
from tensorflow.keras import mixed_precision

os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
os.environ['CUDA_VISIBLE_DEVICES']="0" 

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)


from sklearn.metrics import confusion_matrix

base_dir = '/media/tord/T7/Thesis_ssd/MasterThesis3'
os.chdir(base_dir)
from Classes.DataProcessing.LoadData import LoadData
from Classes.DataProcessing.HelperFunctions import HelperFunctions
from Classes.DataProcessing.DataHandler import DataHandler
from Classes.Modeling.DynamicModels import DynamicModels
from Classes.Modeling.TrainSingleModel import TrainSingleModel
from Classes.DataProcessing.RamLoader import RamLoader
from Classes.DataProcessing.ts_RamGenerator import modified_data_generator
import json

import gc

import datetime
import re
from livelossplot import PlotLossesKeras
from GlobalUtils import GlobalUtils
from Classes.Modeling.CustomCallback import CustomCallback
from tensorflow.keras.callbacks import EarlyStopping
utils = GlobalUtils()

from tensorflow.keras.utils import GeneratorEnqueuer






import sys


helper = HelperFunctions()

tf.config.optimizer.set_jit(True)
mixed_precision.set_global_policy('mixed_float16')

load_args = {
    'earth_explo_only' : True,
    'noise_earth_only' : False,
    'noise_not_noise' : False,
    'downsample' : True,
    'upsample' : True,
    'frac_diff' : 1,
    'seed' : 1,
    'subsample_size' : 0.25,
    'balance_non_train_set' : False,
    'use_true_test_set' : False,
    'even_balance' : True
}
loadData = LoadData(**load_args)
train_ds, val_ds, test_ds = loadData.get_datasets()
noise_ds = loadData.noise_ds
handler = DataHandler(loadData)



model_type = "DENSE_baseline"
is_lstm = True
num_channels = 3    

use_time_augmentor = True
scaler_name = "standard"
use_noise_augmentor = False
filter_name = None
band_min = 2.0
band_max = 4.0
highpass_freq = 0.075


shutdown = False

num_classes = len(list(set(loadData.label_dict.values())))



ramLoader = RamLoader(loadData, 
                      handler, 
                      use_time_augmentor = use_time_augmentor, 
                      use_noise_augmentor = use_noise_augmentor, 
                      scaler_name = scaler_name,
                      filter_name = filter_name, 
                      band_min = band_min,
                      band_max = band_max,
                      highpass_freq = highpass_freq, 
                      load_test_set = True, 
                      meier_load = False)

x_train, y_train, x_val, y_val, x_test, y_test, noiseAug = ramLoader.load_to_ram()
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# WARNING:tensorflow:From /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/tensorflow/python/util/module_wrapper.py:49: The name tf.keras.layers.CuDNNLSTM is deprecated. Please use tf.compat.v1.keras.layers.CuDNNLSTM instead.
#
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: GeForce RTX 3090, compute capability 8.6
# 2 3
# Balancing due to disguised labels.
# This functions barely works, and is a piece of shit that should not be trusted. Only works because noise has id: 0
# {'noise': 84799, 'earthquake': 84799, 'explosion': 82246}
# Mapping train redundancy: : [--------------------------------------->] 100 %
#
# Mapping validation redundancy: : [--------------------------------------->] 100 %
#
# Mapping test redundancy: : [--------------------------------------->] 100 %
#
#
#
# Loaded noise non-noise dataset.
# Evenly balanced among classes in the train set.
# Distribution (Label: (counts, proportion)) of
# Train ds:
# earthquake: (10631, 0.2526)  |  explosion: (10106, 0.2402)  |  noise: (21343, 0.5072)
# Val ds:
# earthquake: (242, 0.0371)  |  explosion: (3125, 0.4788)  |  noise: (3160, 0.4841)
# Test ds:
# earthquake: (184, 0.0423)  |  explosion: (2062, 0.4739)  |  noise: (2105, 0.4838)
# Fitting train time augmentor: [--------------------------------------->] 100 %
#
# Fit process completed after 31.3256516456604 seconds. Total datapoints fitted: 42080.
# Average time per datapoint: 0.0007444308851155038
#
#
# Fitting validation time augmentor: [--------------------------------------->] 100 %
#
# Fit process completed after 3.217491388320923 seconds. Total datapoints fitted: 6527.
# Average time per datapoint: 0.0004929510323764245
#
#
# Fitting test time augmentor: [--------------------------------------->] 100 %
#
# Fit process completed after 2.162919282913208 seconds. Total datapoints fitted: 4351.
# Average time per datapoint: 0.0004971085458315808
#
#
# Stage one loading training set, timeAug: [--------------------------------------->] 100 %
#
# Stage one loading validation set, timeAug: [--------------------------------------->] 100 %
#
# Stage one loading test set, timeAug: [--------------------------------------->] 100 %
#
# Fitting scaler progress: [------------------->] 100 %
#
# Stage two loading training set, labels and standard scaler: [--------------------------------------->] 100 %
#
# Stage two loading validation set, labels and standard scaler: [--------------------------------------->] 100 %
#
# Stage two loading test set, labels and standard scaler: [--------------------------------------->] 100 %
#
#
#
# Process took 0:01:35.600073 seconds.

# %%
use_tensorboard = True
use_liveplots = False
use_custom_callback = True
use_early_stopping = False
start_from_scratch = False
use_reduced_lr = False
log_data = False

beta = 3

def clear_tensorboard_dir():
        import os
        import shutil
        path = f"{base_dir}/Tensorboard_dir/fit"
        files = os.listdir(path)
        print(files)
        for f in files:
            shutil.rmtree(os.path.join(path,f))
if use_tensorboard:
    clear_tensorboard_dir()


modelTrain = TrainSingleModel(x_train, y_train, x_val, y_val, x_test, y_test, noiseAug, helper,
                              loadData, model_type, num_channels, use_tensorboard, use_liveplots,
                              use_custom_callback, use_early_stopping, use_reduced_lr, ramLoader,
                              log_data = log_data, results_df = None, results_file_name = None, index = None, 
                              start_from_scratch = start_from_scratch, beta = beta)
params = {
        "batch_size" : 128,
        "epochs" : 50,
        "learning_rate" : 0.01,
        "optimizer" : "sgd",
        "units" : 50,
        "dense_activation" : "relu",
        "output_layer_activation" : "sigmoid"
    }

model, _ = modelTrain.run(16, 15, evaluate_train = True, evaluate_val = True, evaluate_test = True, meier_mode = False, **params)
# Out:
# ['20210421-190954']
# [   {'model_type': 'DENSE_baseline'},
#     {   'batch_size': 128,
#         'dense_activation': 'softmax',
#         'epochs': 50,
#         'learning_rate': 0.01,
#         'optimizer': 'sgd',
#         'output_layer_activation': 'sigmoid',
#         'units': 50}]
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 6000, 3)]         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18000)             0
# _________________________________________________________________
# dense (Dense)                (None, 50)                900050
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 51
# =================================================================
# Total params: 900,101
# Trainable params: 900,101
# Non-trainable params: 0
# _________________________________________________________________
# Before starting enquers and generators
# ------------------RAM usage: 17033/36156 (Free: 6961)------------------
# Started enquers and generators
# ------------------RAM usage: 17033/36156 (Free: 6961)------------------
# Utilizes 6400/6527 validation points
# Utilizes 41984/42080 training points
# ---------------------------------------------------------------------------------
# Epoch 1/50
#   3/328 [..............................] - ETA: 8s - loss: 0.6944 - binary_accuracy: 0.4375 - precision: 0.4375 - recall: 1.0000  WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0059s vs `on_train_batch_end` time: 0.0070s). Check your callbacks.
# 328/328 [==============================] - 4s 7ms/step - loss: 0.6933 - binary_accuracy: 0.4919 - precision: 0.4907 - recall: 0.9151 - val_loss: 0.6933 - val_binary_accuracy: 0.4845 - val_precision: 1.0000 - val_recall: 3.0303e-04
# - val_f3: 0.0003
# Epoch 2/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6931 - binary_accuracy: 0.5104 - precision: 0.2781 - recall: 1.6177e-04 - val_loss: 0.6935 - val_binary_accuracy: 0.4845 - val_precision: 1.0000 - val_recall: 3.0303e-04
# - val_f3: 0.0003
# Epoch 3/50
# 328/328 [==============================] - 2s 6ms/step - loss: 0.6930 - binary_accuracy: 0.5087 - precision: 0.3592 - recall: 1.5933e-04 - val_loss: 0.6936 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 4/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5081 - precision: 0.3582 - recall: 1.5712e-04 - val_loss: 0.6936 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 5/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5095 - precision: 0.3571 - recall: 1.5533e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 6/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5080 - precision: 0.7477 - recall: 1.5312e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 7/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5089 - precision: 0.7457 - recall: 1.5134e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 8/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5090 - precision: 0.7437 - recall: 1.4950e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 9/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5083 - precision: 0.7416 - recall: 1.4760e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 10/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5079 - precision: 0.7396 - recall: 1.4577e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 11/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5085 - precision: 0.7376 - recall: 1.4414e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 12/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5077 - precision: 0.7356 - recall: 1.4236e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 13/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5080 - precision: 0.7335 - recall: 1.4075e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 14/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5080 - precision: 0.7315 - recall: 1.3915e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 15/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5071 - precision: 0.7295 - recall: 1.3747e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 16/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5090 - precision: 0.7275 - recall: 1.3618e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 17/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5088 - precision: 0.7254 - recall: 1.3468e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 18/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5089 - precision: 0.7234 - recall: 1.3324e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 19/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5085 - precision: 0.7214 - recall: 1.3177e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 20/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5097 - precision: 0.7194 - recall: 1.3050e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 21/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5092 - precision: 0.7173 - recall: 1.2908e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 22/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5099 - precision: 0.7153 - recall: 1.2781e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 23/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5094 - precision: 0.7133 - recall: 1.2644e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 24/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5087 - precision: 0.7112 - recall: 1.2507e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 25/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5077 - precision: 0.7092 - recall: 1.2368e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 26/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5077 - precision: 0.7072 - recall: 1.2240e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 27/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5086 - precision: 0.7052 - recall: 1.2124e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 28/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5085 - precision: 0.7031 - recall: 1.2002e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 29/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5082 - precision: 0.7011 - recall: 1.1879e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 30/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5085 - precision: 0.6991 - recall: 1.1764e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 31/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5067 - precision: 0.6971 - recall: 1.1631e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 32/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5068 - precision: 0.6950 - recall: 1.1516e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 33/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6931 - binary_accuracy: 0.5062 - precision: 0.6930 - recall: 1.1397e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 34/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6930 - binary_accuracy: 0.5067 - precision: 0.6910 - recall: 1.1289e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 35/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6931 - binary_accuracy: 0.5065 - precision: 0.6890 - recall: 1.1177e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 36/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6931 - binary_accuracy: 0.5052 - precision: 0.6869 - recall: 1.1059e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 37/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6931 - binary_accuracy: 0.5050 - precision: 0.6849 - recall: 1.0949e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 38/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6931 - binary_accuracy: 0.5065 - precision: 0.6829 - recall: 1.0854e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 39/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6931 - binary_accuracy: 0.5060 - precision: 0.6809 - recall: 1.0747e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 40/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6931 - binary_accuracy: 0.5058 - precision: 0.6788 - recall: 1.0643e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 41/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6931 - binary_accuracy: 0.5055 - precision: 0.6768 - recall: 1.0540e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 42/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6931 - binary_accuracy: 0.5050 - precision: 0.6748 - recall: 1.0436e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 43/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6931 - binary_accuracy: 0.5058 - precision: 0.6727 - recall: 1.0343e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 44/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6931 - binary_accuracy: 0.5062 - precision: 0.6707 - recall: 1.0248e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 45/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6931 - binary_accuracy: 0.5056 - precision: 0.6687 - recall: 1.0149e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 46/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6931 - binary_accuracy: 0.5045 - precision: 0.6667 - recall: 1.0046e-04 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 47/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6931 - binary_accuracy: 0.5050 - precision: 0.6646 - recall: 9.9552e-05 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 48/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6931 - binary_accuracy: 0.5061 - precision: 0.6626 - recall: 9.8692e-05 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 49/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6931 - binary_accuracy: 0.5051 - precision: 0.6606 - recall: 9.7723e-05 - val_loss: 0.6937 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Epoch 50/50
# 328/328 [==============================] - 2s 5ms/step - loss: 0.6931 - binary_accuracy: 0.5050 - precision: 0.6586 - recall: 9.6805e-05 - val_loss: 0.6938 - val_binary_accuracy: 0.4844 - val_precision: 0.0000e+00 - val_recall: 0.0000e+00
# - val_f3: 0.0
# Unsaved train eval:
# 21284 1 20697 2
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[21284,     1],
#        [20697,     2]], dtype=int32)>
#               precision    recall  f1-score   support
#
#        noise       0.51      1.00      0.67     21285
#    not_noise       0.67      0.00      0.00     20699
#
#     accuracy                           0.51     41984
#    macro avg       0.59      0.50      0.34     41984
# weighted avg       0.59      0.51      0.34     41984
#
# Unsaved val eval:
# 3100 0 3300 0
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[3100,    0],
#        [3300,    0]], dtype=int32)>
#               precision    recall  f1-score   support
#
#        noise       0.48      1.00      0.65      3100
#    not_noise       0.00      0.00      0.00      3300
#
#     accuracy                           0.48      6400
#    macro avg       0.24      0.50      0.33      6400
# weighted avg       0.23      0.48      0.32      6400
#
# Unsaved test eval:
# 2034 0 2190 0
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[2034,    0],
#        [2190,    0]], dtype=int32)>
#               precision    recall  f1-score   support
#
#        noise       0.48      1.00      0.65      2034
#    not_noise       0.00      0.00      0.00      2190
#
#     accuracy                           0.48      4224
#    macro avg       0.24      0.50      0.33      4224
# weighted avg       0.23      0.48      0.31      4224
# /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/sklearn/metrics/_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
conf, report, precision, recall, fscore, accuracy = helper.evaluate_generator(model, x_val, y_val, params["batch_size"],
                                                                             loadData.label_dict, num_channels, noiseAug,
                                                                             scaler_name, plot_conf_matrix = True, plot_p_r_curve = True)
# Out:
# 3100 0 3300 0
# ['noise', 'not_noise']
# 3N
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[3100,    0],
#        [3300,    0]], dtype=int32)>
#               precision    recall  f1-score   support
#
#        noise       0.48      1.00      0.65      3100
#    not_noise       0.00      0.00      0.00      3300
#
#     accuracy                           0.48      6400
#    macro avg       0.24      0.50      0.33      6400
# weighted avg       0.23      0.48      0.32      6400

# %%
fscore
# Out:
# 0.0

# %%
import matplotlib as plt
plt.plotconfusion(y_val, 2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-c303d7c9f29b> in <module>
#       1 import matplotlib as plt
# ----> 2 plt.plotconfusion(y_val, 2)
#
# AttributeError: module 'matplotlib' has no attribute 'plotconfusion'
