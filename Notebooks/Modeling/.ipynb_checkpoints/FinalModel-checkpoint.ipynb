# %%
import numpy as np
import os
import sys
import pandas as pd
import seaborn as sns

import pylab as pl
import h5py

import tensorflow as tf
from tensorflow.keras import mixed_precision
from sklearn.metrics import classification_report, precision_recall_fscore_support

os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
os.environ['CUDA_VISIBLE_DEVICES']="0" 

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)


from sklearn.metrics import confusion_matrix

base_dir = '/media/tord/T7/Thesis_ssd/MasterThesis3'
os.chdir(base_dir)
from Classes.DataProcessing.LoadData import LoadData
from Classes.DataProcessing.HelperFunctions import HelperFunctions
from Classes.DataProcessing.DataHandler import DataHandler
from Classes.Modeling.TrainSingleModelRam import TrainSingleModelRam
from Classes.DataProcessing.RamLoader import RamLoader

from GlobalUtils import GlobalUtils

utils = GlobalUtils()


import sys


helper = HelperFunctions()

tf.config.optimizer.set_jit(True)
mixed_precision.set_global_policy('mixed_float16')
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# WARNING:tensorflow:From /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/tensorflow/python/util/module_wrapper.py:49: The name tf.keras.layers.CuDNNLSTM is deprecated. Please use tf.compat.v1.keras.layers.CuDNNLSTM instead.
#
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: GeForce RTX 3090, compute capability 8.6

# %%
load_args = {
    'earth_explo_only' : False,
    'noise_earth_only' : False,
    'noise_not_noise' : False,
    'downsample' : True,
    'upsample' : True,
    'frac_diff' : 1,
    'seed' : 1,
    'subsample_size' : 0.25,
    'balance_non_train_set' : False,
    'use_true_test_set' : True,
    'even_balance' : False
}
loadData = LoadData(**load_args)
train_ds = loadData.train
test_ds = loadData.test
handler = DataHandler(loadData)
# Out:
# WARNING: You are using the true test set.
# If this is an error, please set use_true_test_set = False and reload the kernel
# Mapping train redundancy: : [--------------------------------------->] 100 %
#
# Mapping test redundancy: : [--------------------------------------->] 100 %
#
#
#
# Loaded true test set, accompanied by a train set for preprocessing fitting.
# Distribution (Label: (counts, proportion)) of
# Train ds:
# earthquake: (26527, 0.3371)  |  explosion: (25650, 0.3259)  |  noise: (26524, 0.337)
# Test ds:
# earthquake: (698, 0.0396)  |  explosion: (8365, 0.4742)  |  noise: (8579, 0.4863)

# %%
use_time_augmentor = True
scaler_name = "normalize"
use_noise_augmentor = True
filter_name = None
band_min = 2.0
band_max = 4.0
highpass_freq = 0.075


shutdown = False

num_classes = len(list(set(loadData.label_dict.values())))



ramLoader = RamLoader(loadData, 
                      handler, 
                      use_time_augmentor = use_time_augmentor, 
                      use_noise_augmentor = use_noise_augmentor, 
                      scaler_name = scaler_name,
                      filter_name = filter_name, 
                      band_min = band_min,
                      band_max = band_max,
                      highpass_freq = highpass_freq, 
                      load_test_set = True, 
                      meier_load = False)

x_test, y_test, noiseAug = ramLoader.load_to_ram()
# Out:
# Initializing loading of the test set
# Step 1: Fit augmentors and scalers on training data
# Fitting train time augmentor: [--------------------------------------->] 100 %
#
# Fit process completed after 388.12026357650757 seconds. Total datapoints fitted: 78701.
# Average time per datapoint: 0.00493157982206716
#
#
# Stage one loading training set, timeAug: [--------------------------------------->] 100 %
#
# Fit process of normalizer skipped as unecessary
#
#
# Stage two loading training set, labels and normalize scaler: [--------------------------------------->] 100 %
#
# Fitting noise augmentor: [--------------------------------------->] 100 %
#
# Step 2: Load and transform the test set, using the previously fitted scaler and augmentors
# Fitting test time augmentor: [--------------------------------------->] 100 %
#
# Fit process completed after 134.75371432304382 seconds. Total datapoints fitted: 17642.
# Average time per datapoint: 0.007638233438558203
#
#
# Stage one loading test set, timeAug: [--------------------------------------->] 100 %
#
# Stage two loading test set, labels and normalize scaler: [--------------------------------------->] 100 %
#
# Time elapsed to completion of load_to_ram_final_evaluation: 0:11:01.107270

# %%
from Classes.DataProcessing.RamGen import RamGen

# %%
# Path of the best performing model on Noise vs Not-Noise
save_dir_3n = '/media/tord/T7/Thesis_ssd/SavedModels/CNN'
model_name_3n = 'CNN_3N_final'
model_3n_path = f'{save_dir_3n}/{model_name_3n}'
# This model is trained with batch_size of 256
# Batch size will be 1 for predictions
print(model_3n_path)
model_3n = helper.load_model(model_3n_path)



# Path of the best performing model on Explosion vs Earthquake
save_dir_ee = '/media/tord/T7/Thesis_ssd/SavedModels/CNN'
model_name_ee = 'CNN_EE_final'
model_ee_path = f'{save_dir_ee}/{model_name_ee}'
# This model is trained with batch_size of 256
# Batch size will be 1 for predictions
model_ee = helper.load_model(model_ee_path)
# Out:
# /media/tord/T7/Thesis_ssd/SavedModels/CNN/CNN_3N_final

# %%
import time

def predict_final_model(loadData, model_3n, model_ee, test_traces, test_labels, noiseAug, num_channels_3n, num_channels_ee):
    # This function assumes data to be preprocessed with normalize scaler
    
    noise_not_noise_dict = loadData.noise_not_noise_dict()
    start = time.time()
    predictions_3n = helper.predict_RamGenerator(model_3n, test_traces, test_labels, 1, True, noiseAug, None, num_channels_3n, final_eval = True)
    print(f"Completed 3N predictions after f{round(time.time()-start)} seconds. Amount of predictions: {len(test_labels)}")
    print(f"Average time per datapoint: {(time.time() - start)/len(test_labels)}")
    rounded_3n_predictions = np.rint(predictions_3n)
    
    
    earth_explo_dict = loadData.earth_explo_dict()
    not_noise_traces, not_noise_labels = get_not_noise_traces_labels(predictions_3n, test_traces, test_labels, noise_not_noise_dict)
    ee_start = time.time()
    predictions_ee = helper.predict_RamGenerator(model_ee, not_noise_traces, not_noise_labels, 1, True, noiseAug, None, num_channels_ee, final_eval = True)
    print(f"Completed 3N predictions after f{round(time.time()-ee_start)} seconds. Amount of predictions: {len(test_labels)}")
    print(f"Average time per datapoint: {(time.time() - ee_start)/len(test_labels)}")
    rounded_ee_predictions = np.rint(predictions_ee)
    print(rounded_ee_predictions)
    
    # Converting the 3N predictions into string
    dict_3n = {'noise' : 0, 'not_noise' : 1}
    converted_3n_predictions = convert_predictions(rounded_3n_predictions, dict_3n)
    print(converted_3n_predictions)
    # We now have a list of ["noise", "not-noise"...]
    # We want to take the not-noise elements and convert them into their final predictions.
    # We can do this by using a list of indexes of the not noise elements, and replace them by their true final predictions.
    not_noise_indexes = get_not_noise_indexes(rounded_3n_predictions, noise_not_noise_dict)
    

    end = time.time()
    print(f"Prediction of {len(test_labels)} complete. Process took {round(end-start)} seconds")
    print(f"Average time per datapoint: {(end-start)/len(test_labels)}")
    return convert_ee_predictions(rounded_ee_predictions, earth_explo_dict, converted_3n_predictions, not_noise_indexes)
    
def get_not_noise_indexes(rounded_predictions, noise_not_noise_dict):
    not_noise_indexes = np.where(rounded_predictions == 1)[0]
    return not_noise_indexes
    
def get_not_noise_traces_labels(predictions, test_traces, test_labels, noise_not_noise_dict):
    rounded_predictions = np.rint(predictions)
    not_noise_indexes = get_not_noise_indexes(rounded_predictions, noise_not_noise_dict)
    not_noise_traces = test_traces[not_noise_indexes][:]
    not_noise_labels = test_labels[not_noise_indexes]
    return not_noise_traces, not_noise_labels

def convert_ee_predictions(rounded_predictions, label_dict, converted_3n_predictions, not_noise_indexes):
    final_predictions = converted_3n_predictions.copy()
    converted_ee_predictions = convert_predictions(rounded_predictions, label_dict)
    for idx, nn_index in enumerate(not_noise_indexes):
        final_predictions[nn_index] = converted_ee_predictions[idx]
    return final_predictions
    
def convert_predictions(rounded_predictions, label_dict):
    transformed_predictions = np.empty((rounded_predictions.shape), dtype=object)
    # Assumes that the dictionary is sorted by ascending values. Also that the key, value pair is unique
    keys = list(label_dict.keys())
    for idx, pred in enumerate(rounded_predictions):
        transformed_predictions[idx] =  keys[int(pred[0])]
    return transformed_predictions

def transform_true_labels(true_labels, final_dict):
    output = np.empty((len(true_labels)))
    for idx, lab in enumerate(true_labels):
        output[idx] = np.where(lab == 1)[0]
    return output

import matplotlib.pyplot as plt
def plot_confusion_matrix(conf, label_dict):
    fig = plt.figure()
    ax = fig.add_subplot(111)
    labels = list(label_dict.keys())
    for x in range(len(labels)):
        for y in range(len(labels)):
            ax.annotate(str(np.array(conf[x,y]).ravel()[0]), xy = (y, x), ha = 'center', va = 'center')
    print(labels)
    offset = 0.5
    width = height = len(labels)
    ax.set_xlim(-offset, width - offset)
    ax.set_ylim(-offset, height - offset)
    plt.title(f'Confusion matrix of the final classifier on the test set')
    #ax.set_xticklabels([''] + labels)
    #ax.set_yticklabels([''] + labels)
    ax.hlines(y=np.arange(height+1)- offset, xmin=-offset, xmax=width-offset, color  = "black")
    ax.vlines(x=np.arange(width+1) - offset, ymin=-offset, ymax=height-offset, color = "black")
    plt.xticks(range(width), labels)
    plt.yticks(range(height), labels)
    ax.invert_yaxis()
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.show()

def get_all_unidentified_by_type(type_int, predictions, y_test):
    index_list = []
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    final_preds = np.array([final_dict.get(x[0]) for x in test_pred])
    final_true = transform_true_labels(y_test, final_dict)
    for i in range(len(final_true)):
        if final_true[i] == type_int and final_true[i] != final_preds[i]:
            index_list.append(i)
    return index_list

def get_distance_distribution(ds):
    total = len(ds)
    all_dist = []
    for idx, path_label in enumerate(ds):
        path, label, _ = path_label
        dist = np.rint(handler.path_to_trace(path)[1].get('dist_to_arces'))
        all_dist.append(dist)
    return all_dist

    
def get_magnitude_distribution(ds):
    total = len(ds)
    all_mag = []
    for idx, path_label in enumerate(ds):
        path, label, _ = path_label
        mag = handler.path_to_trace(path)[1].get('magnitudes')[0]['mag']
        all_mag.append(mag)
    return all_mag

def get_msrdr_distribution(ds):
    total = len(ds)
    all_msrdr = []
    for idx, path_label in enumerate(ds):
        path, label, _ = path_label
        msrdr = handler.path_to_trace(path)[1].get('magnitude_sqrtdist_ratio')
        all_msrdr.append(msrdr)
    return all_msrdr    


def get_bins_count_pdf_cdf(dist, nr_bins, minimum, maximum):
    print(f"Max dist: {max(dist)}")
    print(f"Min dist: {min(dist)}")
    count, bins_count = np.histogram(dist, bins = nr_bins, range = (minimum, maximum))
    pdf = count / sum(count)
    cdf = np.cumsum(pdf)
    return bins_count, count, pdf, cdf

def plot_unidentified_and_original(pdf_o, pdf_u, bins_count_o, bins_count_u, counts_o, counts_u, width, type_int, title, xlabel, ylabel):
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    key_list = list(final_dict.keys())
    plt.bar(bins_count_o[1:], counts_o, width=width, color="blue", label=f"All {key_list[type_int]}s")
    plt.bar(bins_count_u[1:], counts_u, width=width, color="red", label=f"Correctly identified {key_list[type_int]}s")
    plt.legend()
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.rcParams['figure.figsize'] = [10, 8]
    plt.show()

    
def broken_plot_unidentified_and_original(pdf_o, pdf_u, bins_count_o, bins_count_u, counts_o, counts_u, width, type_int, low_max, high_max, title, xlabel, ylabel):
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    key_list = list(final_dict.keys())
    
    fig, (ax1, ax2) = plt.subplots(2,1, sharex=True, gridspec_kw={'height_ratios': [3, 1]})
    fig.subplots_adjust(hspace=0.01)
    # Plotting data on both axis:
    ax1.bar(bins_count_o[1:], counts_o, width = width, color = "blue", label=f"All {key_list[type_int]}s")
    ax2.bar(bins_count_o[1:], counts_o, width = width, color = "blue", label=f"All {key_list[type_int]}s")
    ax1.bar(bins_count_u[1:], counts_u, width = width, color = "red", label=f"Correctly identified {key_list[type_int]}s")
    ax2.bar(bins_count_u[1:], counts_u, width = width, color = "red", label=f"Correctly identified {key_list[type_int]}s")
    
    
    # Setting cutoff:
    ax1.set_ylim(low_max, high_max)
    ax2.set_ylim(0, low_max)
    
    ax1.spines['bottom'].set_visible(False)
    ax2.spines['top'].set_visible(False)
    ax2.xaxis.tick_bottom()
    ax2.yaxis.tick_left()
    ax1.yaxis.tick_left()
    ax2.spines['bottom'].set_visible(True)
    ax2.spines['left'].set_visible(True)
    ax1.spines['left'].set_visible(True)
    
    # Slant of cutoff markers
    d = 0.5
    kwargs = dict(marker = [(-1, -d),(1,d)], markersize = 12, 
                  linestyle ="none", color = 'k', mec = 'k', mew = 1, clip_on = False)
    ax1.plot([0,1], [0,0], transform=ax1.transAxes, **kwargs)
    ax2.plot([0,1], [1,1], transform=ax2.transAxes, **kwargs)
    plt.xlabel(xlabel)
    fig.text(0.04, 0.5, ylabel, va='center', rotation='vertical')
    fig.text(0.30, 0.9, title, va = 'center')
    ax1.legend(loc = 'best')
    plt.show()
    
          
def plot_distances_unid(predictions, y_test, test_ds, type_int):
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    key_list = list(final_dict.keys())
    unid = get_all_unidentified_by_type(type_int, predictions, y_test)
    unid = test_ds[unid]
    unid_dist = get_distance_distribution(unid)
    all_dist = get_distance_distribution(test_ds[test_ds[:,1] == f"{key_list[type_int]}"])
    nr_bins = 40

    bins_count_u, counts_u, pdf_u, _ = get_bins_count_pdf_cdf(unid_dist, nr_bins, 10, 2400)
    bins_count_o, counts_o, pdf_o, _ = get_bins_count_pdf_cdf(all_dist, nr_bins, 10, 2400)
    counts_u = counts_o - counts_u
    
    if type_int == 1:
        low_max = 40
        high_max = 3200
        broken_plot_unidentified_and_original(pdf_o, pdf_u, bins_count_o, bins_count_u, counts_o, counts_u, 50, type_int, low_max, high_max, f"Distribution of {key_list[type_int]} distances in the test set", "Distance", "Frequency")
    else:
    
        plot_unidentified_and_original(pdf_o, pdf_u, bins_count_o, bins_count_u, counts_o, counts_u, 50, type_int, f"Distribution of {key_list[type_int]} distances in the test set", "Distance", "Frequency")

    
def plot_magnitude_unid(predictions, y_test, test_ds, type_int):
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    key_list = list(final_dict.keys())
    unid = get_all_unidentified_by_type(type_int, predictions, y_test)
    unid = test_ds[unid]
    unid_dist = get_magnitude_distribution(unid)
    all_dist = get_magnitude_distribution(test_ds[test_ds[:,1] == f"{key_list[type_int]}"])
    nr_bins = 40

    bins_count_u, counts_u, pdf_u, _ = get_bins_count_pdf_cdf(unid_dist, nr_bins, 0, 6)
    bins_count_o, counts_o, pdf_o, _ = get_bins_count_pdf_cdf(all_dist, nr_bins, 0, 6)
    counts_u = counts_o - counts_u
    if type_int == 1:
        low_max = 50
        high_max = 2500
        broken_plot_unidentified_and_original(pdf_o, pdf_u, bins_count_o, bins_count_u, counts_o, counts_u, 0.1, type_int, low_max, high_max, f"Distribution of {key_list[type_int]} magntidues in the test set", "Magnitude", "Frequency")
    if type_int == 2:
        low_max = 10
        high_max = 150
        plot_unidentified_and_original(pdf_o, pdf_u, bins_count_o, bins_count_u, counts_o, counts_u, 0.1, type_int, f"Distribution of {key_list[type_int]} magntidues in the test set", "Magnitude", "Frequency")
    

def plot_msrdr_unid(predictions, y_test, test_ds, type_int):
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    key_list = list(final_dict.keys())
    unid = get_all_unidentified_by_type(type_int, predictions, y_test)
    unid = test_ds[unid]
    unid_dist = get_msrdr_distribution(unid)
    all_dist = get_msrdr_distribution(test_ds[test_ds[:,1] == f"{key_list[type_int]}"])
    nr_bins = 60

    bins_count_u, counts_u, pdf_u, _ = get_bins_count_pdf_cdf(unid_dist, nr_bins, 0, 0.8)
    bins_count_o, counts_o, pdf_o, _ = get_bins_count_pdf_cdf(all_dist, nr_bins, 0, 0.8)
    counts_u = counts_o - counts_u
    if type_int == 1:
        low_max = 20
        high_max = 3000
    if type_int == 2:
        low_max = 10
        high_max = 150
    
    broken_plot_unidentified_and_original(pdf_o, pdf_u, bins_count_o, bins_count_u, counts_o, counts_u, 0.01, type_int, low_max, high_max, f"Distribution of {key_list[type_int]} MSRDR in the test set", "MSRDR", "Frequency")

    
    
from scipy.stats import linregress

def plot_distances_noise(predictions, y_test, test_ds, type_int):
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    key_list = list(final_dict.keys())
    unid = get_class_incorrectly_predicted_noise(predictions, y_test, type_int)
    unid = test_ds[unid]
    unid_dist = get_distance_distribution(unid)
    all_dist = get_distance_distribution(test_ds[test_ds[:,1] == f"{key_list[type_int]}"])
    nr_bins = 40

    bins_count_u, counts_u, pdf_u, _ = get_bins_count_pdf_cdf(unid_dist, nr_bins, 10, 2400)
    bins_count_o, counts_o, pdf_o, _ = get_bins_count_pdf_cdf(all_dist, nr_bins, 10, 2400)
    
    if type_int == 1:
        low_max = 40
        high_max = 3200
        broken_plot_unidentified_and_original(pdf_o, pdf_u, bins_count_o, bins_count_u, counts_o, counts_u, 50, type_int, low_max, high_max, f"Distribution of {key_list[type_int]} distances in the test set", "Distance", "Frequency")
    else:
    
        plot_unidentified_and_original(pdf_o, pdf_u, bins_count_o, bins_count_u, counts_o, counts_u, 50, type_int, f"Distribution of {key_list[type_int]} distances in the test set", "Distance", "Frequency")

def plot_distances_noise_adjusted(predictions, y_test, test_ds, type_int):
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    key_list = list(final_dict.keys())
    unid = get_class_incorrectly_predicted_noise(predictions, y_test, type_int)
    unid = test_ds[unid]
    unid_dist = get_distance_distribution(unid)
    all_dist = get_distance_distribution(test_ds[test_ds[:,1] == f"{key_list[type_int]}"])
    nr_bins = 40

    bins_count_u, counts_u, pdf_u, _ = get_bins_count_pdf_cdf(unid_dist, nr_bins, 10, 2400)
    bins_count_o, counts_o, pdf_o, _ = get_bins_count_pdf_cdf(all_dist, nr_bins, 10, 2400)
    pdf = pdf_u
    bins_count = bins_count_u
    counts = adjust_by_pop(counts_o, counts_u)
    title = f"Distance distribution of {key_list[type_int]}s predicted to be noise"
    xlabel = "Distance"
    ylabel = "Probability"
    plot_adjusted(pdf, bins_count, counts, 50, type_int, title, xlabel, ylabel)
        #plot_unidentified_and_original(pdf_o, pdf_u, bins_count_o, bins_count_u, counts_o, counts_u, 50, type_int, f"Distribution of {key_list[type_int]} distances in the test set", "Distance", "Frequency")

        
def plot_magnitude_noise_adjusted(predictions, y_test, test_ds, type_int):
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    key_list = list(final_dict.keys())
    unid = get_class_incorrectly_predicted_noise(predictions, y_test, type_int)
    unid = test_ds[unid]
    unid_dist = get_magnitude_distribution(unid)
    all_dist = get_magnitude_distribution(test_ds[test_ds[:,1] == f"{key_list[type_int]}"])
    nr_bins = 40

    bins_count_u, counts_u, pdf_u, _ = get_bins_count_pdf_cdf(unid_dist, nr_bins, 0, 6)
    bins_count_o, counts_o, pdf_o, _ = get_bins_count_pdf_cdf(all_dist, nr_bins, 0, 6)
    pdf = pdf_u
    bins_count = bins_count_u
    counts = adjust_by_pop(counts_o, counts_u)
    title = f"Magnitude distribution of {key_list[type_int]}s predicted to be noise"
    xlabel = "Magnitude"
    ylabel = "Probability"
    plot_adjusted(pdf, bins_count, counts, 0.1, type_int, title, xlabel, ylabel)
    
def plot_distance_noise_both(predictions, y_test, test_ds, type_int):
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    key_list = list(final_dict.keys())
    unid = get_class_incorrectly_predicted_noise(predictions, y_test, type_int)
    unid = test_ds[unid]
    unid_dist = get_distance_distribution(unid)
    all_dist = get_distance_distribution(test_ds[test_ds[:,1] == f"{key_list[type_int]}"])
    nr_bins = 40

    bins_count_u, counts_u, pdf_u, _ = get_bins_count_pdf_cdf(unid_dist, nr_bins, 10, 2400)
    bins_count_o, counts_o, pdf_o, _ = get_bins_count_pdf_cdf(all_dist, nr_bins, 10, 2400)
    pdf = pdf_u
    bins_count = bins_count_u
    counts = adjust_by_pop(counts_o, counts_u)
    title = f"Distance distribution of {key_list[type_int]}s predicted to be noise"
    xlabel = "Distance"
    ylabel = "Probability"
    #plot_adjusted(pdf, bins_count, counts, 50, type_int, title, xlabel, ylabel)
    plot_both(pdf_o, pdf_u, bins_count_o, bins_count_u, counts_o, counts_u, counts, 50, type_int, title, xlabel, ylabel)
    
def plot_magnitude_noise_both(predictions, y_test, test_ds, type_int):
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    key_list = list(final_dict.keys())
    unid = get_class_incorrectly_predicted_noise(predictions, y_test, type_int)
    unid = test_ds[unid]
    unid_dist = get_magnitude_distribution(unid)
    all_dist = get_magnitude_distribution(test_ds[test_ds[:,1] == f"{key_list[type_int]}"])
    nr_bins = 40

    bins_count_u, counts_u, pdf_u, _ = get_bins_count_pdf_cdf(unid_dist, nr_bins, 0, 6)
    bins_count_o, counts_o, pdf_o, _ = get_bins_count_pdf_cdf(all_dist, nr_bins, 0, 6)
    pdf = pdf_u
    bins_count = bins_count_u
    counts = adjust_by_pop(counts_o, counts_u)
    title = f"Magnitude distribution of {key_list[type_int]}s predicted to be noise"
    xlabel = "Magnitude"
    ylabel = "Probability"
    #plot_adjusted(pdf, bins_count, counts, 50, type_int, title, xlabel, ylabel)
    plot_both(pdf_o, pdf_u, bins_count_o, bins_count_u, counts_o, counts_u, counts, 0.1, type_int, title, xlabel, ylabel)

    
def plot_msrdr_noise_both(predictions, y_test, test_ds, type_int):
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    key_list = list(final_dict.keys())
    unid = get_class_incorrectly_predicted_noise(predictions, y_test, type_int)
    unid = test_ds[unid]
    unid_dist = get_msrdr_distribution(unid)
    all_dist = get_msrdr_distribution(test_ds[test_ds[:,1] == f"{key_list[type_int]}"])
    nr_bins = 60

    bins_count_u, counts_u, pdf_u, _ = get_bins_count_pdf_cdf(unid_dist, nr_bins, 0, 0.8)
    bins_count_o, counts_o, pdf_o, _ = get_bins_count_pdf_cdf(all_dist, nr_bins, 0, 0.8)
    pdf = pdf_u
    bins_count = bins_count_u
    counts = adjust_by_pop(counts_o, counts_u)
    title = f"MSRDR distribution of {key_list[type_int]}s predicted to be noise"
    xlabel = "MSRDR"
    ylabel = "Probability"
    #plot_adjusted(pdf, bins_count, counts, 50, type_int, title, xlabel, ylabel)
    plot_both(pdf_o, pdf_u, bins_count_o, bins_count_u, counts_o, counts_u, counts, 0.01, type_int, title, xlabel, ylabel)

    
    
def plot_msrdr_noise_adjusted(predictions, y_test, test_ds, type_int):
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    key_list = list(final_dict.keys())
    unid = get_class_incorrectly_predicted_noise(predictions, y_test, type_int)
    unid = test_ds[unid]
    unid_dist = get_msrdr_distribution(unid)
    all_dist = get_msrdr_distribution(test_ds[test_ds[:,1] == f"{key_list[type_int]}"])
    nr_bins = 40

    bins_count_u, counts_u, pdf_u, _ = get_bins_count_pdf_cdf(unid_dist, nr_bins, 0, 0.8)
    bins_count_o, counts_o, pdf_o, _ = get_bins_count_pdf_cdf(all_dist, nr_bins, 0, 0.8)
    pdf = pdf_u
    bins_count = bins_count_u
    counts = adjust_by_pop(counts_o, counts_u)
    title = f"MSRDR distribution of {key_list[type_int]}s predicted to be noise"
    xlabel = "MSRDR"
    ylabel = "Probability"
    plot_adjusted(pdf, bins_count, counts, 0.01, type_int, title, xlabel, ylabel)


def plot_adjusted(pdf, bins_count, counts, width, type_int, title, xlabel, ylabel):
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    key_list = list(final_dict.keys())
    plt.bar(bins_count[1:], counts, width=width, color="red", label=f"E{key_list[type_int][1:]}s predicted to be noise, adjusted for population")
    plt.legend()
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.rcParams['figure.figsize'] = [10, 8]
    plt.show()

def plot_both(pdf_o, pdf_u, bins_count_o, bins_count_u, counts_o, counts_u, counts_a, width, type_int, title, xlabel, ylabel):
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    key_list = list(final_dict.keys())
    fig, (ax1, ax2) = plt.subplots(1,2)
    fig.subplots_adjust(hspace=0.1)
    ax1.bar(bins_count_o[1:], counts_o, width=width, color="blue", label=f"All {key_list[type_int]}s")
    ax1.bar(bins_count_u[1:], counts_u, width=width, color="red", label=f"E{key_list[type_int][1:]}s predicted \nto be noise")
    
    slope, intercept, r_value, p_value, std_err  = linregress(bins_count_u[1:], counts_a)
    
    ax2.plot(bins_count_u[1:], slope*bins_count_u[1:]+intercept, color = "red", label = f"Linear regression line. P-value: {round(p_value, 2)}\n R-value: {round(r_value, 2)}")
    print("Intercept: ", intercept)
    print("Coef: ", slope)
    print("P-value: ", p_value)
    
    #coef = np.polyfit(bins_count_u[1:], counts_a,1)
    #poly1d_fn = np.poly1d(coef) 
    # poly1d_fn is now a function which takes in x and returns an estimate for y

    #plt.plot(bins_count_u[1:], counts_a, 'yo', bins_count_u[1:], poly1d_fn(bins_count_u[1:]), '--k', color = "black")
    #plt.plot(bins_count_u[1:], counts_a, 'yo', bins_count_u[1:], poly1d_fn(bins_count_u[1:]), '--k', color = "black")
    ax2.bar(bins_count_u[1:], counts_a, width=width, color="black", label=f"E{key_list[type_int][1:]}s predicted to be noise,\n adjusted for population")
    
    
    fig.text(0.45, 0.08, xlabel, va='center')
    fig.text(0.04, 0.5, "Frequency", va='center', rotation='vertical')
    fig.text(0.48, 0.5, "Probability", va='center', rotation = 'vertical')
    fig.text(0.35, 0.9, title, va = 'center')
    ax1.legend()
    ax2.legend()
    plt.show()
    


def adjust_by_pop(counts_o, counts_u):
    new_counts = []
    for i in range(len(counts_o)):
        if counts_u[i] == 0:
            new_counts.append(0)
        else:
            new_counts.append(counts_u[i]/counts_o[i])
    return new_counts
    
def plot_all_plots(predictions, y_test, test_ds):
    print("Plotting errors")
    print("Distances:")
    plot_distances_unid(predictions, y_test, test_ds, 1)
    plot_distances_unid(predictions, y_test, test_ds, 2)
    print("Magnitudes:")
    plot_magnitude_unid(predictions, y_test, test_ds, 1)
    plot_magnitude_unid(predictions, y_test, test_ds, 2)
    print("MSRDR:")
    plot_msrdr_unid(predictions, y_test, test_ds, 1)
    plot_msrdr_unid(predictions, y_test, test_ds, 2)
    print("Finished")
    print("Plotting events incorrectly labeled noise:")
    print("Distances:")
    plot_distance_noise_both(test_pred, y_test, test_ds, 1)
    plot_distance_noise_both(test_pred, y_test, test_ds, 2)
    print("Magnitudes:")
    plot_magnitude_noise_both(test_pred, y_test, test_ds, 1)
    plot_magnitude_noise_both(test_pred, y_test, test_ds, 2)
    print("MSRDR:")
    plot_msrdr_noise_both(test_pred, y_test, test_ds, 1)
    plot_msrdr_noise_both(test_pred, y_test, test_ds, 2)

# %%
def evaluate_full_pipeline(test_pred, test_traces, test_labels, test_ds):
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    # We now have the predictions in their string form and (assumed) in the correct ordering
    # Let us now convert the final predictions and true labels into one-hot encoding
    final_preds = np.array([final_dict.get(x[0]) for x in test_pred])
    final_true = transform_true_labels(test_labels, final_dict)
    assert len(final_preds) == len(final_true), f"preds len {len(final_preds)}, true len {len(final_true)}"
    # Should be able to attempt to print a confusion matrix now
    conf=tf.math.confusion_matrix(final_true, final_preds, num_classes = 3)
    precision, recall, fscore, _ = precision_recall_fscore_support(final_true, final_preds, beta = 2, average = "macro", zero_division = 0.0)
    report = classification_report(final_true, final_preds, target_names = final_dict)
    plot_all_plots(test_pred, test_labels, test_ds)
    return conf, report, precision, recall, fscore

# %%
test_pred = predict_final_model(loadData, model_3n, model_ee, x_test, y_test, noiseAug, 3, 3)

conf, report, precision, recall, fscore  = evaluate_full_pipeline(test_pred, x_test, y_test, test_ds)

print(conf)
print(report)
plot_confusion_matrix(conf,{"noise" : 0, "explosion" : 1, "earthquake" : 2})
# Out:
# Completed 3N predictions after f18 seconds. Amount of predictions: 17642
# Average time per datapoint: 0.001005052101205312
# Completed 3N predictions after f21 seconds. Amount of predictions: 17642
# Average time per datapoint: 0.0011754585980098679
# [[ 0.]
#  [ 0.]
#  [ 0.]
#  ...,
#  [ 0.]
#  [ 0.]
#  [ 0.]]
# [['noise']
#  ['noise']
#  ['noise']
#  ...,
#  ['not_noise']
#  ['not_noise']
#  ['noise']]
# Prediction of 17642 complete. Process took 39 seconds
# Average time per datapoint: 0.0022275762187152098
# Plotting errors
# Distances:
# Max dist: 1852.0
# Min dist: 86.0
# Max dist: 1965.0
# Min dist: 86.0
# Max dist: 2394.0
# Min dist: 137.0
# Max dist: 2394.0
# Min dist: 11.0
# Magnitudes:
# Max dist: 4.3
# Min dist: 0.7
# Max dist: 4.3
# Min dist: 0.7
# Max dist: 5.601
# Min dist: 0.9
# Max dist: 5.601
# Min dist: 0.7
# MSRDR:
# Max dist: 0.2204338987563581
# Min dist: 0.060004438309835983
# Max dist: 0.248623046072668
# Min dist: 0.06000339438365045
# Max dist: 0.22025937986007593
# Min dist: 0.06073591348988495
# Max dist: 0.789717329282861
# Min dist: 0.06039273726920308
# Finished
# Plotting events incorrectly labeled noise:
# Distances:
# [0 0 0 ..., 1 1 0]
# Max dist: 1852.0
# Min dist: 176.0
# Max dist: 1965.0
# Min dist: 86.0
# Intercept:  0.100976501914
# Coef:  1.19896665021e-05
# P-value:  0.805699714705
# [0 0 0 ..., 1 1 0]
# Max dist: 2394.0
# Min dist: 139.0
# Max dist: 2394.0
# Min dist: 11.0
# Intercept:  0.00726640616643
# Coef:  8.49530280906e-05
# P-value:  0.0697704501882
# Magnitudes:
# [0 0 0 ..., 1 1 0]
# Max dist: 4.3
# Min dist: 0.9
# Max dist: 4.3
# Min dist: 0.7
# Intercept:  0.0272608281908
# Coef:  0.0061497933713
# P-value:  0.681315091293
# [0 0 0 ..., 1 1 0]
# Max dist: 4.302
# Min dist: 1.882
# Max dist: 5.601
# Min dist: 0.7
# Intercept:  0.0382547858533
# Coef:  0.000323815943025
# P-value:  0.950193207721
# MSRDR:
# [0 0 0 ..., 1 1 0]
# Max dist: 0.14095092201657328
# Min dist: 0.060004438309835983
# Max dist: 0.248623046072668
# Min dist: 0.06000339438365045
# Intercept:  0.00751756994186
# Coef:  -0.0130017792115
# P-value:  0.00626613032579
# [0 0 0 ..., 1 1 0]
# Max dist: 0.22025937986007593
# Min dist: 0.06073591348988495
# Max dist: 0.789717329282861
# Min dist: 0.06039273726920308
# Intercept:  0.0585998102035
# Coef:  -0.0963094895872
# P-value:  0.0288425241499
# tf.Tensor(
# [[8405   65  109]
#  [ 178 7450  737]
#  [  58   90  550]], shape=(3, 3), dtype=int32)
#               precision    recall  f1-score   support
#
#        noise       0.97      0.98      0.98      8579
#    explosion       0.98      0.89      0.93      8365
#   earthquake       0.39      0.79      0.53       698
#
#     accuracy                           0.93     17642
#    macro avg       0.78      0.89      0.81     17642
# weighted avg       0.95      0.93      0.94     17642
#
# ['noise', 'explosion', 'earthquake']

# %%
plot_all_plots(test_pred, y_test, test_ds)
# Out:
# Distances:
# Max dist: 1852.0
# Min dist: 86.0
# Max dist: 1965.0
# Min dist: 86.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-358-a8864cc68f3c> in <module>
# ----> 1 plot_all_plots(test_pred, y_test, test_ds)
#
# <ipython-input-357-30a912e376ce> in plot_all_plots(predictions, y_test, test_ds)
#     261 def plot_all_plots(predictions, y_test, test_ds):
#     262     print("Distances:")
# --> 263     plot_distances_unid(predictions, y_test, test_ds, 1)
#     264     plot_distances_unid(predictions, y_test, test_ds, 2)
#     265     print("Magnitudes:")
#
# <ipython-input-357-30a912e376ce> in plot_distances_unid(predictions, y_test, test_ds, type_int)
#     209         low_max = 40
#     210         high_max = 3200
# --> 211         broken_plot_unidentified_and_original(pdf_o, pdf_u, bins_count_o, bins_count_u, counts_o, counts_u, 50, type_int, low_max, high_max, f"Distribution of {key_list[type_int]} distances in the test set", "Distance", "Frequency")
#     212     else:
#     213
#
# <ipython-input-357-30a912e376ce> in broken_plot_unidentified_and_original(pdf_o, pdf_u, bins_count_o, bins_count_u, counts_o, counts_u, width, type_int, low_max, high_max, title, xlabel, ylabel)
#     173     ax2.spines['top'].set_visible(False)
#     174     ax2.xaxis.tick_bottom()
# --> 175     ax2.xaxis.tick_bottom(False)
#     176     ax2.yaxis.tick_left()
#     177     ax1.yaxis.tick_left()
#
# TypeError: tick_bottom() takes 1 positional argument but 2 were given

# %%
conf
# Out:
# <tf.Tensor: shape=(3, 3), dtype=int32, numpy=
# array([[8407,   66,  106],
#        [ 177, 7446,  742],
#        [  58,   88,  552]], dtype=int32)>

# %%
print(report)
# Out:
#               precision    recall  f1-score   support
#
#        noise       0.97      0.98      0.98      8579
#    explosion       0.98      0.89      0.93      8365
#   earthquake       0.39      0.79      0.53       698
#
#     accuracy                           0.93     17642
#    macro avg       0.78      0.89      0.81     17642
# weighted avg       0.95      0.93      0.94     17642

# %%
fscore
# Out:
# 0.84767911525637862

# %%
precision
# Out:
# 0.78187511567124679

# %%
plot_confusion_matrix(conf,{"noise" : 0, "explosion" : 1, "earthquake" : 2})
# Out:
# ['noise', 'explosion', 'earthquake']

# %% [markdown]
# Recall for noise: 0.9799510432
# precision for noise: 0.9729198009
# f2 for noise: 0.978536676165186
#
# Recall for explosions:  7452 / 8365   0.890854751943
# Precision for explosions: 0.9800105208
# f2 for explo: 0.9073641145568898
#
# Recall for earthquakes: 0.7922636103
# Precision for earth: 0.3958482462

# %%
def f2_score(recall, precision):
    return ((1+2**2)*precision*recall)/((2**2)*precision+recall)

# %%
f2_n = f2_score(0.7922636103, 0.3958482462)
f2_n
# Out:
# 0.6600620672874103

# %%
print(len(test_pred))
# Out:
# 17642

# %%
print(len(y_test))
# Out:
# 17642

# %%
def get_all_errors(preds, true):
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    final_true = transform_true_labels(true, final_dict)
    final_preds = np.array([final_dict.get(x[0]) for x in test_pred])
    assert len(final_true) == len(final_preds)
    error_indexes = []
    for i in range(len(final_true)):
        if final_true[i] != final_preds[i]:
            error_indexes.append(i)
    return error_indexes

# %%
error_indexes = get_all_errors(test_pred, y_test)

# %%
len(error_indexes)

# %%
test_errors = test_ds[error_indexes]

# %%
def get_all_unidentified_by_type(type_int, predictions, y_test):
    index_list = []
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    final_preds = np.array([final_dict.get(x[0]) for x in test_pred])
    final_true = transform_true_labels(y_test, final_dict)
    for i in range(len(final_true)):
        if final_true[i] == type_int and final_true[i] != final_preds[i]:
            print(predictions[i])
            index_list.append(i)
    return index_list

# %%
unidentified_earthquake_indexes = get_all_unidentified_by_type(2, test_pred, y_test)
# Out:
# ['explosion']
# ['noise']
# ['explosion']
# ['explosion']
# ['explosion']
# ['noise']
# ['noise']
# ['noise']
# ['explosion']
# ['explosion']
# ['explosion']
# ['noise']
# ['noise']
# ['explosion']
# ['explosion']
# ['explosion']
# ['explosion']
# ['noise']
# ['explosion']
# ['explosion']
# ['explosion']
# ['noise']
# ['noise']
# ['noise']
# ['explosion']
# ['noise']
# ['explosion']
# ['explosion']
# ['explosion']
# ['explosion']
# ['explosion']
# ['explosion']
# ['explosion']
# ['explosion']
# ['explosion']
# ['explosion']
# ['explosion']
# ['explosion']
# ['explosion']
# ['noise']
# ['explosion']
# ['noise']
# ['noise']
# ['explosion']
# ['explosion']
# ['noise']
# ['explosion']
# ['noise']
# ['explosion']
# ['noise']
# ['noise']
# ['noise']
# ['noise']
# ['noise']
# ['explosion']
# ['noise']
# ['noise']
# ['explosion']
# ['explosion']
# ['explosion']
# ['explosion']
# ['explosion']
# ['noise']
# ['explosion']
# ['explosion']
# ['explosion']
# ['noise']
# ['explosion']
# ['noise']
# ['explosion']
# ['noise']
# ['explosion']
# ['explosion']
# ['explosion']
# ['noise']
# ['noise']
# ['noise']
# ['noise']
# ['explosion']
# ['noise']
# ['noise']
# ['noise']
# ['explosion']
# ['explosion']
# ['noise']
# ['explosion']
# ['explosion']
# ['explosion']
# ['noise']
# ['noise']
# ['noise']
# ['explosion']
# ['explosion']
# ['noise']
# ['explosion']
# ['noise']
# ['noise']
# ['explosion']
# ['explosion']
# ['noise']
# ['explosion']
# ['explosion']
# ['explosion']
# ['noise']
# ['noise']
# ['noise']
# ['explosion']
# ['explosion']
# ['explosion']
# ['noise']
# ['noise']
# ['explosion']
# ['explosion']
# ['explosion']
# ['explosion']
# ['explosion']
# ['noise']
# ['explosion']
# ['explosion']
# ['noise']
# ['noise']
# ['explosion']
# ['noise']
# ['explosion']
# ['noise']
# ['explosion']
# ['noise']
# ['explosion']
# ['explosion']
# ['explosion']
# ['explosion']
# ['explosion']
# ['explosion']
# ['noise']
# ['noise']
# ['explosion']
# ['explosion']
# ['explosion']
# ['explosion']
# ['explosion']
# ['explosion']
# ['noise']
# ['noise']
# ['noise']
# ['explosion']
# ['explosion']

# %%
len(unidentified_earthquake_indexes)
# Out:
# 146

# %%
unid_earthquake = test_ds[unidentified_earthquake_indexes]

# %%
unid_earthquake
# Out:
# array([[ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2017-01-03T10.40.39.865000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2019-11-01T06.33.07.414000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2013-11-09T10.32.15.751000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2015-02-14T02.59.42.264000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2008-11-04T07.58.50.289000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2018-04-04T15.38.44.939000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2020-05-28T12.12.29.814000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2009-03-29T02.38.07.187000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2010-07-29T17.01.01.412000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2015-08-22T04.17.19.071000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2011-05-26T01.15.59.244000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2008-05-20T11.19.32.688000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2018-09-30T22.00.05.434000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2013-08-07T09.22.30.150000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2007-11-28T09.12.19.341000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2011-03-17T19.28.35.182000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2012-01-17T00.24.45.959000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2019-03-28T15.50.11.008000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2010-05-21T05.59.55.267000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2011-10-13T06.48.27.107000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2010-09-16T20.35.26.798000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2016-02-09T17.07.28.969000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2016-05-18T20.25.58.913000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2016-04-11T12.58.14.639000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2014-02-14T15.51.29.431000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2020-01-26T01.42.47.534000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2010-09-17T09.00.32.778000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2013-08-09T15.50.34.541000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2008-06-19T10.29.09.243000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/1992-08-29T15.05.14.220000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2010-08-14T10.19.51.122000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2017-01-06T17.51.45.477000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2013-05-11T09.41.45.078000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2009-07-24T11.39.50.512000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2008-05-22T02.02.00.873000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2012-08-30T13.53.20.228000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2011-07-19T11.50.30.270000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2011-01-23T12.04.44.534000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2015-06-25T23.15.27.267000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2020-04-08T23.21.48.506000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2015-10-25T04.04.10.278000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2014-05-29T14.29.46.625000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2011-08-04T19.43.21.921000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2016-12-26T02.31.07.290000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2013-09-30T17.08.51.251000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2008-11-19T11.48.54.742000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2011-01-26T18.27.15.237000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2008-11-07T20.23.56.144000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2014-07-09T07.14.11.636000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2015-02-08T22.40.18.121000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2017-11-15T08.45.03.744000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2020-04-05T23.23.43.142000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2019-01-05T14.17.38.279000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2015-02-06T14.17.25.867000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2010-06-30T08.59.06.845000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2010-03-26T07.26.47.598000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2016-02-22T23.00.16.172000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2010-07-21T00.45.16.201000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2010-11-20T11.27.36.566000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2009-01-25T15.21.09.843000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2017-11-27T20.09.47.529000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2005-05-17T02.44.07.197000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2011-01-30T22.07.48.984000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2009-04-02T17.01.05.869000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2010-07-23T09.47.23.228000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2015-09-15T11.07.35.475000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2018-03-25T11.58.33.744000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2016-05-23T15.29.08.343000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2013-05-29T03.21.39.301000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/1996-06-09T02.21.20.897000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2013-03-30T00.51.50.230000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2011-11-08T03.39.04.914000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2015-07-03T13.09.19.634000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2010-09-28T09.02.06.009000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2019-09-13T20.19.22.789000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2013-08-23T11.51.44.695000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2008-10-26T16.03.32.656000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2019-10-01T16.20.27.511000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2009-08-28T08.13.45.273000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2012-04-30T09.01.44.736000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2016-04-08T22.46.20.017000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2013-08-06T13.41.25.617000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2012-08-28T17.01.19.602000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/1992-01-05T05.42.59.717000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2008-05-29T01.20.16.115000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2009-12-04T10.00.22.374000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2015-05-30T17.21.54.780000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2016-08-29T02.34.09.665000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2009-02-20T12.24.11.019000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2020-08-05T17.46.21.308000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2015-12-25T09.50.55.942000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2009-05-31T19.03.34.615000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2016-09-02T01.13.06.330000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/1997-01-14T03.53.36.137000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2013-08-18T07.33.44.555000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2013-04-20T14.22.20.379000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2020-02-06T20.01.03.562000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2010-06-03T14.46.23.430000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2015-09-16T10.13.21.165000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2011-08-29T05.38.08.476000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2011-09-16T09.51.48.037000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2010-09-13T23.27.09.550000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2010-05-15T10.21.49.924000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2020-04-15T04.48.45.448000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2018-02-08T04.49.06.428000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2013-06-04T15.26.38.811000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2014-07-10T14.24.03.107000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2008-02-21T03.13.23.246000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2008-02-23T15.32.31.733000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2010-02-22T17.17.18.532000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2008-09-25T17.49.34.601000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2008-02-11T13.12.06.687000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2009-07-15T05.03.15.224000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2016-02-11T00.36.13.674000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/1994-07-09T06.03.40.312000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2013-07-25T10.40.36.970000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2015-09-23T14.22.26.348000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2010-12-11T02.00.11.843000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2008-02-21T03.02.52.463000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2019-06-25T23.17.52.178000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2018-09-25T00.30.39.723000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2016-06-19T22.33.16.591000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2015-07-09T09.01.16.281000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2014-08-26T17.05.30.425000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2011-03-24T17.02.25.136000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2014-08-25T16.23.00.603000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2012-05-28T08.40.57.968000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2014-11-04T18.14.37.937000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2020-02-21T11.55.07.570000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2018-06-29T14.34.04.237000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2012-08-15T08.07.40.739000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2008-09-05T09.59.11.940000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2013-11-25T03.57.47.142000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2013-09-26T08.13.13.027000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2008-05-27T08.24.37.361000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/1995-06-08T10.09.51.812000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2018-02-16T02.47.06.516000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2014-06-04T16.42.35.910000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2014-06-17T18.00.34.808000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2018-06-04T17.18.07.199000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/1994-01-17T02.07.51.702000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2020-05-09T15.39.13.324000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2013-12-22T13.20.48.986000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2014-12-02T05.51.14.718000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2013-06-03T16.49.30.267000Z.h5',
#         'earthquake', 0],
#        [ '/media/tord/T7/Thesis_ssd/norsar_data_nov/earthquakes/2016-05-26T12.54.17.891000Z.h5',
#         'earthquake', 0]], dtype=object)

# %%
len(eq_noise)
# Out:
# 0

# %%
plot_msrdr_unid(test_pred, y_test, test_ds, 1)
# Out:
# Gathering distances: [-------------->                         ] 38 %
# Gathering distances: [----------------------------->          ] 77 %
# Gathering distances: [>                                       ] 1 %
# Gathering distances: [>                                       ] 4 %
# Gathering distances: [-->                                     ] 8 %
# Gathering distances: [---->                                   ] 12 %
# Gathering distances: [----->                                  ] 16 %
# Gathering distances: [------->                                ] 20 %
# Gathering distances: [-------->                               ] 24 %
# Gathering distances: [---------->                             ] 28 %
# Gathering distances: [------------>                           ] 32 %
# Gathering distances: [------------->                          ] 36 %
# Gathering distances: [--------------->                        ] 40 %
# Gathering distances: [---------------->                       ] 44 %
# Gathering distances: [------------------>                     ] 49 %
# Gathering distances: [-------------------->                   ] 53 %
# Gathering distances: [---------------------->                 ] 57 %
# Gathering distances: [----------------------->                ] 61 %
# Gathering distances: [------------------------->              ] 65 %
# Gathering distances: [-------------------------->             ] 69 %
# Gathering distances: [---------------------------->           ] 73 %
# Gathering distances: [------------------------------>         ] 77 %
# Gathering distances: [------------------------------->        ] 81 %
# Gathering distances: [--------------------------------->      ] 85 %
# Gathering distances: [---------------------------------->     ] 89 %
# Gathering distances: [------------------------------------>   ] 93 %
# Gathering distances: [--------------------------------------> ] 98 %
# Max dist: 0.2204338987563581
# Min dist: 0.060004438309835983
# Max dist: 0.248623046072668
# Min dist: 0.06000339438365045

# %%
plot_magnitude_unid(test_pred, y_test, test_ds, 1)
# Out:
# Gathering distances: [-------------->                         ] 37 %
# Gathering distances: [------------------------->              ] 66 %
# Gathering distances: [>                                       ] 0 %
# Gathering distances: [>                                       ] 4 %
# Gathering distances: [-->                                     ] 8 %
# Gathering distances: [--->                                    ] 12 %
# Gathering distances: [----->                                  ] 16 %
# Gathering distances: [------->                                ] 20 %
# Gathering distances: [-------->                               ] 24 %
# Gathering distances: [---------->                             ] 28 %
# Gathering distances: [------------>                           ] 32 %
# Gathering distances: [------------->                          ] 36 %
# Gathering distances: [--------------->                        ] 41 %
# Gathering distances: [----------------->                      ] 45 %
# Gathering distances: [------------------>                     ] 49 %
# Gathering distances: [-------------------->                   ] 53 %
# Gathering distances: [---------------------->                 ] 57 %
# Gathering distances: [----------------------->                ] 61 %
# Gathering distances: [------------------------->              ] 65 %
# Gathering distances: [-------------------------->             ] 69 %
# Gathering distances: [---------------------------->           ] 73 %
# Gathering distances: [------------------------------>         ] 78 %
# Gathering distances: [------------------------------->        ] 82 %
# Gathering distances: [--------------------------------->      ] 86 %
# Gathering distances: [----------------------------------->    ] 90 %
# Gathering distances: [------------------------------------>   ] 94 %
# Gathering distances: [--------------------------------------> ] 98 %
# Max dist: 4.3
# Min dist: 0.7
# Max dist: 4.3
# Min dist: 0.7

# %%
plot_distances_unid(test_pred, y_test, test_ds, 1)
# Out:
# Gathering distances: [------------->                          ] 36 %
# Gathering distances: [---------------------------->           ] 74 %
# Gathering distances: [>                                       ] 1 %
# Gathering distances: [->                                      ] 5 %
# Gathering distances: [-->                                     ] 8 %
# Gathering distances: [---->                                   ] 12 %
# Gathering distances: [----->                                  ] 17 %
# Gathering distances: [------->                                ] 21 %
# Gathering distances: [--------->                              ] 25 %
# Gathering distances: [---------->                             ] 29 %
# Gathering distances: [------------>                           ] 34 %
# Gathering distances: [-------------->                         ] 38 %
# Gathering distances: [--------------->                        ] 42 %
# Gathering distances: [----------------->                      ] 46 %
# Gathering distances: [------------------->                    ] 50 %
# Gathering distances: [-------------------->                   ] 54 %
# Gathering distances: [---------------------->                 ] 58 %
# Gathering distances: [------------------------>               ] 63 %
# Gathering distances: [------------------------->              ] 67 %
# Gathering distances: [--------------------------->            ] 71 %
# Gathering distances: [----------------------------->          ] 75 %
# Gathering distances: [------------------------------->        ] 80 %
# Gathering distances: [-------------------------------->       ] 84 %
# Gathering distances: [---------------------------------->     ] 88 %
# Gathering distances: [------------------------------------>   ] 92 %
# Gathering distances: [------------------------------------->  ] 97 %
# Max dist: 1852.0
# Min dist: 86.0
# Max dist: 1965.0
# Min dist: 86.0

# %%
unid_earth_dist = get_distance_distribution(unid_earthquake)
all_earth_dist = get_distance_distribution(test_ds[test_ds[:,1] == "earthquake"])
# Out:
# Gathering distances: [-------->                               ] 23 %
# Gathering distances: [-------------------------->             ] 69 %
# Gathering distances: [--------------------------------------->] 100 %

# %%
nr_bins = 40
bins_count_u, counts_u, pdf_u, _ = get_bins_count_pdf_cdf(unid_earth_dist, nr_bins, 10, 2400)
bins_count_o, counts_o, pdf_o, _ = get_bins_count_pdf_cdf(all_earth_dist, nr_bins, 10, 2400)
counts_u = counts_o - counts_u

plot_unidentified_and_original(pdf_o, pdf_u, bins_count_o, bins_count_u, counts_o, counts_u, "Distribution of earthquake distances in the test set", "Distance", "Frequency")
# Out:
# Max dist: 2394.0
# Min dist: 137.0
# Max dist: 2394.0
# Min dist: 11.0

# %%
def get_class_incorrectly_predicted_noise(test_pred, y_true, type_int):
    index_list = []
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    final_preds = np.array([final_dict.get(x[0]) for x in test_pred])
    print(final_preds)
    final_true = transform_true_labels(y_test, final_dict)
    for i in range(len(test_pred)):
        if final_preds[i] == 0 and final_true[i] == type_int:
            index_list.append(i)
    return index_list

# %%
eq_noise = get_class_incorrectly_predicted_noise(test_pred, y_test, 2)
print(len(eq_noise))
# Out:
# [0 0 0 ..., 1 1 0]
# 178

# %%
from scipy.stats import linregress

def plot_distances_noise(predictions, y_test, test_ds, type_int):
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    key_list = list(final_dict.keys())
    unid = get_class_incorrectly_predicted_noise(predictions, y_test, type_int)
    unid = test_ds[unid]
    unid_dist = get_distance_distribution(unid)
    all_dist = get_distance_distribution(test_ds[test_ds[:,1] == f"{key_list[type_int]}"])
    nr_bins = 40

    bins_count_u, counts_u, pdf_u, _ = get_bins_count_pdf_cdf(unid_dist, nr_bins, 10, 2400)
    bins_count_o, counts_o, pdf_o, _ = get_bins_count_pdf_cdf(all_dist, nr_bins, 10, 2400)
    
    if type_int == 1:
        low_max = 40
        high_max = 3200
        broken_plot_unidentified_and_original(pdf_o, pdf_u, bins_count_o, bins_count_u, counts_o, counts_u, 50, type_int, low_max, high_max, f"Distribution of {key_list[type_int]} distances in the test set", "Distance", "Frequency")
    else:
    
        plot_unidentified_and_original(pdf_o, pdf_u, bins_count_o, bins_count_u, counts_o, counts_u, 50, type_int, f"Distribution of {key_list[type_int]} distances in the test set", "Distance", "Frequency")

def plot_distances_noise_adjusted(predictions, y_test, test_ds, type_int):
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    key_list = list(final_dict.keys())
    unid = get_class_incorrectly_predicted_noise(predictions, y_test, type_int)
    unid = test_ds[unid]
    unid_dist = get_distance_distribution(unid)
    all_dist = get_distance_distribution(test_ds[test_ds[:,1] == f"{key_list[type_int]}"])
    nr_bins = 40

    bins_count_u, counts_u, pdf_u, _ = get_bins_count_pdf_cdf(unid_dist, nr_bins, 10, 2400)
    bins_count_o, counts_o, pdf_o, _ = get_bins_count_pdf_cdf(all_dist, nr_bins, 10, 2400)
    pdf = pdf_u
    bins_count = bins_count_u
    counts = adjust_by_pop(counts_o, counts_u)
    title = f"Distance distribution of {key_list[type_int]}s predicted to be noise"
    xlabel = "Distance"
    ylabel = "Probability"
    plot_adjusted(pdf, bins_count, counts, 50, type_int, title, xlabel, ylabel)
        #plot_unidentified_and_original(pdf_o, pdf_u, bins_count_o, bins_count_u, counts_o, counts_u, 50, type_int, f"Distribution of {key_list[type_int]} distances in the test set", "Distance", "Frequency")

        
def plot_magnitude_noise_adjusted(predictions, y_test, test_ds, type_int):
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    key_list = list(final_dict.keys())
    unid = get_class_incorrectly_predicted_noise(predictions, y_test, type_int)
    unid = test_ds[unid]
    unid_dist = get_magnitude_distribution(unid)
    all_dist = get_magnitude_distribution(test_ds[test_ds[:,1] == f"{key_list[type_int]}"])
    nr_bins = 40

    bins_count_u, counts_u, pdf_u, _ = get_bins_count_pdf_cdf(unid_dist, nr_bins, 0, 6)
    bins_count_o, counts_o, pdf_o, _ = get_bins_count_pdf_cdf(all_dist, nr_bins, 0, 6)
    pdf = pdf_u
    bins_count = bins_count_u
    counts = adjust_by_pop(counts_o, counts_u)
    title = f"Magnitude distribution of {key_list[type_int]}s predicted to be noise"
    xlabel = "Magnitude"
    ylabel = "Probability"
    plot_adjusted(pdf, bins_count, counts, 0.1, type_int, title, xlabel, ylabel)
    
def plot_distance_noise_both(predictions, y_test, test_ds, type_int):
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    key_list = list(final_dict.keys())
    unid = get_class_incorrectly_predicted_noise(predictions, y_test, type_int)
    unid = test_ds[unid]
    unid_dist = get_distance_distribution(unid)
    all_dist = get_distance_distribution(test_ds[test_ds[:,1] == f"{key_list[type_int]}"])
    nr_bins = 40

    bins_count_u, counts_u, pdf_u, _ = get_bins_count_pdf_cdf(unid_dist, nr_bins, 10, 2400)
    bins_count_o, counts_o, pdf_o, _ = get_bins_count_pdf_cdf(all_dist, nr_bins, 10, 2400)
    pdf = pdf_u
    bins_count = bins_count_u
    counts = adjust_by_pop(counts_o, counts_u)
    title = f"Distance distribution of {key_list[type_int]}s predicted to be noise"
    xlabel = "Distance"
    ylabel = "Probability"
    #plot_adjusted(pdf, bins_count, counts, 50, type_int, title, xlabel, ylabel)
    plot_both(pdf_o, pdf_u, bins_count_o, bins_count_u, counts_o, counts_u, counts, 50, type_int, title, xlabel, ylabel)
    
def plot_magnitude_noise_both(predictions, y_test, test_ds, type_int):
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    key_list = list(final_dict.keys())
    unid = get_class_incorrectly_predicted_noise(predictions, y_test, type_int)
    unid = test_ds[unid]
    unid_dist = get_magnitude_distribution(unid)
    all_dist = get_magnitude_distribution(test_ds[test_ds[:,1] == f"{key_list[type_int]}"])
    nr_bins = 40

    bins_count_u, counts_u, pdf_u, _ = get_bins_count_pdf_cdf(unid_dist, nr_bins, 0, 6)
    bins_count_o, counts_o, pdf_o, _ = get_bins_count_pdf_cdf(all_dist, nr_bins, 0, 6)
    pdf = pdf_u
    bins_count = bins_count_u
    counts = adjust_by_pop(counts_o, counts_u)
    title = f"Magnitude distribution of {key_list[type_int]}s predicted to be noise"
    xlabel = "Magnitude"
    ylabel = "Probability"
    #plot_adjusted(pdf, bins_count, counts, 50, type_int, title, xlabel, ylabel)
    plot_both(pdf_o, pdf_u, bins_count_o, bins_count_u, counts_o, counts_u, counts, 0.1, type_int, title, xlabel, ylabel)

    
def plot_msrdr_noise_both(predictions, y_test, test_ds, type_int):
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    key_list = list(final_dict.keys())
    unid = get_class_incorrectly_predicted_noise(predictions, y_test, type_int)
    unid = test_ds[unid]
    unid_dist = get_msrdr_distribution(unid)
    all_dist = get_msrdr_distribution(test_ds[test_ds[:,1] == f"{key_list[type_int]}"])
    nr_bins = 60

    bins_count_u, counts_u, pdf_u, _ = get_bins_count_pdf_cdf(unid_dist, nr_bins, 0, 0.8)
    bins_count_o, counts_o, pdf_o, _ = get_bins_count_pdf_cdf(all_dist, nr_bins, 0, 0.8)
    pdf = pdf_u
    bins_count = bins_count_u
    counts = adjust_by_pop(counts_o, counts_u)
    title = f"MSRDR distribution of {key_list[type_int]}s predicted to be noise"
    xlabel = "MSRDR"
    ylabel = "Probability"
    #plot_adjusted(pdf, bins_count, counts, 50, type_int, title, xlabel, ylabel)
    plot_both(pdf_o, pdf_u, bins_count_o, bins_count_u, counts_o, counts_u, counts, 0.01, type_int, title, xlabel, ylabel)

    
    
def plot_msrdr_noise_adjusted(predictions, y_test, test_ds, type_int):
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    key_list = list(final_dict.keys())
    unid = get_class_incorrectly_predicted_noise(predictions, y_test, type_int)
    unid = test_ds[unid]
    unid_dist = get_msrdr_distribution(unid)
    all_dist = get_msrdr_distribution(test_ds[test_ds[:,1] == f"{key_list[type_int]}"])
    nr_bins = 40

    bins_count_u, counts_u, pdf_u, _ = get_bins_count_pdf_cdf(unid_dist, nr_bins, 0, 0.8)
    bins_count_o, counts_o, pdf_o, _ = get_bins_count_pdf_cdf(all_dist, nr_bins, 0, 0.8)
    pdf = pdf_u
    bins_count = bins_count_u
    counts = adjust_by_pop(counts_o, counts_u)
    title = f"MSRDR distribution of {key_list[type_int]}s predicted to be noise"
    xlabel = "MSRDR"
    ylabel = "Probability"
    plot_adjusted(pdf, bins_count, counts, 0.01, type_int, title, xlabel, ylabel)


def plot_adjusted(pdf, bins_count, counts, width, type_int, title, xlabel, ylabel):
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    key_list = list(final_dict.keys())
    plt.bar(bins_count[1:], counts, width=width, color="red", label=f"E{key_list[type_int][1:]}s predicted to be noise, adjusted for population")
    plt.legend()
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.rcParams['figure.figsize'] = [10, 8]
    plt.show()

def plot_both(pdf_o, pdf_u, bins_count_o, bins_count_u, counts_o, counts_u, counts_a, width, type_int, title, xlabel, ylabel):
    final_dict = {"noise" : 0, "explosion" : 1, "earthquake" : 2}
    key_list = list(final_dict.keys())
    fig, (ax1, ax2) = plt.subplots(1,2)
    fig.subplots_adjust(hspace=0.1)
    ax1.bar(bins_count_o[1:], counts_o, width=width, color="blue", label=f"All {key_list[type_int]}s")
    ax1.bar(bins_count_u[1:], counts_u, width=width, color="red", label=f"E{key_list[type_int][1:]}s predicted \nto be noise")
    
    slope, intercept, r_value, p_value, std_err  = linregress(bins_count_u[1:], counts_a)
    
    ax2.plot(bins_count_u[1:], slope*bins_count_u[1:]+intercept, color = "red", label = f"Linear regression line. P-value: {round(p_value, 2)}\n R-value: {round(r_value, 2)}")
    print("Intercept: ", intercept)
    print("Coef: ", slope)
    print("P-value: ", p_value)
    
    #coef = np.polyfit(bins_count_u[1:], counts_a,1)
    #poly1d_fn = np.poly1d(coef) 
    # poly1d_fn is now a function which takes in x and returns an estimate for y

    #plt.plot(bins_count_u[1:], counts_a, 'yo', bins_count_u[1:], poly1d_fn(bins_count_u[1:]), '--k', color = "black")
    #plt.plot(bins_count_u[1:], counts_a, 'yo', bins_count_u[1:], poly1d_fn(bins_count_u[1:]), '--k', color = "black")
    ax2.bar(bins_count_u[1:], counts_a, width=width, color="black", label=f"E{key_list[type_int][1:]}s predicted to be noise,\n adjusted for population")
    
    
    fig.text(0.45, 0.08, xlabel, va='center')
    fig.text(0.04, 0.5, "Frequency", va='center', rotation='vertical')
    fig.text(0.48, 0.5, "Probability", va='center', rotation = 'vertical')
    fig.text(0.35, 0.9, title, va = 'center')
    ax1.legend()
    ax2.legend()
    plt.show()
    


def adjust_by_pop(counts_o, counts_u):
    new_counts = []
    for i in range(len(counts_o)):
        if counts_u[i] == 0:
            new_counts.append(0)
        else:
            new_counts.append(counts_u[i]/counts_o[i])
    return new_counts

# %%
plot_msrdr_noise_both(test_pred, y_test, test_ds, 2)
# Out:
# [0 0 0 ..., 1 1 0]
# Max dist: 0.22025937986007593
# Min dist: 0.06073591348988495
# Max dist: 0.789717329282861
# Min dist: 0.06039273726920308
# Intercept:  0.0595189185517
# Coef:  -0.0978999690752
# P-value:  0.026966417321

# %% [markdown]
# # Distances
# - Want to portray how the distance of the event correlates to its error.
# - Look at errors of earthquakes and explosions and plot their distance.
# - MSRDR could be interesting, portraying signal to noise ratio.
# -
#
#
# Looking at distance errors:
# - For both earthquakes and explosions (seperately):
#  - could look at errors adjusted for frequency

# %%
# Of the events which are predicted to be noise, how do they identify in terms of magnitude, distance and msrdr?
# Need for each non-noise class: The events predicted to be noise in error.
