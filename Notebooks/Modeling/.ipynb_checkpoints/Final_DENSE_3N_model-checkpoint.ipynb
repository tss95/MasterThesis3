# %%
import numpy as np
import os
import sys
import pandas as pd
import seaborn as sns

import pylab as pl
import h5py

import tensorflow as tf
from tensorflow.keras import mixed_precision

os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
os.environ['CUDA_VISIBLE_DEVICES']="0" 

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)


from sklearn.metrics import confusion_matrix

base_dir = '/media/tord/T7/Thesis_ssd/MasterThesis3'
os.chdir(base_dir)
from Classes.DataProcessing.LoadData import LoadData
from Classes.DataProcessing.HelperFunctions import HelperFunctions
from Classes.DataProcessing.DataHandler import DataHandler
from Classes.Modeling.DynamicModels import DynamicModels
from Classes.Modeling.TrainSingleModelRam import TrainSingleModelRam
from Classes.DataProcessing.RamLoader import RamLoader
import json

import gc

import datetime
import re
from livelossplot import PlotLossesKeras
from GlobalUtils import GlobalUtils
from Classes.Modeling.CustomCallback import CustomCallback
from tensorflow.keras.callbacks import EarlyStopping
utils = GlobalUtils()

from tensorflow.keras.utils import GeneratorEnqueuer






import sys


helper = HelperFunctions()

tf.config.optimizer.set_jit(True)
mixed_precision.set_global_policy('mixed_float16')
# Out:
# 1 Physical GPUs, 1 Logical GPUs
# WARNING:tensorflow:From /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/tensorflow/python/util/module_wrapper.py:49: The name tf.keras.layers.CuDNNLSTM is deprecated. Please use tf.compat.v1.keras.layers.CuDNNLSTM instead.
#
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: GeForce RTX 3090, compute capability 8.6

# %%
load_args = {
    'earth_explo_only' : False,
    'noise_earth_only' : False,
    'noise_not_noise' : True,
    'downsample' : True,
    'upsample' : True,
    'frac_diff' : 1,
    'seed' : 1,
    'subsample_size' : 0.25,
    'balance_non_train_set' : False,
    'use_true_test_set' : False,
    'even_balance' : True
}
loadData = LoadData(**load_args)
train_ds, val_ds, test_ds = loadData.get_datasets()
noise_ds = loadData.noise_ds
handler = DataHandler(loadData)
# Out:
# 2 3
# Balancing due to disguised labels.
# This functions barely works, and is a piece of shit that should not be trusted. Only works because noise has id: 0
# {'noise': 84799, 'earthquake': 84799, 'explosion': 82246}
# Mapping train redundancy: : [--------------------------------------->] 100 %
#
# Mapping validation redundancy: : [--------------------------------------->] 100 %
#
# Mapping test redundancy: : [--------------------------------------->] 100 %
#
#
#
# Loaded noise non-noise dataset.
# Evenly balanced among classes in the train set.
# Distribution (Label: (counts, proportion)) of
# Train ds:
# earthquake: (10631, 0.2526)  |  explosion: (10106, 0.2402)  |  noise: (21343, 0.5072)
# Val ds:
# earthquake: (242, 0.0371)  |  explosion: (3125, 0.4788)  |  noise: (3160, 0.4841)
# Test ds:
# earthquake: (184, 0.0423)  |  explosion: (2062, 0.4739)  |  noise: (2105, 0.4838)

# %%
model_type = "DENSE_grow"
is_lstm = True
num_channels = 3    

use_time_augmentor = True
scaler_name = "standard"
use_noise_augmentor = True
filter_name = None
band_min = 2.0
band_max = 4.0
highpass_freq = 0.075


shutdown = False

num_classes = len(list(set(loadData.label_dict.values())))



ramLoader = RamLoader(loadData, 
                      handler, 
                      use_time_augmentor = use_time_augmentor, 
                      use_noise_augmentor = use_noise_augmentor, 
                      scaler_name = scaler_name,
                      filter_name = filter_name, 
                      band_min = band_min,
                      band_max = band_max,
                      highpass_freq = highpass_freq, 
                      load_test_set = True, 
                      meier_load = False)

x_train, y_train, x_val, y_val, x_test, y_test, noiseAug = ramLoader.load_to_ram()
# Out:
# Fitting train time augmentor: [--------------------------------------->] 100 %
#
# Fit process completed after 16.480058670043945 seconds. Total datapoints fitted: 42080.
# Average time per datapoint: 0.0003916363752386869
#
#
# Fitting validation time augmentor: [--------------------------------------->] 100 %
#
# Fit process completed after 3.199103355407715 seconds. Total datapoints fitted: 6527.
# Average time per datapoint: 0.000490133806558559
#
#
# Fitting test time augmentor: [--------------------------------------->] 100 %
#
# Fit process completed after 2.0423781871795654 seconds. Total datapoints fitted: 4351.
# Average time per datapoint: 0.0004694043178992336
#
#
# Stage one loading training set, timeAug: [--------------------------------------->] 100 %
#
# Stage one loading validation set, timeAug: [--------------------------------------->] 100 %
#
# Stage one loading test set, timeAug: [--------------------------------------->] 100 %
#
# Fitting scaler progress: [------------------->] 100 %
#
# Stage two loading training set, labels and standard scaler: [--------------------------------------->] 100 %
#
# Stage two loading validation set, labels and standard scaler: [--------------------------------------->] 100 %
#
# Stage two loading test set, labels and standard scaler: [--------------------------------------->] 100 %
#
# (array([    4,     5,     6, ..., 42071, 42073, 42075]), array([0, 0, 0, ..., 0, 0, 0]))
# Fitting noise augmentor: [--------------------------------------->] 100 %
#
#
#
# Time elapsed to completion of load_to_ram_noise_not_noise: 0:01:22.594651

# %% [markdown]
# # Final 3N model:

# %%
use_tensorboard = True
use_liveplots = False
use_custom_callback = True
use_early_stopping = True
start_from_scratch = False
use_reduced_lr = True
log_data = True
beta = 1


params = {
        "batch_size" : 64,
        "epochs" : 50,
        "learning_rate" : 0.001,
        "optimizer" : "rmsprop",
        "num_layers" : 1,
        "units" : 200,
        "dropout_T_bn_F" : False,
        "use_layerwise_dropout_batchnorm" : False,
        "growth_sequence" : [1],
        "dropout_rate" : 0.1,
        "l2_r" : 0,
        "l1_r" : 0,
        "activation" : "relu",
        "output_layer_activation" : "sigmoid"
    }

workers = 32
max_queue_size = 20

finalModel = TrainSingleModelRam(noiseAug, helper, loadData,
                                 model_type, num_channels, use_tensorboard,
                                 use_liveplots, use_custom_callback, 
                                 use_early_stopping, use_reduced_lr, ramLoader,
                                 log_data = log_data,
                                 start_from_scratch = start_from_scratch, 
                                 beta = beta)
model = finalModel.run(x_train, y_train, x_val, y_val, x_test, y_test, workers, max_queue_size, evaluate_train = True, evaluate_val = True, evaluate_test = True, meier_mode = False, index = None, **params)
# Out:
# Trying to create result file
# Made result file:  results_DENSE_grow_noiseNotNoise_timeAug_standard_noiseAug_earlyS_unbalanced_valtest_subsample-0.25_numChannels-3.csv
# [   {'model_type': 'DENSE_grow'},
#     {   'activation': 'relu',
#         'batch_size': 64,
#         'dropout_T_bn_F': False,
#         'dropout_rate': 0.1,
#         'epochs': 50,
#         'growth_sequence': [1],
#         'l1_r': 0,
#         'l2_r': 0,
#         'learning_rate': 0.001,
#         'num_layers': 1,
#         'optimizer': 'rmsprop',
#         'output_layer_activation': 'sigmoid',
#         'units': 200,
#         'use_layerwise_dropout_batchnorm': False}]
# Saving file. 1 rows.
# results_DENSE_grow_noiseNotNoise_timeAug_standard_noiseAug_earlyS_unbalanced_valtest_subsample-0.25_numChannels-3.csv saved to path:   /media/tord/T7/Thesis_ssd/MasterThesis3/GridSearchResults/2_classes
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 6000, 3)]         0
# _________________________________________________________________
# flatten (Flatten)            (None, 18000)             0
# _________________________________________________________________
# dense (Dense)                (None, 200)               3600200
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 201
# =================================================================
# Total params: 3,600,401
# Trainable params: 3,600,401
# Non-trainable params: 0
# _________________________________________________________________
# Started enquers and generators
# ------------------RAM usage: 16210/36156 (Free: 10359)------------------
# ----------EarlyStop monitoring val_binary_accuracy------------
# ----------Reduce LR monitoring val_binary_accuracy------------
# Utilizes 6464/6527 validation points
# Utilizes 42048/42080 training points
# -------------------------------------------------------------------
# Loaded fit args. Starting training
# ------------------RAM usage: 16212/36156 (Free: 10357)------------------
# Epoch 1/50
#   4/657 [..............................] - ETA: 11s - loss: 0.6929 - binary_accuracy: 0.5046 - precision: 0.7061 - recall: 0.4536  WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0056s vs `on_train_batch_end` time: 0.0059s). Check your callbacks.
# 657/657 [==============================] - 22s 31ms/step - loss: 0.7707 - binary_accuracy: 0.5552 - precision: 0.7577 - recall: 0.2484 - val_loss: 0.6836 - val_binary_accuracy: 0.5582 - val_precision: 0.8597 - val_recall: 0.1723
# - val_f1: 0.2765
# Epoch 2/50
# 657/657 [==============================] - 20s 31ms/step - loss: 0.9380 - binary_accuracy: 0.6430 - precision: 0.8227 - recall: 0.3835 - val_loss: 0.6677 - val_binary_accuracy: 0.6075 - val_precision: 0.8078 - val_recall: 0.3114
# - val_f1: 0.4595
# Epoch 3/50
# 657/657 [==============================] - 20s 31ms/step - loss: 0.7296 - binary_accuracy: 0.6943 - precision: 0.8392 - recall: 0.4838 - val_loss: 0.6628 - val_binary_accuracy: 0.6375 - val_precision: 0.8636 - val_recall: 0.3536
# - val_f1: 0.506
# Epoch 4/50
# 657/657 [==============================] - 20s 31ms/step - loss: 0.7150 - binary_accuracy: 0.7292 - precision: 0.8646 - recall: 0.5397 - val_loss: 0.6777 - val_binary_accuracy: 0.6815 - val_precision: 0.8267 - val_recall: 0.4854
# - val_f1: 0.6109
# Epoch 5/50
# 657/657 [==============================] - 20s 31ms/step - loss: 1.2576 - binary_accuracy: 0.7556 - precision: 0.8781 - recall: 0.5889 - val_loss: 0.6822 - val_binary_accuracy: 0.7088 - val_precision: 0.7860 - val_recall: 0.5972
# - val_f1: 0.6922
# Epoch 6/50
# 657/657 [==============================] - 21s 32ms/step - loss: 1.4481 - binary_accuracy: 0.7750 - precision: 0.8849 - recall: 0.6267 - val_loss: 0.6972 - val_binary_accuracy: 0.7257 - val_precision: 0.8199 - val_recall: 0.5988
# - val_f1: 0.6915
# Epoch 7/50
# 657/657 [==============================] - 21s 32ms/step - loss: 0.6872 - binary_accuracy: 0.7904 - precision: 0.8943 - recall: 0.6539 - val_loss: 0.7250 - val_binary_accuracy: 0.7426 - val_precision: 0.8530 - val_recall: 0.6035
# - val_f1: 0.7177
# Epoch 8/50
# 657/657 [==============================] - 20s 31ms/step - loss: 2.5532 - binary_accuracy: 0.8048 - precision: 0.9031 - recall: 0.6759 - val_loss: 0.7475 - val_binary_accuracy: 0.7395 - val_precision: 0.8859 - val_recall: 0.5693
# - val_f1: 0.6987
# Epoch 9/50
# 657/657 [==============================] - 20s 31ms/step - loss: 3.5886 - binary_accuracy: 0.8147 - precision: 0.9152 - recall: 0.6947 - val_loss: 0.7540 - val_binary_accuracy: 0.7684 - val_precision: 0.8439 - val_recall: 0.6730
# - val_f1: 0.7428
# Epoch 10/50
# 657/657 [==============================] - 20s 31ms/step - loss: 1.3918 - binary_accuracy: 0.8266 - precision: 0.9211 - recall: 0.7094 - val_loss: 0.7606 - val_binary_accuracy: 0.7731 - val_precision: 0.8486 - val_recall: 0.6801
# - val_f1: 0.7708
# Epoch 11/50
# 657/657 [==============================] - 20s 31ms/step - loss: 0.4866 - binary_accuracy: 0.8419 - precision: 0.9307 - recall: 0.7339 - val_loss: 0.7729 - val_binary_accuracy: 0.7884 - val_precision: 0.8438 - val_recall: 0.7231
# - val_f1: 0.7796
# Epoch 12/50
# 657/657 [==============================] - 20s 31ms/step - loss: 0.6614 - binary_accuracy: 0.8463 - precision: 0.9319 - recall: 0.7463 - val_loss: 0.8241 - val_binary_accuracy: 0.7970 - val_precision: 0.8771 - val_recall: 0.7044
# - val_f1: 0.784
# Epoch 13/50
# 657/657 [==============================] - 21s 31ms/step - loss: 0.7703 - binary_accuracy: 0.8588 - precision: 0.9424 - recall: 0.7591 - val_loss: 0.8386 - val_binary_accuracy: 0.8058 - val_precision: 0.8785 - val_recall: 0.7229
# - val_f1: 0.7901
# Epoch 14/50
# 657/657 [==============================] - 21s 32ms/step - loss: 0.3251 - binary_accuracy: 0.8639 - precision: 0.9436 - recall: 0.7709 - val_loss: 0.8283 - val_binary_accuracy: 0.8057 - val_precision: 0.9009 - val_recall: 0.7003
# - val_f1: 0.7928
# Epoch 15/50
# 657/657 [==============================] - 21s 31ms/step - loss: 1.4390 - binary_accuracy: 0.8730 - precision: 0.9488 - recall: 0.7851 - val_loss: 0.8154 - val_binary_accuracy: 0.8094 - val_precision: 0.8982 - val_recall: 0.7127
# - val_f1: 0.7965
# Epoch 16/50
# 657/657 [==============================] - 20s 31ms/step - loss: 4.9736 - binary_accuracy: 0.8805 - precision: 0.9541 - recall: 0.7964 - val_loss: 0.8466 - val_binary_accuracy: 0.8179 - val_precision: 0.8484 - val_recall: 0.7877
# - val_f1: 0.8188
# Epoch 17/50
# 657/657 [==============================] - 21s 31ms/step - loss: 0.4370 - binary_accuracy: 0.8858 - precision: 0.9553 - recall: 0.8077 - val_loss: 0.8653 - val_binary_accuracy: 0.8320 - val_precision: 0.8650 - val_recall: 0.7982
# - val_f1: 0.8304
# Epoch 18/50
# 657/657 [==============================] - 21s 32ms/step - loss: 0.2701 - binary_accuracy: 0.8937 - precision: 0.9592 - recall: 0.8185 - val_loss: 0.8774 - val_binary_accuracy: 0.8349 - val_precision: 0.8858 - val_recall: 0.7823
# - val_f1: 0.8232
# Epoch 19/50
# 657/657 [==============================] - 20s 31ms/step - loss: 0.3355 - binary_accuracy: 0.8992 - precision: 0.9597 - recall: 0.8302 - val_loss: 0.8586 - val_binary_accuracy: 0.8329 - val_precision: 0.9013 - val_recall: 0.7589
# - val_f1: 0.8266
# Epoch 20/50
# 657/657 [==============================] - 21s 32ms/step - loss: 0.2411 - binary_accuracy: 0.9053 - precision: 0.9640 - recall: 0.8412 - val_loss: 0.8902 - val_binary_accuracy: 0.8376 - val_precision: 0.8699 - val_recall: 0.8032
# - val_f1: 0.8409
# Epoch 21/50
# 657/657 [==============================] - 20s 31ms/step - loss: 1.3179 - binary_accuracy: 0.9100 - precision: 0.9641 - recall: 0.8500 - val_loss: 0.9398 - val_binary_accuracy: 0.8410 - val_precision: 0.8677 - val_recall: 0.8158
# - val_f1: 0.8441
# Epoch 22/50
# 657/657 [==============================] - 20s 31ms/step - loss: 2.9897 - binary_accuracy: 0.9119 - precision: 0.9627 - recall: 0.8557 - val_loss: 0.9671 - val_binary_accuracy: 0.8461 - val_precision: 0.8811 - val_recall: 0.8117
# - val_f1: 0.8472
# Epoch 23/50
# 657/657 [==============================] - 21s 31ms/step - loss: 0.4370 - binary_accuracy: 0.9210 - precision: 0.9669 - recall: 0.8686 - val_loss: 0.9583 - val_binary_accuracy: 0.8439 - val_precision: 0.8617 - val_recall: 0.8326
# - val_f1: 0.8457
# Epoch 24/50
# 657/657 [==============================] - 20s 31ms/step - loss: 0.2021 - binary_accuracy: 0.9226 - precision: 0.9677 - recall: 0.8734 - val_loss: 0.9408 - val_binary_accuracy: 0.8444 - val_precision: 0.9142 - val_recall: 0.7695
# - val_f1: 0.8454
# Epoch 25/50
# 657/657 [==============================] - 20s 31ms/step - loss: 0.5424 - binary_accuracy: 0.9273 - precision: 0.9699 - recall: 0.8803 - val_loss: 0.9763 - val_binary_accuracy: 0.8543 - val_precision: 0.8696 - val_recall: 0.8423
# - val_f1: 0.8544
# Epoch 26/50
# 657/657 [==============================] - 20s 31ms/step - loss: 0.3841 - binary_accuracy: 0.9302 - precision: 0.9701 - recall: 0.8850 - val_loss: 0.9906 - val_binary_accuracy: 0.8581 - val_precision: 0.8986 - val_recall: 0.8166
# - val_f1: 0.851
# Epoch 27/50
# 657/657 [==============================] - 20s 31ms/step - loss: 0.1883 - binary_accuracy: 0.9380 - precision: 0.9738 - recall: 0.8980 - val_loss: 1.1320 - val_binary_accuracy: 0.8527 - val_precision: 0.8836 - val_recall: 0.8232
# - val_f1: 0.8594
# Epoch 28/50
# 657/657 [==============================] - 20s 31ms/step - loss: 0.7051 - binary_accuracy: 0.9400 - precision: 0.9726 - recall: 0.9035 - val_loss: 1.0892 - val_binary_accuracy: 0.8595 - val_precision: 0.9033 - val_recall: 0.8146
# - val_f1: 0.8538
# Epoch 29/50
# 657/657 [==============================] - 20s 31ms/step - loss: 1.0877 - binary_accuracy: 0.9412 - precision: 0.9748 - recall: 0.9045 - val_loss: 1.0663 - val_binary_accuracy: 0.8597 - val_precision: 0.8867 - val_recall: 0.8358
# - val_f1: 0.86
# Epoch 30/50
# 657/657 [==============================] - 20s 31ms/step - loss: 0.1557 - binary_accuracy: 0.9464 - precision: 0.9765 - recall: 0.9150 - val_loss: 1.1262 - val_binary_accuracy: 0.8580 - val_precision: 0.9140 - val_recall: 0.8014
# - val_f1: 0.8531
# Epoch 31/50
# 657/657 [==============================] - 20s 31ms/step - loss: 0.1510 - binary_accuracy: 0.9467 - precision: 0.9753 - recall: 0.9158 - val_loss: 1.1974 - val_binary_accuracy: 0.8581 - val_precision: 0.8949 - val_recall: 0.8218
# - val_f1: 0.8568
# Epoch 32/50
# 657/657 [==============================] - 20s 31ms/step - loss: 0.2436 - binary_accuracy: 0.9507 - precision: 0.9765 - recall: 0.9216 - val_loss: 1.1471 - val_binary_accuracy: 0.8642 - val_precision: 0.9041 - val_recall: 0.8239
# - val_f1: 0.8519
# Epoch 33/50
# 657/657 [==============================] - 20s 31ms/step - loss: 1.5812 - binary_accuracy: 0.9517 - precision: 0.9758 - recall: 0.9263 - val_loss: 1.1501 - val_binary_accuracy: 0.8642 - val_precision: 0.9116 - val_recall: 0.8155
# - val_f1: 0.861
# Epoch 34/50
# 657/657 [==============================] - 20s 31ms/step - loss: 0.1503 - binary_accuracy: 0.9553 - precision: 0.9788 - recall: 0.9298 - val_loss: 1.1907 - val_binary_accuracy: 0.8532 - val_precision: 0.8432 - val_recall: 0.8790
# - val_f1: 0.8557
# Epoch 35/50
# 657/657 [==============================] - 21s 32ms/step - loss: 0.2247 - binary_accuracy: 0.9588 - precision: 0.9771 - recall: 0.9379 - val_loss: 1.1884 - val_binary_accuracy: 0.8592 - val_precision: 0.8590 - val_recall: 0.8690
# - val_f1: 0.8664
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 0.000500000023749.
# Epoch 36/50
# 657/657 [==============================] - 21s 31ms/step - loss: 0.1185 - binary_accuracy: 0.9614 - precision: 0.9796 - recall: 0.9421 - val_loss: 1.1869 - val_binary_accuracy: 0.8687 - val_precision: 0.8957 - val_recall: 0.8440
# - val_f1: 0.8663
# Epoch 37/50
# 657/657 [==============================] - 20s 31ms/step - loss: 0.1140 - binary_accuracy: 0.9625 - precision: 0.9801 - recall: 0.9428 - val_loss: 1.1874 - val_binary_accuracy: 0.8656 - val_precision: 0.8904 - val_recall: 0.8410
# - val_f1: 0.8716
# Epoch 38/50
# 657/657 [==============================] - 21s 32ms/step - loss: 0.1069 - binary_accuracy: 0.9676 - precision: 0.9839 - recall: 0.9493 - val_loss: 1.1978 - val_binary_accuracy: 0.8685 - val_precision: 0.8986 - val_recall: 0.8395
# - val_f1: 0.8653
# Epoch 39/50
# 657/657 [==============================] - 20s 31ms/step - loss: 0.6174 - binary_accuracy: 0.9688 - precision: 0.9840 - recall: 0.9521 - val_loss: 1.1831 - val_binary_accuracy: 0.8704 - val_precision: 0.8945 - val_recall: 0.8486
# - val_f1: 0.8702
# Epoch 40/50
# 657/657 [==============================] - 21s 31ms/step - loss: 0.1002 - binary_accuracy: 0.9705 - precision: 0.9857 - recall: 0.9542 - val_loss: 1.1759 - val_binary_accuracy: 0.8722 - val_precision: 0.8967 - val_recall: 0.8504
# - val_f1: 0.8694
# Epoch 41/50
# 657/657 [==============================] - 21s 31ms/step - loss: 0.4175 - binary_accuracy: 0.9707 - precision: 0.9863 - recall: 0.9541 - val_loss: 1.2151 - val_binary_accuracy: 0.8673 - val_precision: 0.8719 - val_recall: 0.8709
# - val_f1: 0.8679
# Epoch 42/50
# 657/657 [==============================] - 21s 31ms/step - loss: 0.1729 - binary_accuracy: 0.9708 - precision: 0.9854 - recall: 0.9550 - val_loss: 1.2460 - val_binary_accuracy: 0.8639 - val_precision: 0.8869 - val_recall: 0.8425
# - val_f1: 0.867
# Epoch 43/50
# 657/657 [==============================] - 21s 32ms/step - loss: 0.3921 - binary_accuracy: 0.9736 - precision: 0.9871 - recall: 0.9592 - val_loss: 1.2478 - val_binary_accuracy: 0.8722 - val_precision: 0.9063 - val_recall: 0.8382
# - val_f1: 0.8715
#
# Epoch 00043: ReduceLROnPlateau reducing learning rate to 0.000250000011874.
# Epoch 44/50
# 657/657 [==============================] - 21s 32ms/step - loss: 0.0979 - binary_accuracy: 0.9755 - precision: 0.9883 - recall: 0.9613 - val_loss: 1.2382 - val_binary_accuracy: 0.8704 - val_precision: 0.8961 - val_recall: 0.8462
# - val_f1: 0.8697
# Epoch 45/50
# 657/657 [==============================] - 20s 31ms/step - loss: 0.0904 - binary_accuracy: 0.9738 - precision: 0.9865 - recall: 0.9602 - val_loss: 1.2490 - val_binary_accuracy: 0.8708 - val_precision: 0.9077 - val_recall: 0.8328
# - val_f1: 0.8689
# Epoch 46/50
# 657/657 [==============================] - 21s 31ms/step - loss: 0.0870 - binary_accuracy: 0.9758 - precision: 0.9874 - recall: 0.9631 - val_loss: 1.2504 - val_binary_accuracy: 0.8687 - val_precision: 0.8966 - val_recall: 0.8423
# - val_f1: 0.8776
#
# Epoch 00046: ReduceLROnPlateau reducing learning rate to 0.000125000005937.
# Epoch 47/50
# 657/657 [==============================] - 20s 31ms/step - loss: 0.0849 - binary_accuracy: 0.9773 - precision: 0.9886 - recall: 0.9649 - val_loss: 1.2594 - val_binary_accuracy: 0.8691 - val_precision: 0.9035 - val_recall: 0.8364
# - val_f1: 0.873
# Restoring model weights from the end of the best epoch.
# Epoch 00047: early stopping
# 101/101 [==============================] - 3s 27ms/step - loss: 1.1854 - binary_accuracy: 0.8683 - precision: 0.8932 - recall: 0.8449
# 2809 317 520 2818
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[2809,  317],
#        [ 520, 2818]], dtype=int32)>
#               precision    recall  f1-score   support
#
#        noise       0.84      0.90      0.87      3126
#    not_noise       0.90      0.84      0.87      3338
#
#     accuracy                           0.87      6464
#    macro avg       0.87      0.87      0.87      6464
# weighted avg       0.87      0.87      0.87      6464
#
# Evaluating train:
# 657/657 [==============================] - 18s 27ms/step - loss: 0.0993 - binary_accuracy: 0.9711 - precision: 0.9853 - recall: 0.9557
# 21052 273 959 19764
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[21052,   273],
#        [  959, 19764]], dtype=int32)>
#               precision    recall  f1-score   support
#
#        noise       0.96      0.99      0.97     21325
#    not_noise       0.99      0.95      0.97     20723
#
#     accuracy                           0.97     42048
#    macro avg       0.97      0.97      0.97     42048
# weighted avg       0.97      0.97      0.97     42048
#
# Saving file. 1 rows.
# results_DENSE_grow_noiseNotNoise_timeAug_standard_noiseAug_earlyS_unbalanced_valtest_subsample-0.25_numChannels-3.csv saved to path:   /media/tord/T7/Thesis_ssd/MasterThesis3/GridSearchResults/2_classes
# batch_size                                                  64
# epochs                                                      50
# learning_rate                                            0.001
# optimizer                                              rmsprop
# num_layers                                                   1
# units                                                      200
# dropout_T_bn_F                                           False
# use_layerwise_dropout_batchnorm                          False
# growth_sequence                                            [1]
# dropout_rate                                               0.1
# l2_r                                                         0
# l1_r                                                         0
# activation                                                relu
# output_layer_activation                                sigmoid
# train_loss                                            0.099296
# train_accuracy                                          0.9707
# train_precision                                       0.986375
# train_recall                                          0.953723
# train_f1                                              0.969774
# val_loss                                              1.185439
# val_accuracy                                          0.870514
# val_precision                                         0.898884
# val_recall                                            0.844218
# val_f1                                                0.870694
# confusion_matrix                   [[2809  317]\n [ 520 2818]]
# Name: 0, dtype: object
# Unsaved train eval:
# 21040 285 909 19814
# ['noise', 'not_noise']
# 3N
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[21040,   285],
#        [  909, 19814]], dtype=int32)>
#               precision    recall  f1-score   support
#
#        noise       0.96      0.99      0.97     21325
#    not_noise       0.99      0.96      0.97     20723
#
#     accuracy                           0.97     42048
#    macro avg       0.97      0.97      0.97     42048
# weighted avg       0.97      0.97      0.97     42048
#
# Unsaved val eval:
# 2798 328 542 2796
# ['noise', 'not_noise']
# 3N
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[2798,  328],
#        [ 542, 2796]], dtype=int32)>
#               precision    recall  f1-score   support
#
#        noise       0.84      0.90      0.87      3126
#    not_noise       0.90      0.84      0.87      3338
#
#     accuracy                           0.87      6464
#    macro avg       0.87      0.87      0.87      6464
# weighted avg       0.87      0.87      0.87      6464
#
# Unsaved test eval:
# 1835 230 320 1903
# ['noise', 'not_noise']
# 3N
# <tf.Tensor: shape=(2, 2), dtype=int32, numpy=
# array([[1835,  230],
#        [ 320, 1903]], dtype=int32)>
#               precision    recall  f1-score   support
#
#        noise       0.85      0.89      0.87      2065
#    not_noise       0.89      0.86      0.87      2223
#
#     accuracy                           0.87      4288
#    macro avg       0.87      0.87      0.87      4288
# weighted avg       0.87      0.87      0.87      4288

# %%
helper.evaluate_RamGenerator()
