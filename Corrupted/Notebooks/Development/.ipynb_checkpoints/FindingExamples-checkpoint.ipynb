# %%
import numpy as np
import pandas as pd
import h5py
import gc

import sklearn as sk

from sklearn.model_selection import ParameterGrid




import tensorflow as tf
from tensorflow.keras import mixed_precision
from tensorflow.keras.utils import GeneratorEnqueuer

import os
base_dir = '/media/tord/T7/Thesis_ssd/MasterThesis3'
os.chdir(base_dir)

from Classes.Modeling.DynamicModels import DynamicModels
from Classes.Modeling.StaticModels import StaticModels
from Classes.DataProcessing.LoadData import LoadData
from Classes.DataProcessing.HelperFunctions import HelperFunctions
from Classes.DataProcessing.DataHandler import DataHandler
from Classes.DataProcessing.RamLoader import RamLoader
from Classes.Modeling.GridSearchResultProcessor import GridSearchResultProcessor
from Classes.DataProcessing.ts_RamGenerator import data_generator



import sys


import random
import pprint
import re
import json
# Out:
# WARNING:tensorflow:From /home/tord/miniconda3/envs/thesis/lib/python3.8/site-packages/tensorflow/python/util/module_wrapper.py:49: The name tf.keras.layers.CuDNNLSTM is deprecated. Please use tf.compat.v1.keras.layers.CuDNNLSTM instead.
#
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: GeForce RTX 3090, compute capability 8.6

# %%
load_args = {
    'earth_explo_only' : False,
    'noise_earth_only' : False,
    'noise_not_noise' : True,
    'downsample' : True,
    'upsample' : True,
    'frac_diff' : 1,
    'seed' : 1,
    'subsample_size' : 0.05,
    'balance_non_train_set' : True,
    'use_true_test_set' : False,
    'even_balance' : True
}
loadData = LoadData(**load_args)
train_ds, val_ds, test_ds = loadData.get_datasets()
noise_ds = loadData.noise_ds
handler = DataHandler(loadData)
helper = HelperFunctions()
# Out:
# 2 2
# 2 2
# 2 2
# Mapping train redundancy: : [------>                                 ] 19 %
# Mapping train redundancy: : [---------->                             ] 29 %
# Mapping train redundancy: : [-------------->                         ] 38 %
# Mapping train redundancy: : [------------------>                     ] 49 %
# Mapping train redundancy: : [---------------------->                 ] 59 %
# Mapping train redundancy: : [-------------------------->             ] 69 %
# Mapping train redundancy: : [------------------------------>         ] 79 %
# Mapping train redundancy: : [---------------------------------->     ] 89 %
# Mapping train redundancy: : [--------------------------------------> ] 98 %
# Mapping train redundancy: : [--------------------------------------->] 100 %
#
# Mapping validation redundancy: : [--------------------------------------->] 100 %
#
# Mapping test redundancy: : [--------------------------------------->] 100 %
#
#
#
# Loaded explosion and earthquake dataset:
# Evenly balanced among classes in the train set.
# As well as non train sets.
# Distribution (Label: (counts, proportion)) of
# Train ds:
# earthquake: (4089, 0.4972)  |  explosion: (4135, 0.5028)
# Val ds:
# earthquake: (613, 0.4972)  |  explosion: (620, 0.5028)
# Test ds:
# earthquake: (406, 0.4939)  |  explosion: (416, 0.5061)

# %%
use_time_augmentor = None
use_noise_augmentor = None
scaler_name = "normalize"
filter_name = "highpass"
band_min = 2
band_max = 4
highpass_freq = 0.075

use_tensorboard = False
use_liveplots = False
use_custom_callback = False
use_early_stopping = False
start_from_scratch = False
use_reduced_lr = False
log_data = False

load_test_set = False


ramLoader = RamLoader(loadData, 
                      handler, 
                      use_time_augmentor = use_time_augmentor, 
                      use_noise_augmentor = use_noise_augmentor, 
                      scaler_name = scaler_name,
                      filter_name = filter_name, 
                      band_min = band_min,
                      band_max = band_max,
                      highpass_freq = highpass_freq, 
                      load_test_set = load_test_set)
x_train, y_train, x_val, y_val, noiseAug = ramLoader.load_to_ram()
# Out:
# Stage one loading training set, highpass: [--------------------------------------->] 100 %
#
# Stage one loading validation set, highpass: [--------------------------------------->] 100 %
#
# Fit process of normalizer skipped as unecessary
#
#
# Stage two loading training set, labels and normalize scaler: [--------------------------------------->] 100 %
#
# Stage two loading validation set, labels and normalize scaler: [--------------------------------------->] 100 %
#
#
#
# Completed loading to RAM
# Process took 0:04:22.402411 seconds.

# %%
i = 0

# %%
i -=1
sample_trace = x_train[i]
sample_label = y_train[i]
print(sample_label)
print(sample_label, train_ds[:,1][i])
original_trace, sample_info = handler.path_to_trace(train_ds[i][0])
helper.plot_event(sample_trace, sample_info)
helper.plot_event(original_trace, sample_info)
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(sample_info)
# Out:
# [0]
# [0] earthquake
# {   'analyst_pick_time': None,
#     'az_to_arces': 135.5069999234114,
#     'baz_to_arces': 329.2485204691264,
#     'dist_to_arces': 795.56775931593,
#     'est_arrivaltime_arces': '2016-09-17 00:44:35.270000',
#     'event_type': 'earthquake',
#     'event_type_certainty': 'known',
#     'magnitude_dist_ratio': 0.003563492822330657,
#     'magnitude_sqrtdist_ratio': 0.10051120410833517,
#     'magnitudes': [   {   'mag': 2.835,
#                           'magnitude_type': 'Mb',
#                           'origin_id': 'smi:local/ebb7f108-e1fb-42bb-a063-e7887601628c',
#                           'resource_id': 'smi:local/6dc01a87-e5f1-4976-aff7-fe6a7c9dab7d'},
#                       {   'mag': 2.13,
#                           'magnitude_type': 'Ml',
#                           'origin_id': 'smi:local/ebb7f108-e1fb-42bb-a063-e7887601628c',
#                           'resource_id': 'smi:local/d482bbcb-e128-4275-8f09-3f07d6c1b753'}],
#     'origins': [   {   'arrivals': [   {   'azimuth': 338.83993,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/2a603728-f4e6-41de-bebd-8c227837bc80',
#                                                                'text': 'ARID=59965'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Pn',
#                                            'pick_id': 'smi:local/63717c18-c316-4eb2-adee-289658e1cb6e',
#                                            'resource_id': 'smi:local/69e78d2a-9c3b-4bc8-8a1b-024afd0d952f',
#                                            'time_residual': -2.2217931},
#                                        {   'azimuth': 195.6956,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/e6195b20-6278-4ddf-9be5-73dcefda7ef3',
#                                                                'text': 'ARID=59967'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Sn',
#                                            'pick_id': 'smi:local/c6c7cdcb-3f4c-45bc-851b-081159aff517',
#                                            'resource_id': 'smi:local/42c577c0-4e00-4679-ba32-badee629876a',
#                                            'time_residual': -3.7089582},
#                                        {   'azimuth': 195.6956,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/fe8e831e-830e-4d0b-9282-cbff6574f8f4',
#                                                                'text': 'ARID=59968'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Pn',
#                                            'pick_id': 'smi:local/8c0f8406-cf42-4b4e-a524-d3994a0fb18b',
#                                            'resource_id': 'smi:local/8b2d5624-84a6-4f56-8f68-5016a86629f3',
#                                            'time_residual': -2.1912379},
#                                        {   'azimuth': 256.0524,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/1bb7c1a6-441f-4211-80b0-f8d753e04433',
#                                                                'text': 'ARID=59969'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Sn',
#                                            'pick_id': 'smi:local/2ed876b2-e058-4570-9f73-30c0b826919d',
#                                            'resource_id': 'smi:local/293bcb60-d54b-4d9a-8a35-c8888098de79',
#                                            'time_residual': 0.13012492},
#                                        {   'azimuth': 256.0524,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/07c072b5-6b58-416b-a8e1-828a7a3ddd7a',
#                                                                'text': 'ARID=59970'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Pn',
#                                            'pick_id': 'smi:local/e3670155-7016-4d1e-94e8-c81f6cdc8c05',
#                                            'resource_id': 'smi:local/7007cc8f-ee9d-4c37-9946-bbfe06fab444',
#                                            'time_residual': -0.7175206},
#                                        {   'azimuth': 293.0034,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/e6e43f60-4f3b-4c5b-8c32-263e9f4f71d9',
#                                                                'text': 'ARID=59971'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Sn',
#                                            'pick_id': 'smi:local/ebff99ba-f77b-4b79-bf2c-a92b8b355edf',
#                                            'resource_id': 'smi:local/ad4f2655-c409-4685-9dad-e2179781e73e',
#                                            'time_residual': -3.3734446},
#                                        {   'azimuth': 293.0034,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/cdfbc9a6-617a-473c-8638-1634c5a2abac',
#                                                                'text': 'ARID=59972'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Pn',
#                                            'pick_id': 'smi:local/a7b70674-a17a-47c9-93ca-943dc12551f0',
#                                            'resource_id': 'smi:local/de986ea2-f6e1-4745-b10d-9d3d0c79340c',
#                                            'time_residual': -2.138144},
#                                        {   'azimuth': 204.81064,
#                                            'backazimuth_residual': -1.0611517,
#                                            'comments': [   {   'resource_id': 'smi:local/fe905840-7bb3-4262-890b-ddfc5f644b97',
#                                                                'text': 'ARID=59973'}],
#                                            'horizontal_slowness_residual': -0.10215226,
#                                            'phase': 'Sn',
#                                            'pick_id': 'smi:local/02af0853-ea95-42b4-9afe-1cf9149df6ed',
#                                            'resource_id': 'smi:local/125ccd10-2612-423c-bfd8-b11f17a682af',
#                                            'time_residual': 0.80831269},
#                                        {   'azimuth': 212.92519,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/be5fab3e-6580-475e-ace4-7c59d0a60928',
#                                                                'text': 'ARID=59974'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Sn',
#                                            'pick_id': 'smi:local/bfa9a600-7c52-4669-b47c-9e071e0c42f0',
#                                            'resource_id': 'smi:local/9daa5fa4-13ab-4042-af3e-b26dba76c898',
#                                            'time_residual': -2.8837198},
#                                        {   'azimuth': 212.92519,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/938a6e52-b04a-4ccb-9816-99d911505053',
#                                                                'text': 'ARID=59975'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Pn',
#                                            'pick_id': 'smi:local/5af9d9ac-39cc-4253-9541-61bf935398ce',
#                                            'resource_id': 'smi:local/1beb8485-6285-496e-8405-be8cd40ce576',
#                                            'time_residual': -1.8247797},
#                                        {   'azimuth': 204.81064,
#                                            'backazimuth_residual': -5.8906417,
#                                            'comments': [   {   'resource_id': 'smi:local/bf110316-4d4c-4bcc-bef6-a6fcdde90f44',
#                                                                'text': 'ARID=8676689'}],
#                                            'horizontal_slowness_residual': -0.66029469,
#                                            'phase': 'Pn',
#                                            'pick_id': 'smi:local/205c45bc-bbc4-4f08-b841-34d7fb1c70bd',
#                                            'resource_id': 'smi:local/aa013999-a6dd-43c9-a6a4-28472b35b77d',
#                                            'time_residual': 0.69010389},
#                                        {   'azimuth': 329.23052,
#                                            'backazimuth_residual': -11.980517,
#                                            'comments': [   {   'resource_id': 'smi:local/1c0b8faa-f5d4-4701-a0cd-4b3e92f3aa44',
#                                                                'text': 'ARID=8676569'}],
#                                            'horizontal_slowness_residual': -3.9382562,
#                                            'phase': 'Pn',
#                                            'pick_id': 'smi:local/7cc974e0-8b70-430c-a39e-e31864e7669e',
#                                            'resource_id': 'smi:local/96cd5070-01fe-4efb-8c3f-73e37489c89f',
#                                            'time_residual': 0.93249943},
#                                        {   'azimuth': 329.23052,
#                                            'backazimuth_residual': -1.720517,
#                                            'comments': [   {   'resource_id': 'smi:local/4c0aecd9-29b9-4da1-b18d-96fab2252de8',
#                                                                'text': 'ARID=8676583'}],
#                                            'horizontal_slowness_residual': -5.6038944,
#                                            'phase': 'Sn',
#                                            'pick_id': 'smi:local/830c8283-b95e-47e3-bc82-b56916cdf867',
#                                            'resource_id': 'smi:local/23ef6251-62f9-4373-8468-deac960fca7b',
#                                            'time_residual': -6.1363887},
#                                        {   'azimuth': 183.25711,
#                                            'backazimuth_residual': -999.0,
#                                            'comments': [   {   'resource_id': 'smi:local/9bde087f-9db8-494f-81af-00239b76ecf0',
#                                                                'text': 'ARID=59964'}],
#                                            'horizontal_slowness_residual': -999.0,
#                                            'phase': 'Pn',
#                                            'pick_id': 'smi:local/c4990a03-fe0e-4230-841a-3b7a154c4e71',
#                                            'resource_id': 'smi:local/9eb13964-4ebb-49bc-93e0-708d7621fa5b',
#                                            'time_residual': -0.60910123}],
#                        'comments': [   {   'resource_id': 'smi:local/aea18860-cb39-430c-8427-0acc3185baac',
#                                            'text': 'orid: 20134'}],
#                        'creation_info': {   'agency_id': 'NORSAR',
#                                             'author': 'ARS:berit',
#                                             'creation_time': '2016-09-30T09:14:22.000000Z'},
#                        'depth': 0.0,
#                        'depth_errors': {'uncertainty': -1.0},
#                        'latitude': 75.22037,
#                        'longitude': 11.116217,
#                        'quality': {   'associated_phase_count': 14,
#                                       'used_phase_count': 10},
#                        'resource_id': 'smi:local/ebb7f108-e1fb-42bb-a063-e7887601628c',
#                        'time': '2016-09-17T00:42:32.875520Z',
#                        'time_errors': {'uncertainty': 2.5217611}}],
#     'picks': [   {   'backazimuth': 317.25,
#                      'backazimuth_errors': {'uncertainty': 0.11},
#                      'horizontal_slowness': 9.79,
#                      'horizontal_slowness_errors': {'uncertainty': 1.12},
#                      'phase_hint': 'Pn',
#                      'resource_id': 'smi:local/7cc974e0-8b70-430c-a39e-e31864e7669e',
#                      'time': '2016-09-17T00:44:18.400000Z',
#                      'waveform_id': {   'channel_code': 'FE23',
#                                         'station_code': 'ARCES'}},
#                  {   'backazimuth': 327.51,
#                      'backazimuth_errors': {'uncertainty': 0.07},
#                      'horizontal_slowness': 19.05,
#                      'horizontal_slowness_errors': {'uncertainty': 1.28},
#                      'phase_hint': 'Sn',
#                      'resource_id': 'smi:local/830c8283-b95e-47e3-bc82-b56916cdf867',
#                      'time': '2016-09-17T00:45:31.025000Z',
#                      'waveform_id': {   'channel_code': 'FR36',
#                                         'station_code': 'ARCES'}}],
#     'resource_id': 'smi:local/9cfc91be-5f07-4172-b521-743f2654544b',
#     'trace_stats': {   'channels': [   'P-beam, vertical',
#                                        'S-beam, transverse',
#                                        'S-beam, radial'],
#                        'sampling_rate': 40.0,
#                        'starttime': '2016-09-17T00:43:35.275000Z',
#                        'station': 'ARCES beam'}}

# %%
train_ds[:,0][0]
# Out:
# '/media/tord/T7/Thesis_ssd/norsar_data_nov/explosions/2011-07-20T20.40.46.869000Z.h5'

# %%
earth_ex = '/media/tord/T7/Thesis_ssd/norsar_data_nov/explosions/1991-12-08T17.19.41.051000Z.h5'
original_trace, sample_info = handler.path_to_trace(earth_ex)
helper.plot_event(sample_trace, sample_info)
helper.plot_event(original_trace, sample_info)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-7-6987775ccf9a> in <module>
#       1 earth_ex = '/media/tord/T7/Thesis_ssd/norsar_data_nov/explosions/1991-12-08T17.19.41.051000Z.h5'
# ----> 2 original_trace, sample_info = handler.path_to_trace(earth_ex)
#       3 helper.plot_event(sample_trace, sample_info)
#       4 helper.plot_event(original_trace, sample_info)
#
# /media/tord/T7/Thesis_ssd/MasterThesis3/Classes/DataProcessing/DataHandler.py in path_to_trace(self, path)
#      32
#      33     def path_to_trace(self, path):
# ---> 34         with h5py.File(path, 'r') as dp:
#      35             trace_array = np.array(dp.get('traces'))
#      36             info = np.array(dp.get('event_info'))
#
# ~/.local/lib/python3.8/site-packages/h5py/_hl/files.py in __init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, **kwds)
#     422             with phil:
#     423                 fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0, **kwds)
# --> 424                 fid = make_fid(name, mode, userblock_size,
#     425                                fapl, fcpl=make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     426                                fs_persist=fs_persist, fs_threshold=fs_threshold),
#
# ~/.local/lib/python3.8/site-packages/h5py/_hl/files.py in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     188         if swmr and swmr_support:
#     189             flags |= h5f.ACC_SWMR_READ
# --> 190         fid = h5f.open(name, flags, fapl=fapl)
#     191     elif mode == 'r+':
#     192         fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/_objects.pyx in h5py._objects.with_phil.wrapper()
#
# h5py/h5f.pyx in h5py.h5f.open()
#
# OSError: Unable to open file (unable to open file: name = '/media/tord/T7/Thesis_ssd/norsar_data_nov/explosions/1991-12-08T17.19.41.051000Z.h5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
