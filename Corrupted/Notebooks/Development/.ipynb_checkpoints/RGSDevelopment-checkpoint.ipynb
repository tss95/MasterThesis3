# %%
import numpy as np
import os
import sys
import pandas as pd


import seaborn as sns

import pylab as pl
import h5py

import tensorflow as tf

os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
os.environ['CUDA_VISIBLE_DEVICES']="0" 

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)

base_dir = '/media/tord/T7/Thesis_ssd/MasterThesis3/'
os.chdir(base_dir)

from GlobalUtils import GlobalUtils
utils = GlobalUtils()
os.chdir(utils.base_dir)
from Classes.DataProcessing.HelperFunctions import HelperFunctions
from Classes.DataProcessing.DataHandler import DataHandler
from Classes.DataProcessing.LoadData import LoadData
from Classes.DataProcessing.RamLoader import RamLoader
gen_dir = '/media/tord/T7/Thesis_ssd/MasterThesis3/Classes/DataProcessing'
os.chdir(gen_dir)
import ts_RamGenerator
os.chdir(base_dir)


helper = HelperFunctions()

import sys
ISCOLAB = 'google.colab' in sys.modules

import random
import pprint
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
load_args = {
    'earth_explo_only' : False,
    'noise_earth_only' : False,
    'noise_not_noise' : True,
    'downsample' : True,
    'upsample' : True,
    'frac_diff' : 1,
    'seed' : 1,
    'subsample_size' : 0.05,
    'balance_non_train_set' : False,
    'use_true_test_set' : False,
    'even_balance' : False
}
loadData = LoadData(**load_args)
full_ds, train_ds, val_ds, test_ds = loadData.get_datasets()
noise_ds = loadData.noise_ds
handler = DataHandler(loadData)
# Out:
# Mapping redundancy: [--------------------------------->      ] 85 %
# Mapping redundancy: [--------------------------------------->] 100 %

# %%
import numpy as np
import pandas as pd
import h5py
import gc

import sklearn as sk

from sklearn.model_selection import ParameterGrid




import tensorflow as tf
from tensorflow.keras import mixed_precision
from tensorflow.keras.utils import GeneratorEnqueuer

import os
base_dir = '/media/tord/T7/Thesis_ssd/MasterThesis3'
os.chdir(base_dir)

from Classes.Modeling.DynamicModels import DynamicModels
from Classes.Modeling.StaticModels import StaticModels
from Classes.DataProcessing.LoadData import LoadData
from Classes.DataProcessing.HelperFunctions import HelperFunctions
from Classes.DataProcessing.DataHandler import DataHandler
from Classes.DataProcessing.RamLoader import RamLoader
from Classes.DataProcessing.NoiseAugmentor import NoiseAugmentor
from Classes.DataProcessing.TimeAugmentor import TimeAugmentor
from Classes.DataProcessing.DataGenerator import DataGenerator
from Classes.Scaling.MinMaxScalerFitter import MinMaxScalerFitter
from Classes.Scaling.StandardScalerFitter import StandardScalerFitter
from Classes.Modeling.GridSearchResultProcessor import GridSearchResultProcessor
from Classes.DataProcessing.ts_RamGenerator import data_generator


import sys


import random
import pprint
import re
import json

class RandomGridSearchDynamic(GridSearchResultProcessor):
    
    def __init__(self, loadData, train_ds, val_ds, test_ds, model_type, scaler_name, use_time_augmentor, use_noise_augmentor,
                 filter_name, n_picks, hyper_grid, use_tensorboard = False, 
                 use_liveplots = True, use_custom_callback = False, use_early_stopping = False, use_reduced_lr = False,
                 band_min = 2.0, band_max = 4.0, highpass_freq = 0.1, start_from_scratch = True, is_lstm = False, 
                 log_data = True, num_channels = 3):
        
        self.loadData = loadData
        self.train_ds = train_ds
        self.val_ds = val_ds
        self.test_ds = test_ds
        self.model_nr_type = model_type
        self.num_classes = len(set(self.loadData.label_dict.values()))

        self.scaler_name = scaler_name
        self.use_noise_augmentor = use_noise_augmentor
        self.use_time_augmentor = use_time_augmentor
        self.filter_name = filter_name
        self.n_picks = n_picks
        self.hyper_grid = hyper_grid
        self.use_tensorboard = use_tensorboard
        self.use_liveplots = use_liveplots
        self.use_custom_callback = use_custom_callback
        self.use_reduced_lr = use_reduced_lr
        self.use_early_stopping = use_early_stopping

        self.band_min = band_min
        self.band_max = band_max
        self.highpass_freq = highpass_freq
        self.start_from_scratch = start_from_scratch
        self.is_lstm = is_lstm
        self.log_data = log_data
        self.num_channels = num_channels
        
        self.helper = HelperFunctions()
        self.handler = DataHandler(self.loadData)
        self.is_dynamic = False
        if type(self.model_nr_type) == str:
            self.is_dynamic = True
        #if self.loadData.earth_explo_only:
        #    self.full_ds = np.concatenate((self.loadData.noise_ds, self.loadData.full_ds))
        #else:
        #    self.full_ds = self.loadData.full_ds
            

    def fit(self):
        pp = pprint.PrettyPrinter(indent=4)
        # Creating grid:
        self.p = ParameterGrid(self.hyper_grid)
        if len(self.p) < self.n_picks:
            self.n_picks = len(self.p)
            print(f"Picks higher than max. Reducing picks to {self.n_picks} picks")
        self.p = self.get_n_params_from_list(self.p, self.n_picks)
        
        # Create name of results file, get initiated results df, either brand new or continue old.
        self.results_file_name = self.get_results_file_name()
        print(self.results_file_name)
        self.results_df = self.initiate_results_df_opti(self.results_file_name, self.num_classes, self.start_from_scratch, self.p[0])
        print(self.results_df)
        # Preprocessing and loading all data to RAM:
        ramLoader = RamLoader(self.loadData, 
                              self.handler, 
                              use_time_augmentor = self.use_time_augmentor, 
                              use_noise_augmentor = self.use_noise_augmentor, 
                              scaler_name = self.scaler_name,
                              filter_name = self.filter_name, 
                              band_min = self.band_min,
                              band_max = self.band_max,
                              highpass_freq = self.highpass_freq, 
                              load_test_set = False)
        self.x_train, self.y_train, self.x_val, self.y_val, self.timeAug, self.scaler, self.noiseAug = ramLoader.load_to_ram()

        
        
        for i in range(len(self.p)):
            gc.collect()
            tf.keras.backend.clear_session()
            tf.config.optimizer.set_jit(True)
            mixed_precision.set_global_policy('mixed_float16')

            model_info = {"model_nr_type" : self.model_nr_type, "index" : i}
            print(f"Model nr {i + 1} of {len(self.p)}")           
            # Translate picks to a more readable format:
            num_channels = self.num_channels
            epoch = self.p[i]["epochs"]
            batch_size = self.p[i]["batch_size"]
            
            opt = self.helper.get_optimizer(self.p[i]["optimizer"], self.p[i]["learning_rate"])
    

            if "decay_sequence" in self.p[i]:
                if "num_filters" in self.p[i]:
                    units_or_num_filters = self.p[i]["num_filters"]
                else:
                    units_or_num_filters = self.p[i]["units"]
                num_layers = self.p[i]["num_layers"]
                self.p[i]["decay_sequence"] = self.helper.get_max_decay_sequence(num_layers, 
                                                                                units_or_num_filters, 
                                                                                self.p[i]["decay_sequence"], 
                                                                                self.num_classes)
   
            
            
            current_picks = [model_info, self.p[i]]
            pp.pprint(current_picks)
            # Store picked parameters:
            if self.log_data:
                self.results_df = self.store_params_before_fit_opti(self.p[i], self.results_df, self.results_file_name)

            _, _, timesteps = self.x_train.shape

            input_shape = (timesteps, self.num_channels)
            
            if self.is_dynamic:  
                model = DynamicModels(self.model_nr_type, self.num_classes, input_shape, **self.p[i]).model
            else:
                raise Exception("Static models are not handled by this class yet.")
            
            # Initializing generators:
            #gen = RamGenerator(self.loadData, self.handler, self.noiseAug)
            train_enq = GeneratorEnqueuer(data_generator(self.x_train, self.y_train, batch_size, self.loadData, self.handler, self.noiseAug, num_channels = num_channels, is_lstm  = self.is_lstm), use_multiprocessing = False)
            val_enq = GeneratorEnqueuer(data_generator(self.x_val, self.y_val,batch_size, self.loadData, self.handler, self.noiseAug, num_channels = num_channels, is_lstm  = self.is_lstm), use_multiprocessing = False)
            train_enq.start(workers = 16, max_queue_size = 15)
            val_enq.start(workers = 16, max_queue_size = 15)
            train_gen = train_enq.get()
            val_gen = train_enq.get()

            # Generate compiler args using picks
            model_compile_args = self.helper.generate_model_compile_args(opt, self.num_classes)
            # Compile model using generated args
            model.compile(**model_compile_args)
            
            print("Starting: ")
            pp.pprint(self.p[i])
            print("---------------------------------------------------------------------------------")

            
            # Generate fit args using picks.
            fit_args = self.helper.generate_fit_args(self.train_ds, self.val_ds, batch_size, 
                                                     epoch, val_gen, use_tensorboard = self.use_tensorboard, 
                                                     use_liveplots = self.use_liveplots, 
                                                     use_custom_callback = self.use_custom_callback,
                                                     use_early_stopping = self.use_early_stopping,
                                                     use_reduced_lr = self.use_reduced_lr)
            try:
                print(f"Utilizes {self.helper.get_steps_per_epoch(self.loadData.val, batch_size)*batch_size}/{len(self.loadData.val)} validation points")
                print(f"Utilizes {self.helper.get_steps_per_epoch(self.loadData.train, batch_size)*batch_size}/{len(self.loadData.train)} training points")
                
                
                # Fit the model using the generated args
                model.fit(train_gen, **fit_args)
                
                # Evaluate the fitted model on the validation set
                val_eval = model.evaluate(x=val_gen,
                                          steps=self.helper.get_steps_per_epoch(self.loadData.val, batch_size),
                                          return_dict = True)
                pp.pprint(val_eval)
                
                metrics = {}
                metrics['val'] = {  "val_loss" : val_eval["loss"],
                                    "val_accuracy" : val_eval["binary_accuracy"],
                                    "val_precision": val_eval["precision"],
                                    "val_recall" : val_eval["recall"]}
                
                # Evaluate the fitted model on the train set
                
                train_eval = model.evaluate(x=train_gen,
                                            steps=self.helper.get_steps_per_epoch(self.loadData.train, batch_size),
                                            return_dict = True)
                train_enq.stop()
                val_enq.stop()
                
                metrics['train'] = { "train_loss" : train_eval["loss"],
                                    "train_accuracy" : train_eval["binary_accuracy"],
                                    "train_precision": train_eval["precision"],
                                    "train_recall" : train_eval["recall"]}
                
                
                _ = self.helper.evaluate_model(model, self.x_val, self.y_val, self.loadData.label_dict, num_channels = self.num_channels, plot = False, run_evaluate = False)
                train_enq.stop()
                val_enq.stop()
                gc.collect()
                
                tf.keras.backend.clear_session()
                tf.compat.v1.reset_default_graph()
                del model, train_gen, val_gen, train_enq, val_enq
                
                if self.log_data:
                    self.results_df = self.store_metrics_after_fit(metrics, self.results_df, self.results_file_name)

            except Exception as e:
                print(str(e))
                print("Something went wrong while training the model (most likely)")

                continue


    def print_best_performers(self, min_loss, max_accuracy, max_precision, max_recall):
        print("----------------------------------------------------LOSS----------------------------------------------------------")
        print(f"Min val loss: {min_loss['val_loss']}, at index: {min_loss['val_index']}")
        print(f"Min training loss: {min_loss['train_loss']}, at index: {min_loss['train_index']}")
        print("----------------------------------------------------ACCURACY------------------------------------------------------")
        print(f"Highest val accuracy: {max_accuracy['val_accuracy']}, at index: {max_accuracy['val_index']}")
        print(f"Highest training accuracy: {max_accuracy['train_accuracy']}, at index: {max_accuracy['train_index']}")
        print("----------------------------------------------------PRECISION-----------------------------------------------------")
        print(f"Highest val precision: {max_precision['val_precision']}, at index: {max_precision['val_index']}")
        print(f"Highest training precision: {max_precision['train_precision']}, at index: {max_precision['train_index']}") 
        print("-----------------------------------------------------RECALL-------------------------------------------------------")
        print(f"Highest val recall: {max_recall['val_recall']}, at index: {max_recall['val_index']}")
        print(f"Highest training recall: {max_recall['train_recall']}, at index: {max_recall['train_index']}")
        print("------------------------------------------------------------------------------------------------------------------")
       

    
    def get_n_params_from_list(self, grid, n_picks):
        print(f"Length of grid: {len(grid)}")
        indexes = random.sample(range(0, len(grid)), n_picks)
        picks = [grid[idx] for idx in indexes]
        return picks

# %%
# IncepTime grid:
hyper_grid = {    
    "batch_size" : [64, 128, 256],
    "epochs" : [50, 50, 50, 50, 50, 50, 50, 50, 50],
    "learning_rate" : [0.1, 0.01, 0.01, 0.001, 0.0001],
    "optimizer" : ["adam", "adam", "adam", "adam", "rmsprop", "sgd", "adam", "rmsprop", "sgd"],
    "use_residuals" : [True, True, False],
    "use_bottleneck" : [True, True, False],
    "num_modules" : np.concatenate((np.array([1]), np.arange(3, 9, 3))),
    "filter_size" : np.arange(30, 60, 2),
    "bottleneck_size" : np.arange(30, 50, 2),
    "num_filters" : np.arange(20, 40, 2),
    "residual_activation" : ["relu", "relu", "relu", "relu", "tanh"],
    "module_activation" : ["linear", "linear", "linear", "relu", "tanh"],
    "module_output_activation" : ["relu", "relu", "relu", "relu", "linear", "tanh"],
    "output_layer_activation": ["sigmoid"],
    "reg_residual": [True, False, False],
    "reg_module" : [True, False, False],
    "l1_r" : [0.1, 0.01, 0.01, 0.001, 0.0001, 0],
    "l2_r" : [0.1, 0.01, 0.01, 0.001, 0.0001, 0]
}

# Dense grid:
"""
hyper_grid = {
        "batch_size" : [64, 128, 256],
        "epochs" : [50, 50, 50, 50, 50, 50, 50, 50, 50],
        "learning_rate" : [0.1, 0.01, 0.01, 0.001, 0.001, 0.0001, 0.0001],
        "optimizer" : ["sgd", "sgd", "sgd", "sgd", "rmsprop", "adam", "rmsprop", "sgd"],
        "num_layers" : [1, 2, 3, 4, 5],
        "units" : np.arange(100, 300, 10),
        "use_layerwise_dropout_batchnorm" : [False, True],
        "decay_sequence" : [[1,2,4,4,2,1], [1,4,8,8,4,1], [1,1,1,1,1,1], [1, 2, 4, 6, 8, 10]],
        "dropout_rate" : [0.3, 0.2, 0.1, 0.01, 0.001, 0],
        "l2_r" : [0.3, 0.2, 0.1, 0.01, 0.001, 0.0001],
        "l1_r" : [0.3, 0.2, 0.1, 0.01, 0.001, 0.0001],
        "activation" : ["tanh", "tanh", "relu", "relu", "relu", "sigmoid", "softmax"],
        "output_layer_activation" : ["sigmoid"]
    }
"""


model_type = "InceptionTime"
is_lstm = True
num_channels = 2    

use_time_augmentor = True
scaler_name = "standard"
use_noise_augmentor = True
filter_name = None
band_min = 2.0
band_max = 4.0
highpass_freq = 15

n_picks = 100

use_tensorboard = False
use_liveplots = False
use_custom_callback = True
use_early_stopping = True
start_from_scratch = True
use_reduced_lr = True
log_data = True

shutdown = False

def clear_tensorboard_dir():
        import os
        import shutil
        path = f"{base_dir}/Tensorboard_dir/fit"
        files = os.listdir(path)
        print(files)
        for f in files:
            shutil.rmtree(os.path.join(path,f))
if use_tensorboard:
    clear_tensorboard_dir()



randomGridSearch = RandomGridSearchDynamic(loadData, train_ds, val_ds, test_ds, model_type, scaler_name, use_time_augmentor, use_noise_augmentor,
                                            filter_name, n_picks, hyper_grid=hyper_grid, use_tensorboard = use_tensorboard, 
                                            use_liveplots = use_liveplots, use_custom_callback = use_custom_callback, use_early_stopping = use_early_stopping, 
                                            use_reduced_lr = use_reduced_lr, band_min = band_min, band_max = band_max, highpass_freq = highpass_freq, 
                                            start_from_scratch = start_from_scratch, is_lstm = is_lstm, log_data = log_data, num_channels = num_channels)
results_df, min_loss, max_accuracy, max_precision, max_recall = randomGridSearch.fit()
# Out:
# Length of grid: 2391484500000
# results_InceptionTime_noiseNotNoise_timeAug_noiseAug_earlyS_numChannels-2.csv
# Empty DataFrame
# Columns: [use_residuals, use_bottleneck, residual_activation, reg_residual, reg_module, output_layer_activation, optimizer, num_modules, num_filters, module_output_activation, module_activation, learning_rate, l2_r, l1_r, filter_size, epochs, bottleneck_size, batch_size, train_loss, train_accuracy, train_precision, train_recall, val_loss, val_accuracy, val_precision, val_recall]
# Index: []
#
# [0 rows x 26 columns]
# Fit process completed after 41.12778639793396 seconds. Total datapoints fitted: 14475.
# Average time per datapoint: 0.0028412978513253167
#
#
# Stage one loading training set, timeAug: [--------------------------------------->] 100 %
#
# Stage one loading validation set, timeAug: [--------------------------------------->] 100 %
#
# Fitting scaler progress: [------------------->] 100 %
#
# Stage two loading training set, labels and standard scaler: [--------------------------------------->] 100 %
#
# Stage two loading validation set, labels and standard scaler: [--------------------------------------->] 100 %
#
# Completed loading to RAM [--------------------------------------> ] 99 %
# Model nr 1 of 100
# [   {'index': 0, 'model_nr_type': 'InceptionTime'},
#     {   'batch_size': 256,
#         'bottleneck_size': 48,
#         'epochs': 50,
#         'filter_size': 40,
#         'l1_r': 0.01,
#         'l2_r': 0.01,
#         'learning_rate': 0.01,
#         'module_activation': 'linear',
#         'module_output_activation': 'relu',
#         'num_filters': 38,
#         'num_modules': 3,
#         'optimizer': 'adam',
#         'output_layer_activation': 'sigmoid',
#         'reg_module': False,
#         'reg_residual': True,
#         'residual_activation': 'tanh',
#         'use_bottleneck': False,
#         'use_residuals': True}]
# Saving file. 1 rows.
# results_InceptionTime_noiseNotNoise_timeAug_noiseAug_earlyS_numChannels-2.csv saved to path:   /media/tord/T7/Thesis_ssd/MasterThesis3/GridSearchResults/2_classes
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 6000, 2)]    0
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 6000, 2)      0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 6000, 38)     3040        input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 6000, 38)     1520        input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 6000, 38)     760         input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 6000, 38)     76          max_pooling1d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 6000, 152)    0           conv1d[0][0]
#                                                                  conv1d_1[0][0]
#                                                                  conv1d_2[0][0]
#                                                                  conv1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 6000, 152)    608         concatenate[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 6000, 152)    0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 6000, 152)    0           activation[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 6000, 38)     231040      activation[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 6000, 38)     115520      activation[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 6000, 38)     57760       activation[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 6000, 38)     5776        max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 6000, 152)    0           conv1d_4[0][0]
#                                                                  conv1d_5[0][0]
#                                                                  conv1d_6[0][0]
#                                                                  conv1d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 6000, 152)    608         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 6000, 152)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 6000, 152)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 6000, 38)     231040      activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 6000, 38)     115520      activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 6000, 38)     57760       activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 6000, 38)     5776        max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 6000, 152)    0           conv1d_8[0][0]
#                                                                  conv1d_9[0][0]
#                                                                  conv1d_10[0][0]
#                                                                  conv1d_11[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 6000, 152)    304         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 6000, 152)    608         concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 6000, 152)    608         conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 6000, 152)    0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 6000, 152)    0           batch_normalization_3[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 6000, 152)    0           add[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 152)          0           activation_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            153         global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 828,477
# Trainable params: 827,261
# Non-trainable params: 1,216
# __________________________________________________________________________________________________
# Starting:
# {   'batch_size': 256,
#     'bottleneck_size': 48,
#     'epochs': 50,
#     'filter_size': 40,
#     'l1_r': 0.01,
#     'l2_r': 0.01,
#     'learning_rate': 0.01,
#     'module_activation': 'linear',
#     'module_output_activation': 'relu',
#     'num_filters': 38,
#     'num_modules': 3,
#     'optimizer': 'adam',
#     'output_layer_activation': 'sigmoid',
#     'reg_module': False,
#     'reg_residual': True,
#     'residual_activation': 'tanh',
#     'train_accuracy': nan,
#     'train_loss': nan,
#     'train_precision': nan,
#     'train_recall': nan,
#     'use_bottleneck': False,
#     'use_residuals': True,
#     'val_accuracy': nan,
#     'val_loss': nan,
#     'val_precision': nan,
#     'val_recall': nan}
# ---------------------------------------------------------------------------------
# 'HelperFunctions' object has no attribute 'steps_per_epoch'
# Something went wrong while training the model (most likely)
# Model nr 2 of 100
# [   {'index': 1, 'model_nr_type': 'InceptionTime'},
#     {   'batch_size': 64,
#         'bottleneck_size': 38,
#         'epochs': 50,
#         'filter_size': 34,
#         'l1_r': 0,
#         'l2_r': 0.001,
#         'learning_rate': 0.01,
#         'module_activation': 'linear',
#         'module_output_activation': 'tanh',
#         'num_filters': 26,
#         'num_modules': 3,
#         'optimizer': 'adam',
#         'output_layer_activation': 'sigmoid',
#         'reg_module': True,
#         'reg_residual': False,
#         'residual_activation': 'tanh',
#         'use_bottleneck': True,
#         'use_residuals': False}]
# Saving file. 2 rows.
# results_InceptionTime_noiseNotNoise_timeAug_noiseAug_earlyS_numChannels-2.csv saved to path:   /media/tord/T7/Thesis_ssd/MasterThesis3/GridSearchResults/2_classes
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 6000, 2)]    0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 6000, 38)     76          input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 6000, 2)      0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 6000, 26)     33592       conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 6000, 26)     16796       conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 6000, 26)     7904        conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 6000, 26)     52          max_pooling1d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 6000, 104)    0           conv1d_1[0][0]
#                                                                  conv1d_2[0][0]
#                                                                  conv1d_3[0][0]
#                                                                  conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 6000, 104)    416         concatenate[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 6000, 104)    0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 6000, 38)     3952        activation[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 6000, 104)    0           activation[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 6000, 26)     33592       conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 6000, 26)     16796       conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 6000, 26)     7904        conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 6000, 26)     2704        max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 6000, 104)    0           conv1d_6[0][0]
#                                                                  conv1d_7[0][0]
#                                                                  conv1d_8[0][0]
#                                                                  conv1d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 6000, 104)    416         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 6000, 104)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 6000, 38)     3952        activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 6000, 104)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 6000, 26)     33592       conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 6000, 26)     16796       conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 6000, 26)     7904        conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 6000, 26)     2704        max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 6000, 104)    0           conv1d_11[0][0]
#                                                                  conv1d_12[0][0]
#                                                                  conv1d_13[0][0]
#                                                                  conv1d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 6000, 104)    416         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 6000, 104)    0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 104)          0           activation_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            105         global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 189,669
# Trainable params: 189,045
# Non-trainable params: 624
# __________________________________________________________________________________________________
# Starting:
# {   'batch_size': 64,
#     'bottleneck_size': 38,
#     'epochs': 50,
#     'filter_size': 34,
#     'l1_r': 0,
#     'l2_r': 0.001,
#     'learning_rate': 0.01,
#     'module_activation': 'linear',
#     'module_output_activation': 'tanh',
#     'num_filters': 26,
#     'num_modules': 3,
#     'optimizer': 'adam',
#     'output_layer_activation': 'sigmoid',
#     'reg_module': True,
#     'reg_residual': False,
#     'residual_activation': 'tanh',
#     'train_accuracy': nan,
#     'train_loss': nan,
#     'train_precision': nan,
#     'train_recall': nan,
#     'use_bottleneck': True,
#     'use_residuals': False,
#     'val_accuracy': nan,
#     'val_loss': nan,
#     'val_precision': nan,
#     'val_recall': nan}
# ---------------------------------------------------------------------------------
# 'HelperFunctions' object has no attribute 'steps_per_epoch'
# Something went wrong while training the model (most likely)
# Model nr 3 of 100
# [   {'index': 2, 'model_nr_type': 'InceptionTime'},
#     {   'batch_size': 256,
#         'bottleneck_size': 30,
#         'epochs': 50,
#         'filter_size': 30,
#         'l1_r': 0.01,
#         'l2_r': 0,
#         'learning_rate': 0.0001,
#         'module_activation': 'linear',
#         'module_output_activation': 'relu',
#         'num_filters': 26,
#         'num_modules': 1,
#         'optimizer': 'rmsprop',
#         'output_layer_activation': 'sigmoid',
#         'reg_module': False,
#         'reg_residual': False,
#         'residual_activation': 'relu',
#         'use_bottleneck': True,
#         'use_residuals': True}]
# Saving file. 3 rows.
# results_InceptionTime_noiseNotNoise_timeAug_noiseAug_earlyS_numChannels-2.csv saved to path:   /media/tord/T7/Thesis_ssd/MasterThesis3/GridSearchResults/2_classes
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 6000, 2)]    0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 6000, 30)     60          input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 6000, 2)      0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 6000, 26)     23400       conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 6000, 26)     11700       conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 6000, 26)     5460        conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 6000, 26)     52          max_pooling1d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 6000, 104)    0           conv1d_1[0][0]
#                                                                  conv1d_2[0][0]
#                                                                  conv1d_3[0][0]
#                                                                  conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 6000, 104)    416         concatenate[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 6000, 104)    0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 104)          0           activation[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            105         global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 41,193
# Trainable params: 40,985
# Non-trainable params: 208
# __________________________________________________________________________________________________
# Starting:
# {   'batch_size': 256,
#     'bottleneck_size': 30,
#     'epochs': 50,
#     'filter_size': 30,
#     'l1_r': 0.01,
#     'l2_r': 0,
#     'learning_rate': 0.0001,
#     'module_activation': 'linear',
#     'module_output_activation': 'relu',
#     'num_filters': 26,
#     'num_modules': 1,
#     'optimizer': 'rmsprop',
#     'output_layer_activation': 'sigmoid',
#     'reg_module': False,
#     'reg_residual': False,
#     'residual_activation': 'relu',
#     'train_accuracy': nan,
#     'train_loss': nan,
#     'train_precision': nan,
#     'train_recall': nan,
#     'use_bottleneck': True,
#     'use_residuals': True,
#     'val_accuracy': nan,
#     'val_loss': nan,
#     'val_precision': nan,
#     'val_recall': nan}
# ---------------------------------------------------------------------------------
# 'HelperFunctions' object has no attribute 'steps_per_epoch'
# Something went wrong while training the model (most likely)
# Model nr 4 of 100
# [   {'index': 3, 'model_nr_type': 'InceptionTime'},
#     {   'batch_size': 256,
#         'bottleneck_size': 40,
#         'epochs': 50,
#         'filter_size': 34,
#         'l1_r': 0.0001,
#         'l2_r': 0.1,
#         'learning_rate': 0.001,
#         'module_activation': 'tanh',
#         'module_output_activation': 'tanh',
#         'num_filters': 26,
#         'num_modules': 6,
#         'optimizer': 'adam',
#         'output_layer_activation': 'sigmoid',
#         'reg_module': False,
#         'reg_residual': True,
#         'residual_activation': 'tanh',
#         'use_bottleneck': False,
#         'use_residuals': True}]
# Saving file. 4 rows.
# results_InceptionTime_noiseNotNoise_timeAug_noiseAug_earlyS_numChannels-2.csv saved to path:   /media/tord/T7/Thesis_ssd/MasterThesis3/GridSearchResults/2_classes
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 6000, 2)]    0
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 6000, 2)      0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 6000, 26)     1768        input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 6000, 26)     884         input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 6000, 26)     416         input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 6000, 26)     52          max_pooling1d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 6000, 104)    0           conv1d[0][0]
#                                                                  conv1d_1[0][0]
#                                                                  conv1d_2[0][0]
#                                                                  conv1d_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 6000, 104)    416         concatenate[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 6000, 104)    0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 6000, 104)    0           activation[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 6000, 26)     91936       activation[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 6000, 26)     45968       activation[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 6000, 26)     21632       activation[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 6000, 26)     2704        max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 6000, 104)    0           conv1d_4[0][0]
#                                                                  conv1d_5[0][0]
#                                                                  conv1d_6[0][0]
#                                                                  conv1d_7[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 6000, 104)    416         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 6000, 104)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 6000, 104)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 6000, 26)     91936       activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 6000, 26)     45968       activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 6000, 26)     21632       activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 6000, 26)     2704        max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 6000, 104)    0           conv1d_8[0][0]
#                                                                  conv1d_9[0][0]
#                                                                  conv1d_10[0][0]
#                                                                  conv1d_11[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 6000, 104)    208         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 6000, 104)    416         concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 6000, 104)    416         conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 6000, 104)    0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 6000, 104)    0           batch_normalization_3[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 6000, 104)    0           add[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_3 (MaxPooling1D)  (None, 6000, 104)    0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 6000, 26)     91936       activation_3[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 6000, 26)     45968       activation_3[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 6000, 26)     21632       activation_3[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 6000, 26)     2704        max_pooling1d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 6000, 104)    0           conv1d_13[0][0]
#                                                                  conv1d_14[0][0]
#                                                                  conv1d_15[0][0]
#                                                                  conv1d_16[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 6000, 104)    416         concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 6000, 104)    0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_4 (MaxPooling1D)  (None, 6000, 104)    0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 6000, 26)     91936       activation_4[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 6000, 26)     45968       activation_4[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 6000, 26)     21632       activation_4[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 6000, 26)     2704        max_pooling1d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 6000, 104)    0           conv1d_17[0][0]
#                                                                  conv1d_18[0][0]
#                                                                  conv1d_19[0][0]
#                                                                  conv1d_20[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 6000, 104)    416         concatenate_4[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 6000, 104)    0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_5 (MaxPooling1D)  (None, 6000, 104)    0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 6000, 26)     91936       activation_5[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 6000, 26)     45968       activation_5[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 6000, 26)     21632       activation_5[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 6000, 26)     2704        max_pooling1d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 6000, 104)    0           conv1d_21[0][0]
#                                                                  conv1d_22[0][0]
#                                                                  conv1d_23[0][0]
#                                                                  conv1d_24[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 6000, 104)    10816       activation_3[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 6000, 104)    416         concatenate_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 6000, 104)    416         conv1d_25[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 6000, 104)    0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 6000, 104)    0           batch_normalization_7[0][0]
#                                                                  activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 6000, 104)    0           add_1[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 104)          0           activation_7[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            105         global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 828,777
# Trainable params: 827,113
# Non-trainable params: 1,664
# __________________________________________________________________________________________________
# Starting:
# {   'batch_size': 256,
#     'bottleneck_size': 40,
#     'epochs': 50,
#     'filter_size': 34,
#     'l1_r': 0.0001,
#     'l2_r': 0.1,
#     'learning_rate': 0.001,
#     'module_activation': 'tanh',
#     'module_output_activation': 'tanh',
#     'num_filters': 26,
#     'num_modules': 6,
#     'optimizer': 'adam',
#     'output_layer_activation': 'sigmoid',
#     'reg_module': False,
#     'reg_residual': True,
#     'residual_activation': 'tanh',
#     'train_accuracy': nan,
#     'train_loss': nan,
#     'train_precision': nan,
#     'train_recall': nan,
#     'use_bottleneck': False,
#     'use_residuals': True,
#     'val_accuracy': nan,
#     'val_loss': nan,
#     'val_precision': nan,
#     'val_recall': nan}
# ---------------------------------------------------------------------------------
# 'HelperFunctions' object has no attribute 'steps_per_epoch'
# Something went wrong while training the model (most likely)
# Model nr 5 of 100
# [   {'index': 4, 'model_nr_type': 'InceptionTime'},
#     {   'batch_size': 128,
#         'bottleneck_size': 44,
#         'epochs': 50,
#         'filter_size': 36,
#         'l1_r': 0.0001,
#         'l2_r': 0.01,
#         'learning_rate': 0.001,
#         'module_activation': 'linear',
#         'module_output_activation': 'linear',
#         'num_filters': 30,
#         'num_modules': 3,
#         'optimizer': 'adam',
#         'output_layer_activation': 'sigmoid',
#         'reg_module': True,
#         'reg_residual': True,
#         'residual_activation': 'tanh',
#         'use_bottleneck': True,
#         'use_residuals': False}]
# Saving file. 5 rows.
# results_InceptionTime_noiseNotNoise_timeAug_noiseAug_earlyS_numChannels-2.csv saved to path:   /media/tord/T7/Thesis_ssd/MasterThesis3/GridSearchResults/2_classes
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 6000, 2)]    0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 6000, 44)     88          input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 6000, 2)      0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 6000, 30)     47520       conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 6000, 30)     23760       conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 6000, 30)     11880       conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 6000, 30)     60          max_pooling1d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 6000, 120)    0           conv1d_1[0][0]
#                                                                  conv1d_2[0][0]
#                                                                  conv1d_3[0][0]
#                                                                  conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 6000, 120)    480         concatenate[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 6000, 120)    0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 6000, 44)     5280        activation[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 6000, 120)    0           activation[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 6000, 30)     47520       conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 6000, 30)     23760       conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 6000, 30)     11880       conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 6000, 30)     3600        max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 6000, 120)    0           conv1d_6[0][0]
#                                                                  conv1d_7[0][0]
#                                                                  conv1d_8[0][0]
#                                                                  conv1d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 6000, 120)    480         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 6000, 120)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 6000, 44)     5280        activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 6000, 120)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 6000, 30)     47520       conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 6000, 30)     23760       conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 6000, 30)     11880       conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 6000, 30)     3600        max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 6000, 120)    0           conv1d_11[0][0]
#                                                                  conv1d_12[0][0]
#                                                                  conv1d_13[0][0]
#                                                                  conv1d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 6000, 120)    480         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 6000, 120)    0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 120)          0           activation_2[0][0]
# ...
# conv1d_6 (Conv1D)               (None, 6000, 26)     50336       conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 6000, 26)     25168       conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 6000, 26)     12584       conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 6000, 26)     2704        max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 6000, 104)    0           conv1d_6[0][0]
#                                                                  conv1d_7[0][0]
#                                                                  conv1d_8[0][0]
#                                                                  conv1d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 6000, 104)    416         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 6000, 104)    0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 6000, 44)     4576        activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 6000, 104)    0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 6000, 26)     50336       conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 6000, 26)     25168       conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 6000, 26)     12584       conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 6000, 26)     2704        max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 6000, 104)    0           conv1d_11[0][0]
#                                                                  conv1d_12[0][0]
#                                                                  conv1d_13[0][0]
#                                                                  conv1d_14[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 6000, 104)    208         input_1[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 6000, 104)    416         concatenate_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 6000, 104)    416         conv1d_15[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 6000, 104)    0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 6000, 104)    0           batch_normalization_3[0][0]
#                                                                  activation_2[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 6000, 104)    0           add[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 104)          0           activation_3[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            105         global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 280,941
# Trainable params: 280,109
# Non-trainable params: 832
# __________________________________________________________________________________________________
# Starting:
# {   'batch_size': 128,
#     'bottleneck_size': 44,
#     'epochs': 50,
#     'filter_size': 44,
#     'l1_r': 0.001,
#     'l2_r': 0.01,
#     'learning_rate': 0.001,
#     'module_activation': 'tanh',
#     'module_output_activation': 'relu',
#     'num_filters': 26,
#     'num_modules': 3,
#     'optimizer': 'sgd',
#     'output_layer_activation': 'sigmoid',
#     'reg_module': False,
#     'reg_residual': False,
#     'residual_activation': 'tanh',
#     'train_accuracy': nan,
#     'train_loss': nan,
#     'train_precision': nan,
#     'train_recall': nan,
#     'use_bottleneck': True,
#     'use_residuals': True,
#     'val_accuracy': nan,
#     'val_loss': nan,
#     'val_precision': nan,
#     'val_recall': nan}
# ---------------------------------------------------------------------------------
# 'HelperFunctions' object has no attribute 'steps_per_epoch'
# Something went wrong while training the model (most likely)
# Model nr 72 of 100
# [   {'index': 71, 'model_nr_type': 'InceptionTime'},
#     {   'batch_size': 256,
#         'bottleneck_size': 44,
#         'epochs': 50,
#         'filter_size': 44,
#         'l1_r': 0.001,
#         'l2_r': 0.1,
#         'learning_rate': 0.01,
#         'module_activation': 'linear',
#         'module_output_activation': 'relu',
#         'num_filters': 22,
#         'num_modules': 3,
#         'optimizer': 'adam',
#         'output_layer_activation': 'sigmoid',
#         'reg_module': False,
#         'reg_residual': True,
#         'residual_activation': 'relu',
#         'use_bottleneck': True,
#         'use_residuals': False}]
# Saving file. 72 rows.
# results_InceptionTime_noiseNotNoise_timeAug_noiseAug_earlyS_numChannels-2.csv saved to path:   /media/tord/T7/Thesis_ssd/MasterThesis3/GridSearchResults/2_classes
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 6000, 2)]    0
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 6000, 44)     88          input_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d (MaxPooling1D)    (None, 6000, 2)      0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 6000, 22)     42592       conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 6000, 22)     21296       conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 6000, 22)     10648       conv1d[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 6000, 22)     44          max_pooling1d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 6000, 88)     0           conv1d_1[0][0]
#                                                                  conv1d_2[0][0]
#                                                                  conv1d_3[0][0]
#                                                                  conv1d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 6000, 88)     352         concatenate[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 6000, 88)     0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 6000, 44)     3872        activation[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_1 (MaxPooling1D)  (None, 6000, 88)     0           activation[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 6000, 22)     42592       conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 6000, 22)     21296       conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 6000, 22)     10648       conv1d_5[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 6000, 22)     1936        max_pooling1d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 6000, 88)     0           conv1d_6[0][0]
#                                                                  conv1d_7[0][0]
#                                                                  conv1d_8[0][0]
#                                                                  conv1d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 6000, 88)     352         concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 6000, 88)     0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 6000, 44)     3872        activation_1[0][0]
# __________________________________________________________________________________________________
# max_pooling1d_2 (MaxPooling1D)  (None, 6000, 88)     0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 6000, 22)     42592       conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 6000, 22)     21296       conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 6000, 22)     10648       conv1d_10[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 6000, 22)     1936        max_pooling1d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 6000, 88)     0           conv1d_11[0][0]
#                                                                  conv1d_12[0][0]
#                                                                  conv1d_13[0][0]
#                                                                  conv1d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 6000, 88)     352         concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 6000, 88)     0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 88)           0           activation_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1)            89          global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 236,501
# Trainable params: 235,973
# Non-trainable params: 528
# __________________________________________________________________________________________________
# Starting:
# {   'batch_size': 256,
#     'bottleneck_size': 44,
#     'epochs': 50,
#     'filter_size': 44,
#     'l1_r': 0.001,
#     'l2_r': 0.1,
#     'learning_rate': 0.01,
#     'module_activation': 'linear',
#     'module_output_activation': 'relu',
#     'num_filters': 22,
#     'num_modules': 3,
#     'optimizer': 'adam',
#     'output_layer_activation': 'sigmoid',
#     'reg_module': False,
#     'reg_residual': True,
#     'residual_activation': 'relu',
#     'train_accuracy': nan,
#     'train_loss': nan,
#     'train_precision': nan,
#     'train_recall': nan,
#     'use_bottleneck': True,
#     'use_residuals': False,
#     'val_accuracy': nan,
#     'val_loss': nan,
#     'val_precision': nan,
#     'val_recall': nan}
# ---------------------------------------------------------------------------------
# 'HelperFunctions' object has no attribute 'steps_per_epoch'
# Something went wrong while training the model (most likely)
# Model nr 73 of 100
# [   {'index': 72, 'model_nr_type': 'InceptionTime'},
#     {   'batch_size': 128,
#         'bottleneck_size': 38,
#         'epochs': 50,
#         'filter_size': 48,
#         'l1_r': 0.01,
#         'l2_r': 0.1,
#         'learning_rate': 0.0001,
#         'module_activation': 'linear',
#         'module_output_activation': 'relu',
#         'num_filters': 30,
#         'num_modules': 6,
#         'optimizer': 'sgd',
#         'output_layer_activation': 'sigmoid',
#         'reg_module': False,
#         'reg_residual': True,
#         'residual_activation': 'tanh',
#         'use_bottleneck': True,
#         'use_residuals': True}]
# Saving file. 73 rows.
# results_InceptionTime_noiseNotNoise_timeAug_noiseAug_earlyS_numChannels-2.csv saved to path:   /media/tord/T7/Thesis_ssd/MasterThesis3/GridSearchResults/2_classes

# %%
input_layer = tf.keras.layers.Input((1))
x = input_layer
x = tf.keras.layers.Dense(1)(x)
output = tf.keras.layers.Dense(1)(x)
model = tf.keras.Model(inputs = input_layer, outputs = output)

# %%
model.compile()

# %%
model.fit(x = [[1],[0]], y = [1,0])
