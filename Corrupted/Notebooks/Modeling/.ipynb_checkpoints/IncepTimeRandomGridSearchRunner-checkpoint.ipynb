# %%
import numpy as np
import os
import sys
import pandas as pd

import sklearn as sk
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report, confusion_matrix
import seaborn as sns

import pylab as pl
import h5py

import tensorflow as tf

os.environ['TF_CPP_MIN_LOG_LEVEL']='2'
os.environ['CUDA_VISIBLE_DEVICES']="0" 

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
  try:
    # Currently, memory growth needs to be the same across GPUs
    for gpu in gpus:
      tf.config.experimental.set_memory_growth(gpu, True)
    logical_gpus = tf.config.experimental.list_logical_devices('GPU')
    print(len(gpus), "Physical GPUs,", len(logical_gpus), "Logical GPUs")
  except RuntimeError as e:
    # Memory growth must be set before GPUs have been initialized
    print(e)


from sklearn.metrics import confusion_matrix


base_dir = '/media/tord/T7/Thesis_ssd/MasterThesis3.0'
os.chdir(base_dir)
from Classes.DataProcessing.LoadData import LoadData
from Classes.DataProcessing.HelperFunctions import HelperFunctions
from Classes.DataProcessing.DataHandler import DataHandler
from Classes.DataProcessing.TimeAugmentor import TimeAugmentor
from Classes.DataProcessing.NoiseAugmentor import NoiseAugmentor
from Classes.DataProcessing.RamLoader import RamLoader
from Classes.DataProcessing.RamGenerator import RamGenerator
from Classes.Modeling.InceptionTimeModel import InceptionTimeModel
from Classes.Modeling.InceptionTimeRGS import InceptionTimeRGS
from Classes.Modeling.CustomCallback import CustomCallback
from Classes.Modeling.ResultFitter import ResultFitter
from Classes.Scaling.ScalerFitter import ScalerFitter
from Classes.Scaling.MinMaxScalerFitter import MinMaxScalerFitter
from Classes.Scaling.StandardScalerFitter import StandardScalerFitter
import json
#from Classes import Tf_shutup
#Tf_shutup.Tf_shutup()


plt.rcParams["figure.figsize"]= (15,15)
helper = HelperFunctions()

import sys
ISCOLAB = 'google.colab' in sys.modules

import random
import pprint


# %load_ext tensorboard
# Out:
# 1 Physical GPUs, 1 Logical GPUs

# %%
load_args = {
    'earth_explo_only' : False,
    'noise_earth_only' : False,
    'noise_not_noise' : True,
    'downsample' : True,
    'upsample' : True,
    'frac_diff' : 0.3,
    'seed' : 1,
    'subsample_size' : 0.5,
    'balance_non_train_set' : True,
    'use_true_test_set' : False
}
loadData = LoadData(**load_args)
full_ds, train_ds, val_ds, test_ds = loadData.get_datasets()
noise_ds = loadData.noise_ds
handler = DataHandler(loadData)

if load_args['earth_explo_only']:
    full_and_noise_ds = np.concatenate((full_ds, noise_ds))
    timeAug = TimeAugmentor(handler, full_and_noise_ds, seed = load_args['seed'])
else:
    timeAug = TimeAugmentor(handler, full_ds, seed = load_args['seed'])
# Out:
# Mapping redundancy: [--------------------------------------->] 100 %

# %%
print(len(train_ds), len(val_ds), len(test_ds))
classes, counts = handler.get_class_distribution_from_ds(full_ds)
classes, counts = handler.get_class_distribution_from_ds(train_ds)
classes, counts = handler.get_class_distribution_from_ds(val_ds)
print("Nr noise samples " + str(len(loadData.noise_ds)))
# Out:
# 42318 8463 5643
# Total: 56424, earthquake: 18888, explosion: 18479, noise: 19057
# Total: 42318, earthquake: 14236, explosion: 13826, noise: 14256
# Total: 8463, earthquake: 2790, explosion: 2794, noise: 2879
# Nr noise samples 14256

# %%
hyper_grid = {    
    "batch_size" : [128, 256, 512, 1024],
    "epochs" : [200, 250, 300, 350],
    "learning_rate" : [0.1, 0.01, 0.001, 0.0001, 0.00001],
    "optimizer" : ["adam", "rmsprop", "sgd"]
    }
model_grid = {
    "use_residuals" : [True, False],
    "use_bottleneck" : [True, False],
    "nr_modules" : [1, 3, 6, 9, 12],
    "kernel_size" : [20, 30, 40, 50],
    "bottleneck_size" : [24, 26, 28, 30, 32, 34, 36, 38, 40],
    "num_filters" : [24, 26, 28, 30, 32, 34, 36, 38, 40],
    "shortcut_activation" : ["relu", "sigmoid", "softmax", "tanh"],
    "module_activation" : ["linear", "relu", "sigmoid", "softmax", "tanh"],
    "module_output_activation" : ["relu", "linear", "sigmoid", "softmax", "tanh"],
    "output_activation": ["sigmoid"]
}

num_channels = 3

use_time_augmentor = True
use_scaler = True
use_noise_augmentor = True
detrend = False
use_minmax = False
use_highpass = False
highpass_freq = 0.1

n_picks = 200

use_tensorboard = True
use_liveplots = False
use_custom_callback = False
use_early_stopping = True
start_from_scratch = False
use_reduced_lr = True

randomGridSearch = InceptionTimeRGS(loadData, train_ds, val_ds, detrend, use_scaler, use_time_augmentor, 
                                    use_noise_augmentor, use_minmax, use_highpass, n_picks, hyper_grid = hyper_grid, 
                                    model_grid = model_grid, use_tensorboard = use_tensorboard,
                                    use_liveplots = use_liveplots, use_custom_callback = use_custom_callback,
                                    use_early_stopping = use_early_stopping, highpass_freq = highpass_freq,
                                    start_from_scratch = start_from_scratch, use_reduced_lr = use_reduced_lr, 
                                    num_channels = num_channels)
# Out:
# Note that highpass and detrend have not been implemented yet in this class.

# %%
def clear_tensorboard_dir():
    import os
    import shutil
    path = f"{base_dir}/Tensorboard_dir/fit"
    files = os.listdir(path)
    print(files)
    for f in files:
        shutil.rmtree(os.path.join(path,f))
if use_tensorboard:
    clear_tensorboard_dir()
    # %tensorboard --logdir tensorboard_dir/fit
# Out:
# []
# Reusing TensorBoard on port 6006 (pid 5809), started 2:09:36 ago. (Use '!kill 5809' to kill it.)
#       <iframe id="tensorboard-frame-f3de0acf3e9d8097" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-f3de0acf3e9d8097");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>

# %%
results_df, min_loss, max_accuracy, max_precision, max_recall = randomGridSearch.fit()
# Out:
# Fit process completed after 284.39272260665894 seconds. Total datapoints fitted: 56424.
# Average time per datapoint: 0.005040279359964889
# Starting loading to RAM [------------------> ] 99 %%
# Completed loading to RAM
# Starting loading to RAM
# Completed loading to RAM
# Model nr 1 of 200
# 1
# [{'model_nr_type': 'InceptionTime', 'index': 0}, {'batch_size': 128, 'epochs': 300, 'learning_rate': 0.01, 'num_channels': 3, 'optimizer': 'sgd'}, {'bottleneck_size': 40, 'kernel_size': 20, 'module_activation': 'sigmoid', 'module_output_activation': 'tanh', 'nr_modules': 9, 'num_filters': 32, 'output_activation': 'sigmoid', 'shortcut_activation': 'tanh', 'use_bottleneck': False, 'use_residuals': False}]
# Starting:
# {   'batch_size': 128,
#     'epochs': 300,
#     'learning_rate': 0.01,
#     'num_channels': 3,
#     'optimizer': 'sgd'}
# ---------------------------------------------------------------------------------
# {   'bottleneck_size': 40,
#     'kernel_size': 20,
#     'module_activation': 'sigmoid',
#     'module_output_activation': 'tanh',
#     'nr_modules': 9,
#     'num_filters': 32,
#     'output_activation': 'sigmoid',
#     'shortcut_activation': 'tanh',
#     'use_bottleneck': False,
#     'use_residuals': False}
# Epoch 1/300
# 330/330 [==============================] - 24s 61ms/step - loss: 0.5727 - precision: 0.8290 - binary_accuracy: 0.6838 - recall: 0.6588 - val_loss: 0.6305 - val_precision: 0.6594 - val_binary_accuracy: 0.6594 - val_recall: 1.0000
# Epoch 2/300
# 330/330 [==============================] - 19s 59ms/step - loss: 0.2914 - precision: 0.9482 - binary_accuracy: 0.8824 - recall: 0.8703 - val_loss: 0.4617 - val_precision: 0.9479 - val_binary_accuracy: 0.8091 - val_recall: 0.7518
# Epoch 3/300
# 330/330 [==============================] - 19s 59ms/step - loss: 0.1305 - precision: 0.9797 - binary_accuracy: 0.9584 - recall: 0.9571 - val_loss: 0.5450 - val_precision: 0.9284 - val_binary_accuracy: 0.8248 - val_recall: 0.7957
# Epoch 4/300
# 330/330 [==============================] - 20s 60ms/step - loss: 0.0421 - precision: 0.9950 - binary_accuracy: 0.9898 - recall: 0.9896 - val_loss: 0.6770 - val_precision: 0.9351 - val_binary_accuracy: 0.8248 - val_recall: 0.7891
# Epoch 5/300
# 330/330 [==============================] - 20s 59ms/step - loss: 0.0383 - precision: 0.9933 - binary_accuracy: 0.9886 - recall: 0.9895 - val_loss: 0.6978 - val_precision: 0.9225 - val_binary_accuracy: 0.8248 - val_recall: 0.8017
# Restoring model weights from the end of the best epoch.
# Epoch 00005: early stopping
# /home/tord/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py:1911: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   warnings.warn('`Model.evaluate_generator` is deprecated and '
# Model nr 2 of 200
# 2
# [{'model_nr_type': 'InceptionTime', 'index': 1}, {'batch_size': 1024, 'epochs': 200, 'learning_rate': 0.001, 'num_channels': 3, 'optimizer': 'rmsprop'}, {'bottleneck_size': 26, 'kernel_size': 30, 'module_activation': 'relu', 'module_output_activation': 'sigmoid', 'nr_modules': 12, 'num_filters': 30, 'output_activation': 'sigmoid', 'shortcut_activation': 'sigmoid', 'use_bottleneck': True, 'use_residuals': True}]
# Starting:
# {   'batch_size': 1024,
#     'epochs': 200,
#     'learning_rate': 0.001,
#     'num_channels': 3,
#     'optimizer': 'rmsprop'}
# ---------------------------------------------------------------------------------
# {   'bottleneck_size': 26,
#     'kernel_size': 30,
#     'module_activation': 'relu',
#     'module_output_activation': 'sigmoid',
#     'nr_modules': 12,
#     'num_filters': 30,
#     'output_activation': 'sigmoid',
#     'shortcut_activation': 'sigmoid',
#     'use_bottleneck': True,
#     'use_residuals': True}
# Epoch 1/200
# 41/41 [==============================] - 25s 500ms/step - loss: 0.5597 - precision_1: 0.8614 - binary_accuracy: 0.6696 - recall_1: 0.6052 - val_loss: 0.6414 - val_precision_1: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_1: 1.0000
# Epoch 2/200
# 41/41 [==============================] - 19s 479ms/step - loss: 0.3346 - precision_1: 0.8953 - binary_accuracy: 0.8493 - recall_1: 0.8754 - val_loss: 0.6758 - val_precision_1: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_1: 1.0000
# Epoch 3/200
# 41/41 [==============================] - 19s 479ms/step - loss: 0.2699 - precision_1: 0.9230 - binary_accuracy: 0.8838 - recall_1: 0.9003 - val_loss: 0.8298 - val_precision_1: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_1: 1.0000
# Epoch 4/200
# 41/41 [==============================] - 19s 483ms/step - loss: 0.2154 - precision_1: 0.9400 - binary_accuracy: 0.9125 - recall_1: 0.9264 - val_loss: 1.0711 - val_precision_1: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_1: 1.0000
# Restoring model weights from the end of the best epoch.
# Epoch 00004: early stopping
# Model nr 3 of 200
# 3
# [{'model_nr_type': 'InceptionTime', 'index': 2}, {'batch_size': 256, 'epochs': 250, 'learning_rate': 1e-05, 'num_channels': 3, 'optimizer': 'adam'}, {'bottleneck_size': 40, 'kernel_size': 50, 'module_activation': 'tanh', 'module_output_activation': 'sigmoid', 'nr_modules': 3, 'num_filters': 28, 'output_activation': 'sigmoid', 'shortcut_activation': 'tanh', 'use_bottleneck': True, 'use_residuals': True}]
# Starting:
# {   'batch_size': 256,
#     'epochs': 250,
#     'learning_rate': 1e-05,
#     'num_channels': 3,
#     'optimizer': 'adam'}
# ---------------------------------------------------------------------------------
# {   'bottleneck_size': 40,
#     'kernel_size': 50,
#     'module_activation': 'tanh',
#     'module_output_activation': 'sigmoid',
#     'nr_modules': 3,
#     'num_filters': 28,
#     'output_activation': 'sigmoid',
#     'shortcut_activation': 'tanh',
#     'use_bottleneck': True,
#     'use_residuals': True}
# Epoch 1/250
# 165/165 [==============================] - 21s 119ms/step - loss: 0.6972 - precision_2: 0.7834 - binary_accuracy: 0.4992 - recall_2: 0.3379 - val_loss: 0.6818 - val_precision_2: 0.6481 - val_binary_accuracy: 0.6193 - val_recall_2: 0.9250
# Epoch 2/250
# 165/165 [==============================] - 19s 117ms/step - loss: 0.6311 - precision_2: 0.8916 - binary_accuracy: 0.6394 - recall_2: 0.5193 - val_loss: 0.6371 - val_precision_2: 0.6576 - val_binary_accuracy: 0.6490 - val_recall_2: 0.9758
# Epoch 3/250
# 165/165 [==============================] - 19s 115ms/step - loss: 0.5752 - precision_2: 0.9470 - binary_accuracy: 0.7143 - recall_2: 0.6047 - val_loss: 0.5588 - val_precision_2: 0.7323 - val_binary_accuracy: 0.7208 - val_recall_2: 0.9086
# Epoch 4/250
# 165/165 [==============================] - 19s 115ms/step - loss: 0.5356 - precision_2: 0.9497 - binary_accuracy: 0.7541 - recall_2: 0.6648 - val_loss: 0.5022 - val_precision_2: 0.7762 - val_binary_accuracy: 0.7540 - val_recall_2: 0.8810
# Epoch 5/250
# 165/165 [==============================] - 19s 116ms/step - loss: 0.5063 - precision_2: 0.9414 - binary_accuracy: 0.7751 - recall_2: 0.7049 - val_loss: 0.4766 - val_precision_2: 0.7882 - val_binary_accuracy: 0.7647 - val_recall_2: 0.8796
# Epoch 6/250
# Epoch 18/250
# 165/165 [==============================] - 19s 117ms/step - loss: 0.3349 - precision_2: 0.9124 - binary_accuracy: 0.8760 - recall_2: 0.8998 - val_loss: 0.3873 - val_precision_2: 0.8949 - val_binary_accuracy: 0.8333 - val_recall_2: 0.8467
# Epoch 19/250
# 165/165 [==============================] - 19s 116ms/step - loss: 0.3237 - precision_2: 0.9171 - binary_accuracy: 0.8832 - recall_2: 0.9062 - val_loss: 0.3809 - val_precision_2: 0.8953 - val_binary_accuracy: 0.8365 - val_recall_2: 0.8517
# Epoch 20/250
# 165/165 [==============================] - 19s 117ms/step - loss: 0.3119 - precision_2: 0.9227 - binary_accuracy: 0.8919 - recall_2: 0.9140 - val_loss: 0.3746 - val_precision_2: 0.8934 - val_binary_accuracy: 0.8410 - val_recall_2: 0.8618
# Epoch 21/250
# 165/165 [==============================] - 19s 117ms/step - loss: 0.3015 - precision_2: 0.9275 - binary_accuracy: 0.8995 - recall_2: 0.9209 - val_loss: 0.3683 - val_precision_2: 0.8938 - val_binary_accuracy: 0.8460 - val_recall_2: 0.8699
# Epoch 22/250
# 165/165 [==============================] - 19s 116ms/step - loss: 0.2910 - precision_2: 0.9315 - binary_accuracy: 0.9057 - recall_2: 0.9265 - val_loss: 0.3625 - val_precision_2: 0.8912 - val_binary_accuracy: 0.8488 - val_recall_2: 0.8779
# Epoch 23/250
# 165/165 [==============================] - 19s 116ms/step - loss: 0.2827 - precision_2: 0.9347 - binary_accuracy: 0.9118 - recall_2: 0.9322 - val_loss: 0.3573 - val_precision_2: 0.8898 - val_binary_accuracy: 0.8524 - val_recall_2: 0.8858
# Epoch 24/250
# 165/165 [==============================] - 19s 116ms/step - loss: 0.2726 - precision_2: 0.9403 - binary_accuracy: 0.9181 - recall_2: 0.9363 - val_loss: 0.3527 - val_precision_2: 0.8878 - val_binary_accuracy: 0.8533 - val_recall_2: 0.8901
# Epoch 25/250
# 165/165 [==============================] - 19s 116ms/step - loss: 0.2634 - precision_2: 0.9432 - binary_accuracy: 0.9235 - recall_2: 0.9415 - val_loss: 0.3487 - val_precision_2: 0.8868 - val_binary_accuracy: 0.8551 - val_recall_2: 0.8945
# Epoch 26/250
# 165/165 [==============================] - 19s 116ms/step - loss: 0.2531 - precision_2: 0.9483 - binary_accuracy: 0.9298 - recall_2: 0.9459 - val_loss: 0.3452 - val_precision_2: 0.8850 - val_binary_accuracy: 0.8551 - val_recall_2: 0.8968
# Epoch 27/250
# 165/165 [==============================] - 19s 116ms/step - loss: 0.2436 - precision_2: 0.9544 - binary_accuracy: 0.9358 - recall_2: 0.9489 - val_loss: 0.3421 - val_precision_2: 0.8841 - val_binary_accuracy: 0.8550 - val_recall_2: 0.8979
# Epoch 28/250
# 165/165 [==============================] - 19s 116ms/step - loss: 0.2354 - precision_2: 0.9570 - binary_accuracy: 0.9393 - recall_2: 0.9515 - val_loss: 0.3395 - val_precision_2: 0.8841 - val_binary_accuracy: 0.8559 - val_recall_2: 0.8995
# Epoch 40/250
# 165/165 [==============================] - 19s 116ms/step - loss: 0.1558 - precision_2: 0.9824 - binary_accuracy: 0.9737 - recall_2: 0.9780 - val_loss: 0.3260 - val_precision_2: 0.8954 - val_binary_accuracy: 0.8661 - val_recall_2: 0.9024
# Epoch 41/250
# 165/165 [==============================] - 19s 116ms/step - loss: 0.1502 - precision_2: 0.9838 - binary_accuracy: 0.9756 - recall_2: 0.9795 - val_loss: 0.3258 - val_precision_2: 0.8961 - val_binary_accuracy: 0.8666 - val_recall_2: 0.9024
# Epoch 42/250
# 165/165 [==============================] - 19s 116ms/step - loss: 0.1448 - precision_2: 0.9855 - binary_accuracy: 0.9775 - recall_2: 0.9806 - val_loss: 0.3259 - val_precision_2: 0.8955 - val_binary_accuracy: 0.8658 - val_recall_2: 0.9016
# Epoch 43/250
# 165/165 [==============================] - 19s 116ms/step - loss: 0.1397 - precision_2: 0.9865 - binary_accuracy: 0.9793 - recall_2: 0.9823 - val_loss: 0.3258 - val_precision_2: 0.8962 - val_binary_accuracy: 0.8658 - val_recall_2: 0.9007
# Epoch 44/250
# 165/165 [==============================] - 19s 116ms/step - loss: 0.1346 - precision_2: 0.9873 - binary_accuracy: 0.9814 - recall_2: 0.9846 - val_loss: 0.3260 - val_precision_2: 0.8963 - val_binary_accuracy: 0.8660 - val_recall_2: 0.9011
# Epoch 45/250
# 165/165 [==============================] - 19s 116ms/step - loss: 0.1299 - precision_2: 0.9887 - binary_accuracy: 0.9831 - recall_2: 0.9857 - val_loss: 0.3263 - val_precision_2: 0.8964 - val_binary_accuracy: 0.8660 - val_recall_2: 0.9009
# Epoch 46/250
# 165/165 [==============================] - 19s 116ms/step - loss: 0.1253 - precision_2: 0.9901 - binary_accuracy: 0.9847 - recall_2: 0.9868 - val_loss: 0.3267 - val_precision_2: 0.8974 - val_binary_accuracy: 0.8667 - val_recall_2: 0.9009
# Restoring model weights from the end of the best epoch.
# Epoch 00046: early stopping
# Model nr 4 of 200
# 4
# [{'model_nr_type': 'InceptionTime', 'index': 3}, {'batch_size': 128, 'epochs': 250, 'learning_rate': 0.1, 'num_channels': 3, 'optimizer': 'adam'}, {'bottleneck_size': 24, 'kernel_size': 40, 'module_activation': 'tanh', 'module_output_activation': 'tanh', 'nr_modules': 6, 'num_filters': 32, 'output_activation': 'sigmoid', 'shortcut_activation': 'tanh', 'use_bottleneck': True, 'use_residuals': True}]
# Starting:
# {   'batch_size': 128,
#     'epochs': 250,
#     'learning_rate': 0.1,
#     'num_channels': 3,
#     'optimizer': 'adam'}
# ---------------------------------------------------------------------------------
# {   'bottleneck_size': 24,
#     'kernel_size': 40,
#     'module_activation': 'tanh',
#     'module_output_activation': 'tanh',
#     'nr_modules': 6,
#     'num_filters': 32,
#     'output_activation': 'sigmoid',
#     'shortcut_activation': 'tanh',
#     'use_bottleneck': True,
#     'use_residuals': True}
# Epoch 1/250
# 330/330 [==============================] - 22s 61ms/step - loss: 0.6682 - precision_3: 0.6850 - binary_accuracy: 0.6358 - recall_3: 0.8356 - val_loss: 1.4491 - val_precision_3: 0.9820 - val_binary_accuracy: 0.3975 - val_recall_3: 0.0880
# Epoch 2/250
# 330/330 [==============================] - 19s 59ms/step - loss: 0.4771 - precision_3: 0.7930 - binary_accuracy: 0.7553 - recall_3: 0.8543 - val_loss: 0.8010 - val_precision_3: 0.9639 - val_binary_accuracy: 0.4502 - val_recall_3: 0.1727
# Epoch 3/250
# 330/330 [==============================] - 20s 59ms/step - loss: 0.4096 - precision_3: 0.8351 - binary_accuracy: 0.7982 - recall_3: 0.8677 - val_loss: 1.9943 - val_precision_3: 0.9748 - val_binary_accuracy: 0.3762 - val_recall_3: 0.0555
# Epoch 4/250
# 330/330 [==============================] - 20s 59ms/step - loss: 0.3751 - precision_3: 0.8602 - binary_accuracy: 0.8214 - recall_3: 0.8739 - val_loss: 0.5913 - val_precision_3: 0.6708 - val_binary_accuracy: 0.6682 - val_recall_3: 0.9758
# Epoch 5/250
# 330/330 [==============================] - 19s 59ms/step - loss: 0.3387 - precision_3: 0.8795 - binary_accuracy: 0.8435 - recall_3: 0.8862 - val_loss: 0.5688 - val_precision_3: 0.6744 - val_binary_accuracy: 0.6738 - val_recall_3: 0.9768
# Epoch 6/250
# 330/330 [==============================] - 20s 59ms/step - loss: 0.3250 - precision_3: 0.8881 - binary_accuracy: 0.8546 - recall_3: 0.8934 - val_loss: 1.1127 - val_precision_3: 0.6597 - val_binary_accuracy: 0.6596 - val_recall_3: 0.9993
# Epoch 7/250
# 330/330 [==============================] - 19s 59ms/step - loss: 0.3520 - precision_3: 0.8821 - binary_accuracy: 0.8523 - recall_3: 0.8974 - val_loss: 2.3270 - val_precision_3: 0.9812 - val_binary_accuracy: 0.3952 - val_recall_3: 0.0845
# Epoch 8/250
# 330/330 [==============================] - 19s 59ms/step - loss: 0.3890 - precision_3: 0.8783 - binary_accuracy: 0.8451 - recall_3: 0.8903 - val_loss: 1.6235 - val_precision_3: 0.9736 - val_binary_accuracy: 0.4298 - val_recall_3: 0.1391
# Restoring model weights from the end of the best epoch.
# Epoch 00008: early stopping
# Model nr 5 of 200
# 5
# [{'model_nr_type': 'InceptionTime', 'index': 4}, {'batch_size': 256, 'epochs': 300, 'learning_rate': 0.0001, 'num_channels': 3, 'optimizer': 'sgd'}, {'bottleneck_size': 32, 'kernel_size': 30, 'module_activation': 'linear', 'module_output_activation': 'softmax', 'nr_modules': 1, 'num_filters': 26, 'output_activation': 'sigmoid', 'shortcut_activation': 'sigmoid', 'use_bottleneck': True, 'use_residuals': True}]
# Starting:
# {   'batch_size': 256,
#     'epochs': 300,
#     'learning_rate': 0.0001,
#     'num_channels': 3,
#     'optimizer': 'sgd'}
# ---------------------------------------------------------------------------------
# {   'bottleneck_size': 32,
#     'kernel_size': 30,
#     'module_activation': 'linear',
#     'module_output_activation': 'softmax',
#     'nr_modules': 1,
#     'num_filters': 26,
#     'output_activation': 'sigmoid',
#     'shortcut_activation': 'sigmoid',
#     'use_bottleneck': True,
#     'use_residuals': True}
# Epoch 1/300
# Epoch 102/300
# 165/165 [==============================] - 19s 116ms/step - loss: 0.6631 - precision_4: 0.6648 - binary_accuracy: 0.6648 - recall_4: 1.0000 - val_loss: 0.6643 - val_precision_4: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_4: 1.0000
# Epoch 103/300
# 165/165 [==============================] - 19s 115ms/step - loss: 0.6629 - precision_4: 0.6646 - binary_accuracy: 0.6646 - recall_4: 1.0000 - val_loss: 0.6641 - val_precision_4: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_4: 1.0000
# Epoch 104/300
# 165/165 [==============================] - 19s 115ms/step - loss: 0.6625 - precision_4: 0.6659 - binary_accuracy: 0.6659 - recall_4: 1.0000 - val_loss: 0.6639 - val_precision_4: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_4: 1.0000
# Epoch 105/300
# 165/165 [==============================] - 19s 114ms/step - loss: 0.6623 - precision_4: 0.6659 - binary_accuracy: 0.6659 - recall_4: 1.0000 - val_loss: 0.6637 - val_precision_4: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_4: 1.0000
# Epoch 106/300
# 165/165 [==============================] - 19s 115ms/step - loss: 0.6625 - precision_4: 0.6641 - binary_accuracy: 0.6641 - recall_4: 1.0000 - val_loss: 0.6635 - val_precision_4: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_4: 1.0000
# Epoch 107/300
# ...
# Starting:
# {   'batch_size': 128,
#     'epochs': 350,
#     'learning_rate': 0.01,
#     'num_channels': 3,
#     'optimizer': 'rmsprop'}
# ---------------------------------------------------------------------------------
# {   'bottleneck_size': 24,
#     'kernel_size': 40,
#     'module_activation': 'linear',
#     'module_output_activation': 'relu',
#     'nr_modules': 6,
#     'num_filters': 40,
#     'output_activation': 'sigmoid',
#     'shortcut_activation': 'relu',
#     'use_bottleneck': False,
#     'use_residuals': False}
# Epoch 1/350
# 330/330 [==============================] - 22s 61ms/step - loss: 0.5190 - precision_14: 0.7989 - binary_accuracy: 0.7183 - recall_14: 0.7722 - val_loss: 2.6540 - val_precision_14: 0.6592 - val_binary_accuracy: 0.6571 - val_recall_14: 0.9935
# Epoch 2/350
# 330/330 [==============================] - 19s 59ms/step - loss: 0.3743 - precision_14: 0.8931 - binary_accuracy: 0.8256 - recall_14: 0.8371 - val_loss: 2.9650 - val_precision_14: 0.6589 - val_binary_accuracy: 0.6572 - val_recall_14: 0.9957
# Epoch 3/350
# 330/330 [==============================] - 20s 60ms/step - loss: 0.2806 - precision_14: 0.9243 - binary_accuracy: 0.8806 - recall_14: 0.8933 - val_loss: 3.0075 - val_precision_14: 0.6593 - val_binary_accuracy: 0.6586 - val_recall_14: 0.9980
# Epoch 4/350
# 330/330 [==============================] - 20s 59ms/step - loss: 0.2122 - precision_14: 0.9486 - binary_accuracy: 0.9177 - recall_14: 0.9266 - val_loss: 3.3667 - val_precision_14: 0.6594 - val_binary_accuracy: 0.6587 - val_recall_14: 0.9982
# Restoring model weights from the end of the best epoch.
# Epoch 00004: early stopping
# Model nr 16 of 200
# 16
# [{'model_nr_type': 'InceptionTime', 'index': 15}, {'batch_size': 512, 'epochs': 350, 'learning_rate': 0.01, 'num_channels': 3, 'optimizer': 'sgd'}, {'bottleneck_size': 40, 'kernel_size': 50, 'module_activation': 'sigmoid', 'module_output_activation': 'linear', 'nr_modules': 12, 'num_filters': 28, 'output_activation': 'sigmoid', 'shortcut_activation': 'sigmoid', 'use_bottleneck': True, 'use_residuals': True}]
# Starting:
# {   'batch_size': 512,
#     'epochs': 350,
#     'learning_rate': 0.01,
#     'num_channels': 3,
#     'optimizer': 'sgd'}
# ---------------------------------------------------------------------------------
# {   'bottleneck_size': 40,
#     'kernel_size': 50,
#     'module_activation': 'sigmoid',
#     'module_output_activation': 'linear',
#     'nr_modules': 12,
#     'num_filters': 28,
#     'output_activation': 'sigmoid',
#     'shortcut_activation': 'sigmoid',
#     'use_bottleneck': True,
#     'use_residuals': True}
# Epoch 1/350
# 82/82 [==============================] - 24s 252ms/step - loss: 0.6160 - precision_15: 0.6637 - binary_accuracy: 0.6637 - recall_15: 0.9997 - val_loss: 0.6414 - val_precision_15: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_15: 1.0000
# Epoch 2/350
# 82/82 [==============================] - 19s 240ms/step - loss: 0.5307 - precision_15: 0.7026 - binary_accuracy: 0.6951 - recall_15: 0.9410 - val_loss: 0.6472 - val_precision_15: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_15: 1.0000
# Epoch 3/350
# 82/82 [==============================] - 19s 238ms/step - loss: 0.4696 - precision_15: 0.7913 - binary_accuracy: 0.7558 - recall_15: 0.8586 - val_loss: 0.6682 - val_precision_15: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_15: 1.0000
# Epoch 4/350
# 82/82 [==============================] - 19s 236ms/step - loss: 0.4360 - precision_15: 0.8333 - binary_accuracy: 0.7815 - recall_15: 0.8397 - val_loss: 0.7002 - val_precision_15: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_15: 1.0000
# Restoring model weights from the end of the best epoch.
# Epoch 00004: early stopping
# Model nr 17 of 200
# 17
# [{'model_nr_type': 'InceptionTime', 'index': 16}, {'batch_size': 256, 'epochs': 300, 'learning_rate': 0.001, 'num_channels': 3, 'optimizer': 'adam'}, {'bottleneck_size': 26, 'kernel_size': 20, 'module_activation': 'sigmoid', 'module_output_activation': 'tanh', 'nr_modules': 6, 'num_filters': 40, 'output_activation': 'sigmoid', 'shortcut_activation': 'softmax', 'use_bottleneck': False, 'use_residuals': True}]
# Starting:
# {   'batch_size': 256,
#     'epochs': 300,
#     'learning_rate': 0.001,
#     'num_channels': 3,
#     'optimizer': 'adam'}
# ---------------------------------------------------------------------------------
# {   'bottleneck_size': 26,
#     'kernel_size': 20,
#     'module_activation': 'sigmoid',
#     'module_output_activation': 'tanh',
#     'nr_modules': 6,
#     'num_filters': 40,
#     'output_activation': 'sigmoid',
#     'shortcut_activation': 'softmax',
#     'use_bottleneck': False,
#     'use_residuals': True}
# Epoch 1/300
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping
# Model nr 18 of 200
# 18
# [{'model_nr_type': 'InceptionTime', 'index': 17}, {'batch_size': 1024, 'epochs': 200, 'learning_rate': 0.0001, 'num_channels': 3, 'optimizer': 'rmsprop'}, {'bottleneck_size': 34, 'kernel_size': 20, 'module_activation': 'linear', 'module_output_activation': 'softmax', 'nr_modules': 6, 'num_filters': 40, 'output_activation': 'sigmoid', 'shortcut_activation': 'relu', 'use_bottleneck': False, 'use_residuals': False}]
# Starting:
# {   'batch_size': 1024,
#     'epochs': 200,
#     'learning_rate': 0.0001,
#     'num_channels': 3,
#     'optimizer': 'rmsprop'}
# ---------------------------------------------------------------------------------
# {   'bottleneck_size': 34,
#     'kernel_size': 20,
#     'module_activation': 'linear',
#     'module_output_activation': 'softmax',
#     'nr_modules': 6,
#     'num_filters': 40,
#     'output_activation': 'sigmoid',
#     'shortcut_activation': 'relu',
#     'use_bottleneck': False,
#     'use_residuals': False}
# Epoch 1/200
# 41/41 [==============================] - 22s 498ms/step - loss: 0.6918 - precision_17: 0.6634 - binary_accuracy: 0.6634 - recall_17: 1.0000 - val_loss: 0.6907 - val_precision_17: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_17: 1.0000
# Epoch 2/200
# 41/41 [==============================] - 19s 485ms/step - loss: 0.6899 - precision_17: 0.6638 - binary_accuracy: 0.6638 - recall_17: 1.0000 - val_loss: 0.6894 - val_precision_17: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_17: 1.0000
# Epoch 3/200
# 41/41 [==============================] - 19s 484ms/step - loss: 0.6881 - precision_17: 0.6645 - binary_accuracy: 0.6645 - recall_17: 1.0000 - val_loss: 0.6881 - val_precision_17: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_17: 1.0000
# Epoch 4/200
# 41/41 [==============================] - 19s 482ms/step - loss: 0.6865 - precision_17: 0.6616 - binary_accuracy: 0.6616 - recall_17: 1.0000 - val_loss: 0.6868 - val_precision_17: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_17: 1.0000
# Epoch 5/200
# 41/41 [==============================] - 20s 488ms/step - loss: 0.6848 - precision_17: 0.6623 - binary_accuracy: 0.6623 - recall_17: 1.0000 - val_loss: 0.6856 - val_precision_17: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_17: 1.0000
# Epoch 6/200
# 41/41 [==============================] - 20s 489ms/step - loss: 0.6831 - precision_17: 0.6646 - binary_accuracy: 0.6646 - recall_17: 1.0000 - val_loss: 0.6843 - val_precision_17: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_17: 1.0000
# Epoch 7/200
# 41/41 [==============================] - 19s 485ms/step - loss: 0.6816 - precision_17: 0.6636 - binary_accuracy: 0.6636 - recall_17: 1.0000 - val_loss: 0.6831 - val_precision_17: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_17: 1.0000
# Epoch 8/200
# 41/41 [==============================] - 19s 486ms/step - loss: 0.6798 - precision_17: 0.6665 - binary_accuracy: 0.6665 - recall_17: 1.0000 - val_loss: 0.6818 - val_precision_17: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_17: 1.0000
# Epoch 9/200
# 41/41 [==============================] - 19s 485ms/step - loss: 0.6784 - precision_17: 0.6644 - binary_accuracy: 0.6644 - recall_17: 1.0000 - val_loss: 0.6805 - val_precision_17: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_17: 1.0000
# Epoch 10/200
# 41/41 [==============================] - 20s 488ms/step - loss: 0.6769 - precision_17: 0.6648 - binary_accuracy: 0.6648 - recall_17: 1.0000 - val_loss: 0.6792 - val_precision_17: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_17: 1.0000
# Epoch 11/200
# 41/41 [==============================] - 19s 485ms/step - loss: 0.6754 - precision_17: 0.6650 - binary_accuracy: 0.6650 - recall_17: 1.0000 - val_loss: 0.6777 - val_precision_17: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_17: 1.0000
# Epoch 12/200
# 41/41 [==============================] - 19s 485ms/step - loss: 0.6739 - precision_17: 0.6659 - binary_accuracy: 0.6659 - recall_17: 1.0000 - val_loss: 0.6763 - val_precision_17: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_17: 1.0000
# Epoch 13/200
# 41/41 [==============================] - 19s 484ms/step - loss: 0.6729 - precision_17: 0.6629 - binary_accuracy: 0.6629 - recall_17: 1.0000 - val_loss: 0.6749 - val_precision_17: 0.6594 - val_binary_accuracy: 0.6594 - val_recall_17: 1.0000
# Epoch 14/200
#  4/41 [=>............................] - ETA: 14s - loss: 0.6745 - precision_17: 0.6459 - binary_accuracy: 0.6459 - recall_17: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-4ff19472083c> in <module>
# ----> 1 results_df, min_loss, max_accuracy, max_precision, max_recall = randomGridSearch.fit()
#
# /media/tord/T7/Thesis_ssd/MasterThesis3.0/Classes/Modeling/InceptionTimeRGS.py in fit(self)
#     185                                                      use_reduced_lr = self.use_reduced_lr)
#     186             # Fit the model using the generated args
# --> 187             model_fit = model.fit(train_gen, **fit_args)
#     188
#     189             # Evaluate the fitted model on the validation set
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1132                 _r=1):
#    1133               callbacks.on_train_batch_begin(step)
# -> 1134               tmp_logs = self.train_function(iterator)
#    1135               if data_handler.should_sync:
#    1136                 context.async_wait()
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     816     tracing_count = self.experimental_get_tracing_count()
#     817     with trace.Trace(self._name) as tm:
# --> 818       result = self._call(*args, **kwds)
#     819       compiler = "xla" if self._jit_compile else "nonXla"
#     820       new_tracing_count = self.experimental_get_tracing_count()
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     844       # In this case we have created variables on the first call, so we run the
#     845       # defunned version which is guaranteed to never create variables.
# --> 846       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     847     elif self._stateful_fn is not None:
#     848       # Release the lock early so that multiple threads can perform the call
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2991       (graph_function,
#    2992        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2993     return graph_function._call_flat(
#    2994         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2995
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1936         and executing_eagerly):
#    1937       # No tape is watching; skip to running the function.
# -> 1938       return self._build_call_outputs(self._inference_function.call(
#    1939           ctx, args, cancellation_manager=cancellation_manager))
#    1940     forward_backward = self._select_forward_and_backward_functions(
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     562       with _InterpolateFunctionError(self):
#     563         if cancellation_manager is None:
# --> 564           outputs = execute.execute(
#     565               str(self.signature.name),
#     566               num_outputs=self._num_outputs,
#
# ~/.local/lib/python3.8/site-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:
